# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.distributions import MultivariateNormal
from collections import deque
import random
import matplotlib.pyplot as plt

class Policy(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.fc_mean = nn.Linear(dim, dim)
        self.log_std = nn.Parameter(torch.zeros(dim))

        # Value function baseline
        self.value_net = nn.Linear(dim, 1)

    def forward(self, x):
        mean = self.fc_mean(x)
        cov = torch.diag(torch.exp(self.log_std))
        return MultivariateNormal(mean, cov), self.value_net(x)



class ExperienceReplay:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        return random.sample(self.buffer, min(batch_size, len(self.buffer)))

    def __len__(self):
        return len(self.buffer)

def compute_improved_reward(v_new, v_prev, A, lambda_):
    """Enhanced reward function with multiple components"""
    # 1. Primary residual component
    residual = torch.linalg.norm((A - lambda_ * torch.eye(A.shape[0])) @ v_new)
    residual_component = -residual.item()

    # 2. Direction consistency component
    cosine_sim = torch.nn.functional.cosine_similarity(
        v_new.unsqueeze(0), v_prev.unsqueeze(0)
    ).item()
    direction_component = 0.3 * cosine_sim  # Weighted contribution


    with torch.no_grad():
        prev_residual = torch.linalg.norm( (A - lambda_ * torch.eye(A.shape[0])) @ v_prev )
    improvement_component = 0.2 * (prev_residual.item() - residual.item())

    # Combined reward
    reward = residual_component + direction_component + improvement_component

    return reward, residual.item(), cosine_sim

def train(A, lambda_, policy, epochs=500, batch_size=32, replay_size=1000, dominant_v=None):
    optimizer = optim.Adam(policy.parameters(), lr=1e-3)
    replay_buffer = ExperienceReplay(replay_size)
    v = torch.randn(A.shape[0])
    v = v / torch.norm(v)

    # Tracking variables
    best_v = v.clone()
    best_residual = float('inf')
    moving_avg_reward = 0
    alpha = 0.1  # For moving average

    for epoch in range(epochs):
        # Generate multiple trajectories for batch update
        states = []
        actions = []
        rewards = []
        values = []

        for _ in range(batch_size):
            v_prev = v.clone()
            dist, value_est = policy(v_prev)
            delta_v = dist.sample()

            with torch.no_grad():
                v_new = v_prev + delta_v
                v_new = v_new / torch.norm(v_new)
                reward, residual, cos_sim = compute_improved_reward(v_new, v_prev, A, lambda_)

                # Update best solution found
                if residual < best_residual:
                    best_residual = residual
                    best_v = v_new.clone()

                # Update moving average for baseline
                moving_avg_reward = alpha * reward + (1 - alpha) * moving_avg_reward

            # Store experience
            replay_buffer.push((v_prev, delta_v, reward, value_est))

            # Store for batch update
            states.append(v_prev)
            actions.append(delta_v)
            rewards.append(reward)
            values.append(value_est)

        # Sample from replay buffer
        if len(replay_buffer) > batch_size:
            replay_batch = replay_buffer.sample(batch_size)
            replay_states, replay_actions, replay_rewards, replay_values = zip(*replay_batch)

            # Combine with current batch
            states.extend(replay_states)
            actions.extend(replay_actions)
            rewards.extend(replay_rewards)
            values.extend(replay_values)

        # Convert to tensors
        states = torch.stack(states)
        actions = torch.stack(actions)
        rewards = torch.tensor(rewards, dtype=torch.float32)
        old_values = torch.cat(values).squeeze()

        # Normalize rewards
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-8)

        # Compute advantages
        advantages = rewards - old_values.detach()

        # Policy loss
        dists, value_ests = policy(states)
        log_probs = dists.log_prob(actions)

        # PPO-style clipped objective
        ratios = torch.exp(log_probs - dists.log_prob(actions).detach())
        clipped_ratios = torch.clamp(ratios, 0.8, 1.2)
        policy_loss = -torch.min(ratios * advantages, clipped_ratios * advantages).mean()

        # Value loss (MSE)
        value_loss = 0.5 * (value_ests.squeeze() - rewards).pow(2).mean()

        # Entropy bonus
        entropy = dists.entropy().mean()

        # Total loss
        loss = policy_loss + 0.5 * value_loss - 0.01 * entropy

        # Update
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(policy.parameters(), 1.0)
        optimizer.step()

        # Update v with best candidate from batch
        v = best_v.clone()

        if epoch % 100 == 0:
            print(
                f'Epoch {epoch}: Loss = {loss.item():.4f}, '
                f'Residual = {best_residual:.4f}, '
                f'Avg Reward = {moving_avg_reward:.4f}'
                f', Cosine Similarity = {torch.nn.functional.cosine_similarity(best_v.unsqueeze(0), dominant_v.unsqueeze(0)).item():.4f}'
                )

    return best_v

# Test function with improved training
def test_improved_policy(dim=5, epochs=1000):
    # Generate random symmetric matrix
    A_np = np.random.randn(dim, dim)
    A_np = A_np + A_np.T
    A = torch.tensor(A_np, dtype=torch.float32)

    # Get ground truth
    eigenvalues, eigenvectors = np.linalg.eig(A_np)
    dominant_idx = np.argmax(np.abs(eigenvalues))
    dominant_lambda = eigenvalues[dominant_idx]
    dominant_v = torch.tensor(eigenvectors[:, dominant_idx], dtype=torch.float32)

    print(f"True dominant eigenvalue: {dominant_lambda}")

    # Train
    policy = Policy(dim)
    predicted_v = train(A, dominant_lambda, policy, epochs=epochs, dominant_v=dominant_v)

    # Compare
    cosine_sim = torch.nn.functional.cosine_similarity(
        predicted_v.unsqueeze(0), dominant_v.unsqueeze(0)
    ).item()

    print(f"\nPredicted eigenvector: {predicted_v.detach().numpy()}")
    print(f"True eigenvector: {dominant_v.numpy()}")
    print(f"Cosine similarity: {cosine_sim:.4f}")
    import matplotlib.pyplot as plt



    return cosine_sim

# %%
test_improved_policy(dim=50, epochs=1001)

# %% [markdown]
# ## Testing on $200 \times 200$ Matrix

# %%
result = np.zeros(200)
for i in range(200):
    result[i]=test_improved_policy(dim=200, epochs=1001)

# %%
choices = [5, 10, 20, 50, 75, 100]
results = []
for dim in choices:
    print(f"\nTesting with dimension: {dim}")
    for i in range(10):
        print(f"Run {i + 1}")
        x = test_improved_policy(dim=dim, epochs=1001)
        results.append(x)
results = np.array(results)
results = results.reshape(len(choices), 10)
# Out:
# Testing with dimension: 5
# Run 1
# True dominant eigenvalue: 5.396123113872305
# Epoch 0: Loss = 0.0627, Residual = 1.8826, Avg Reward = -5.4884, Cosine Similarity = -0.8536
# Epoch 100: Loss = 0.1922, Residual = 0.6594, Avg Reward = -4.8928, Cosine Similarity = -0.9929
# Epoch 200: Loss = 0.1940, Residual = 0.5165, Avg Reward = -4.3043, Cosine Similarity = -0.9937
# Epoch 300: Loss = 0.1788, Residual = 0.5165, Avg Reward = -4.0824, Cosine Similarity = -0.9937
# Epoch 400: Loss = 0.1768, Residual = 0.5108, Avg Reward = -3.0839, Cosine Similarity = -0.9879
# Epoch 500: Loss = 0.1786, Residual = 0.2031, Avg Reward = -2.5470, Cosine Similarity = -0.9966
# Epoch 600: Loss = 0.1860, Residual = 0.2031, Avg Reward = -2.5558, Cosine Similarity = -0.9966
# Epoch 700: Loss = 0.1877, Residual = 0.1519, Avg Reward = -1.9104, Cosine Similarity = -0.9997
# Epoch 800: Loss = 0.1910, Residual = 0.1519, Avg Reward = -1.9065, Cosine Similarity = -0.9997
# Epoch 900: Loss = 0.1947, Residual = 0.0977, Avg Reward = -2.0552, Cosine Similarity = -0.9999
# Epoch 1000: Loss = 0.1959, Residual = 0.0977, Avg Reward = -1.5110, Cosine Similarity = -0.9999
#
# Predicted eigenvector: [-0.01461377 -0.07885553  0.6545268  -0.6403373   0.3938669 ]
# True eigenvector: [ 0.02027559  0.09092839 -0.65067554  0.63975644 -0.39831385]
# Cosine similarity: -0.9999
# Run 2
# True dominant eigenvalue: -4.3127177726937
# Epoch 0: Loss = 0.1153, Residual = 2.7877, Avg Reward = -5.2068, Cosine Similarity = -0.8268
# Epoch 100: Loss = 0.4960, Residual = 0.6910, Avg Reward = -4.3163, Cosine Similarity = 0.9873
# Epoch 200: Loss = 0.2216, Residual = 0.2612, Avg Reward = -3.8032, Cosine Similarity = 0.9984
# Epoch 300: Loss = 0.1866, Residual = 0.2612, Avg Reward = -2.7670, Cosine Similarity = 0.9984
# Epoch 400: Loss = 0.1936, Residual = 0.2166, Avg Reward = -2.7052, Cosine Similarity = 0.9987
# Epoch 500: Loss = 0.1600, Residual = 0.1758, Avg Reward = -2.1559, Cosine Similarity = 0.9994
# Epoch 600: Loss = 0.1846, Residual = 0.1758, Avg Reward = -1.8679, Cosine Similarity = 0.9994
# Epoch 700: Loss = 0.1893, Residual = 0.1758, Avg Reward = -1.5094, Cosine Similarity = 0.9994
# Epoch 800: Loss = 0.1922, Residual = 0.1541, Avg Reward = -1.3862, Cosine Similarity = 0.9997
# Epoch 900: Loss = 0.1972, Residual = 0.0731, Avg Reward = -1.0955, Cosine Similarity = 0.9999
# Epoch 1000: Loss = 0.1969, Residual = 0.0731, Avg Reward = -1.1913, Cosine Similarity = 0.9999
#
# Predicted eigenvector: [-0.44112474  0.6364687  -0.45578408  0.42883143  0.093172  ]
# True eigenvector: [-0.44445404  0.62913257 -0.46536118  0.42736378  0.08632512]
# Cosine similarity: 0.9999
# Run 3
# True dominant eigenvalue: 4.623407489449587
# Epoch 0: Loss = -0.0418, Residual = 1.7593, Avg Reward = -4.8948, Cosine Similarity = -0.8592
# Epoch 100: Loss = 0.1936, Residual = 0.4604, Avg Reward = -3.8563, Cosine Similarity = -0.9823
# Epoch 200: Loss = 0.1866, Residual = 0.4169, Avg Reward = -3.7212, Cosine Similarity = -0.9939
# Epoch 300: Loss = 0.2110, Residual = 0.1762, Avg Reward = -2.7833, Cosine Similarity = -0.9956
# Epoch 400: Loss = 0.1824, Residual = 0.1762, Avg Reward = -2.3649, Cosine Similarity = -0.9956
# Epoch 500: Loss = 0.1827, Residual = 0.1567, Avg Reward = -1.9450, Cosine Similarity = -0.9965
# Epoch 600: Loss = 0.1877, Residual = 0.1567, Avg Reward = -1.6529, Cosine Similarity = -0.9965
# Epoch 700: Loss = 0.1857, Residual = 0.1051, Avg Reward = -1.3519, Cosine Similarity = -0.9999
# Epoch 800: Loss = 0.1921, Residual = 0.0614, Avg Reward = -1.0307, Cosine Similarity = -0.9997
# Epoch 900: Loss = 0.1953, Residual = 0.0614, Avg Reward = -0.9059, Cosine Similarity = -0.9997
# Epoch 1000: Loss = 0.1976, Residual = 0.0614, Avg Reward = -0.8638, Cosine Similarity = -0.9997
#
# Predicted eigenvector: [-0.5346169   0.4768381   0.35685793  0.49097055 -0.3441083 ]
# True eigenvector: [ 0.55407226 -0.4716499  -0.3571731  -0.47751266  0.3390566 ]
# Cosine similarity: -0.9997
# Run 4
# True dominant eigenvalue: 7.424644191604971
# Epoch 0: Loss = 0.6771, Residual = 4.4515, Avg Reward = -6.1314, Cosine Similarity = -0.0698
# Epoch 100: Loss = 0.1175, Residual = 0.8955, Avg Reward = -5.7014, Cosine Similarity = -0.9947
# Epoch 200: Loss = 0.1782, Residual = 0.5845, Avg Reward = -5.4771, Cosine Similarity = -0.9973
# Epoch 300: Loss = 0.1473, Residual = 0.5469, Avg Reward = -5.2452, Cosine Similarity = -0.9959
# Epoch 400: Loss = 0.1820, Residual = 0.3385, Avg Reward = -3.2280, Cosine Similarity = -0.9989
# Epoch 500: Loss = 0.2017, Residual = 0.3014, Avg Reward = -3.3332, Cosine Similarity = -0.9977
# Epoch 600: Loss = 0.1867, Residual = 0.2722, Avg Reward = -2.8890, Cosine Similarity = -0.9987
# Epoch 700: Loss = 0.1864, Residual = 0.2416, Avg Reward = -2.9873, Cosine Similarity = -0.9994
# Epoch 800: Loss = 0.2055, Residual = 0.2281, Avg Reward = -1.9167, Cosine Similarity = -0.9976
# Epoch 900: Loss = 0.1946, Residual = 0.1672, Avg Reward = -1.8832, Cosine Similarity = -0.9998
# Epoch 1000: Loss = 0.1965, Residual = 0.1672, Avg Reward = -1.6328, Cosine Similarity = -0.9998
#
# Predicted eigenvector: [ 0.7359285  -0.28236076 -0.11941451  0.5690835  -0.20140982]
# True eigenvector: [-0.7254971   0.27789646  0.12690455 -0.57887757  0.21265809]
# Cosine similarity: -0.9998
# Run 5
# True dominant eigenvalue: 5.593262845807819
# Epoch 0: Loss = 0.1573, Residual = 2.4699, Avg Reward = -5.9255, Cosine Similarity = -0.9100
# Epoch 100: Loss = 0.1704, Residual = 0.8433, Avg Reward = -7.1768, Cosine Similarity = -0.9905
# Epoch 200: Loss = 0.1769, Residual = 0.7052, Avg Reward = -5.7393, Cosine Similarity = -0.9946
# Epoch 300: Loss = 0.1788, Residual = 0.6294, Avg Reward = -4.7398, Cosine Similarity = -0.9982
# Epoch 400: Loss = 0.1810, Residual = 0.6294, Avg Reward = -4.7839, Cosine Similarity = -0.9982
# Epoch 500: Loss = 0.2000, Residual = 0.4794, Avg Reward = -4.5818, Cosine Similarity = -0.9969
# Epoch 600: Loss = 0.1859, Residual = 0.2574, Avg Reward = -3.3805, Cosine Similarity = -0.9990
# Epoch 700: Loss = 0.1884, Residual = 0.2574, Avg Reward = -3.0661, Cosine Similarity = -0.9990
# Epoch 800: Loss = 0.1909, Residual = 0.2574, Avg Reward = -2.6337, Cosine Similarity = -0.9990
# Epoch 900: Loss = 0.1932, Residual = 0.2574, Avg Reward = -2.5884, Cosine Similarity = -0.9990
# Epoch 1000: Loss = 0.1956, Residual = 0.2381, Avg Reward = -2.1510, Cosine Similarity = -0.9995
#
# Predicted eigenvector: [ 0.20621786 -0.03627452  0.8343472  -0.4391597   0.2591563 ]
# True eigenvector: [-0.1834343   0.04194694 -0.84855896  0.4274603  -0.24863164]
# Cosine similarity: -0.9995
# Run 6
# True dominant eigenvalue: 4.34313351627869
# Epoch 0: Loss = 0.3499, Residual = 2.7302, Avg Reward = -5.2213, Cosine Similarity = 0.8038
# Epoch 100: Loss = 0.1061, Residual = 0.4676, Avg Reward = -4.4425, Cosine Similarity = -0.9710
# Epoch 200: Loss = 0.1554, Residual = 0.4030, Avg Reward = -3.6182, Cosine Similarity = -0.9922
# Epoch 300: Loss = 0.1799, Residual = 0.1242, Avg Reward = -3.1947, Cosine Similarity = -0.9999
# Epoch 400: Loss = 0.1819, Residual = 0.1242, Avg Reward = -3.2740, Cosine Similarity = -0.9999
# Epoch 500: Loss = 0.1841, Residual = 0.1242, Avg Reward = -2.5553, Cosine Similarity = -0.9999
# Epoch 600: Loss = 0.1865, Residual = 0.1242, Avg Reward = -2.3196, Cosine Similarity = -0.9999
# Epoch 700: Loss = 0.1887, Residual = 0.1242, Avg Reward = -1.5926, Cosine Similarity = -0.9999
# Epoch 800: Loss = 0.1859, Residual = 0.1219, Avg Reward = -1.8026, Cosine Similarity = -0.9988
# Epoch 900: Loss = 0.1933, Residual = 0.1219, Avg Reward = -1.7015, Cosine Similarity = -0.9988
# Epoch 1000: Loss = 0.1955, Residual = 0.1219, Avg Reward = -1.3589, Cosine Similarity = -0.9988
#
# Predicted eigenvector: [-0.21954575  0.84137666 -0.18728912 -0.24877508  0.38329986]
# True eigenvector: [ 0.21500249 -0.8242417   0.16543703  0.2727685  -0.4154847 ]
# Cosine similarity: -0.9988
# Run 7
# True dominant eigenvalue: 6.049689371551798
# Epoch 0: Loss = 0.2877, Residual = 3.1333, Avg Reward = -5.7905, Cosine Similarity = -0.8389
# Epoch 100: Loss = 0.2447, Residual = 0.5711, Avg Reward = -5.2408, Cosine Similarity = -0.9750
# Epoch 200: Loss = 0.1806, Residual = 0.5711, Avg Reward = -5.1945, Cosine Similarity = -0.9750
# Epoch 300: Loss = 0.1915, Residual = 0.4216, Avg Reward = -3.7541, Cosine Similarity = -0.9972
# Epoch 400: Loss = 0.1818, Residual = 0.2817, Avg Reward = -3.3794, Cosine Similarity = -0.9994
# Epoch 500: Loss = 0.1840, Residual = 0.2817, Avg Reward = -2.5626, Cosine Similarity = -0.9994
# Epoch 600: Loss = 0.1864, Residual = 0.2817, Avg Reward = -2.8269, Cosine Similarity = -0.9994
# Epoch 700: Loss = 0.1929, Residual = 0.2371, Avg Reward = -1.9117, Cosine Similarity = -0.9991
# Epoch 800: Loss = 0.1911, Residual = 0.2266, Avg Reward = -1.7646, Cosine Similarity = -0.9990
# Epoch 900: Loss = 0.1932, Residual = 0.1289, Avg Reward = -1.7797, Cosine Similarity = -0.9998
# Epoch 1000: Loss = 0.1965, Residual = 0.1289, Avg Reward = -1.3320, Cosine Similarity = -0.9998
#
# Predicted eigenvector: [ 0.61287636 -0.06127654  0.40238798  0.20198202  0.64646345]
# True eigenvector: [-0.6235671   0.04891699 -0.4049638  -0.19571151 -0.63755196]
# Cosine similarity: -0.9998
# Run 8
# True dominant eigenvalue: 5.368263445986365
# Epoch 0: Loss = 0.8505, Residual = 4.6451, Avg Reward = -6.4451, Cosine Similarity = -0.3923
# Epoch 100: Loss = 0.1385, Residual = 0.9207, Avg Reward = -7.1818, Cosine Similarity = -0.9945
# Epoch 200: Loss = 0.1914, Residual = 0.7986, Avg Reward = -6.0571, Cosine Similarity = -0.9920
# Epoch 300: Loss = 0.1705, Residual = 0.5944, Avg Reward = -5.6092, Cosine Similarity = -0.9973
# Epoch 400: Loss = 0.1817, Residual = 0.3815, Avg Reward = -4.4488, Cosine Similarity = -0.9978
# Epoch 500: Loss = 0.1834, Residual = 0.2130, Avg Reward = -3.4352, Cosine Similarity = -0.9994
# Epoch 600: Loss = 0.1862, Residual = 0.2130, Avg Reward = -2.6680, Cosine Similarity = -0.9994
# Epoch 700: Loss = 0.1888, Residual = 0.2130, Avg Reward = -2.2853, Cosine Similarity = -0.9994
# Epoch 800: Loss = 0.1909, Residual = 0.1513, Avg Reward = -2.0815, Cosine Similarity = -0.9998
# Epoch 900: Loss = 0.1939, Residual = 0.1513, Avg Reward = -1.8644, Cosine Similarity = -0.9998
# Epoch 1000: Loss = 0.1964, Residual = 0.0932, Avg Reward = -1.6572, Cosine Similarity = -0.9999
#
# Predicted eigenvector: [-0.2896175   0.5676429  -0.3012428   0.47352287 -0.5281402 ]
# True eigenvector: [ 0.29465038 -0.56882364  0.30726966 -0.46039292  0.5322072 ]
# Cosine similarity: -0.9999
# Run 9
# True dominant eigenvalue: 5.420245550019694
# Epoch 0: Loss = -0.2306, Residual = 1.5774, Avg Reward = -5.0220, Cosine Similarity = 0.9675
# Epoch 100: Loss = 0.2516, Residual = 0.1878, Avg Reward = -4.1216, Cosine Similarity = 0.9951
# Epoch 200: Loss = 0.1806, Residual = 0.1878, Avg Reward = -3.5088, Cosine Similarity = 0.9951
# Epoch 300: Loss = 0.1793, Residual = 0.1878, Avg Reward = -2.7416, Cosine Similarity = 0.9951
# Epoch 400: Loss = 0.1616, Residual = 0.1772, Avg Reward = -2.8205, Cosine Similarity = 0.9980
# Epoch 500: Loss = 0.1873, Residual = 0.1640, Avg Reward = -2.6835, Cosine Similarity = 0.9990
# Epoch 600: Loss = 0.1862, Residual = 0.1640, Avg Reward = -2.0967, Cosine Similarity = 0.9990
# Epoch 700: Loss = 0.1753, Residual = 0.1342, Avg Reward = -1.5386, Cosine Similarity = 0.9982
# Epoch 800: Loss = 0.1910, Residual = 0.1342, Avg Reward = -1.8133, Cosine Similarity = 0.9982
# Epoch 900: Loss = 0.1934, Residual = 0.1294, Avg Reward = -1.3964, Cosine Similarity = 0.9980
# Epoch 1000: Loss = 0.1958, Residual = 0.1294, Avg Reward = -1.3949, Cosine Similarity = 0.9980
#
# Predicted eigenvector: [ 0.32000247  0.2490091   0.1080085  -0.3839024   0.82252425]
# True eigenvector: [ 0.28033772  0.22895692  0.08964958 -0.42469442  0.82497704]
# Cosine similarity: 0.9980
# Run 10
# True dominant eigenvalue: 5.340625752501963
# Epoch 0: Loss = 0.3382, Residual = 3.9621, Avg Reward = -5.7821, Cosine Similarity = 0.8407
# Epoch 100: Loss = 0.1553, Residual = 0.6163, Avg Reward = -4.5253, Cosine Similarity = 0.9920
# Epoch 200: Loss = 0.1782, Residual = 0.6163, Avg Reward = -4.4194, Cosine Similarity = 0.9920
# Epoch 300: Loss = 0.1811, Residual = 0.4961, Avg Reward = -4.6254, Cosine Similarity = 0.9936
# Epoch 400: Loss = 0.2091, Residual = 0.3931, Avg Reward = -3.1751, Cosine Similarity = 0.9953
# Epoch 500: Loss = 0.1564, Residual = 0.3147, Avg Reward = -2.6757, Cosine Similarity = 0.9953
# Epoch 600: Loss = 0.1845, Residual = 0.2065, Avg Reward = -2.0448, Cosine Similarity = 0.9976
# Epoch 700: Loss = 0.1954, Residual = 0.1901, Avg Reward = -2.2417, Cosine Similarity = 0.9995
# Epoch 800: Loss = 0.1933, Residual = 0.1901, Avg Reward = -1.4156, Cosine Similarity = 0.9995
# Epoch 900: Loss = 0.1957, Residual = 0.1840, Avg Reward = -1.4288, Cosine Similarity = 0.9992
# Epoch 1000: Loss = 0.1983, Residual = 0.1403, Avg Reward = -1.0528, Cosine Similarity = 0.9989
#
# Predicted eigenvector: [-0.651203    0.50155115  0.38011038  0.11634418 -0.40787405]
# True eigenvector: [-0.6797102   0.47093058  0.36206505  0.1216507  -0.4127086 ]
# Cosine similarity: 0.9989
#
# Testing with dimension: 10
# Run 1
# True dominant eigenvalue: -6.801385381576429
# Epoch 0: Loss = -0.1118, Residual = 3.2412, Avg Reward = -6.7095, Cosine Similarity = 0.8036
# Epoch 100: Loss = 0.1097, Residual = 2.3641, Avg Reward = -7.3446, Cosine Similarity = 0.9026
# Epoch 200: Loss = 0.1090, Residual = 1.7955, Avg Reward = -7.1074, Cosine Similarity = 0.9256
# Epoch 300: Loss = 0.1116, Residual = 1.6027, Avg Reward = -5.0960, Cosine Similarity = 0.9321
# Epoch 400: Loss = 0.0738, Residual = 1.2641, Avg Reward = -5.6932, Cosine Similarity = 0.9379
# Epoch 500: Loss = 0.1197, Residual = 1.2641, Avg Reward = -4.6447, Cosine Similarity = 0.9379
# Epoch 600: Loss = 0.1283, Residual = 1.0343, Avg Reward = -3.3696, Cosine Similarity = 0.9910
# Epoch 700: Loss = 0.1162, Residual = 0.9918, Avg Reward = -3.4503, Cosine Similarity = 0.9836
# Epoch 800: Loss = 0.1628, Residual = 0.6169, Avg Reward = -2.6498, Cosine Similarity = 0.9964
# Epoch 900: Loss = 0.1374, Residual = 0.6169, Avg Reward = -2.1602, Cosine Similarity = 0.9964
# Epoch 1000: Loss = 0.1413, Residual = 0.4137, Avg Reward = -2.1067, Cosine Similarity = 0.9887
#
# Predicted eigenvector: [-0.14385642 -0.18644193 -0.02180882 -0.14473031 -0.25399122 -0.5164482
#  -0.34815636 -0.53603494  0.35321185  0.24204753]
# True eigenvector: [-0.09571635 -0.19564596 -0.04548108 -0.11086572 -0.21877305 -0.5327676
#  -0.2634127  -0.5194085   0.3995851   0.32811376]
# Cosine similarity: 0.9887
# Run 2
# True dominant eigenvalue: 8.625012279290807
# Epoch 0: Loss = -0.0507, Residual = 4.8533, Avg Reward = -8.4101, Cosine Similarity = 0.9028
# Epoch 100: Loss = 0.1075, Residual = 2.7122, Avg Reward = -10.0111, Cosine Similarity = 0.9222
# Epoch 200: Loss = 0.1085, Residual = 2.3685, Avg Reward = -8.9227, Cosine Similarity = 0.9802
# Epoch 300: Loss = 0.0743, Residual = 1.9550, Avg Reward = -7.5174, Cosine Similarity = 0.9466
# Epoch 400: Loss = 0.1159, Residual = 1.9550, Avg Reward = -5.9393, Cosine Similarity = 0.9466
# Epoch 500: Loss = 0.1068, Residual = 1.7196, Avg Reward = -5.5103, Cosine Similarity = 0.9794
# Epoch 600: Loss = 0.1104, Residual = 1.2775, Avg Reward = -5.4634, Cosine Similarity = 0.9823
# Epoch 700: Loss = 0.1288, Residual = 1.0956, Avg Reward = -4.0240, Cosine Similarity = 0.9905
# Epoch 800: Loss = 0.1349, Residual = 1.0929, Avg Reward = -3.4831, Cosine Similarity = 0.9894
# Epoch 900: Loss = 0.1376, Residual = 0.9963, Avg Reward = -3.0458, Cosine Similarity = 0.9931
# Epoch 1000: Loss = 0.1417, Residual = 0.8558, Avg Reward = -2.5539, Cosine Similarity = 0.9891
#
# Predicted eigenvector: [ 0.1696812   0.03835448  0.60992885 -0.15310681 -0.10016666 -0.341306
#   0.47132054 -0.22706814  0.37435666 -0.18415554]
# True eigenvector: [ 0.15978898  0.10342535  0.5723442  -0.06368922 -0.052968   -0.36403683
#   0.51451993 -0.27665058  0.34463692 -0.19174767]
# Cosine similarity: 0.9891
# Run 3
# True dominant eigenvalue: -9.248326552795307
# Epoch 0: Loss = 0.5642, Residual = 6.2524, Avg Reward = -9.8962, Cosine Similarity = -0.2038
# Epoch 100: Loss = 0.1513, Residual = 3.0830, Avg Reward = -11.6495, Cosine Similarity = 0.3066
# Epoch 200: Loss = 0.0980, Residual = 1.9505, Avg Reward = -9.7644, Cosine Similarity = 0.4075
# Epoch 300: Loss = 0.1077, Residual = 1.9505, Avg Reward = -8.5320, Cosine Similarity = 0.4075
# Epoch 400: Loss = 0.1110, Residual = 1.9505, Avg Reward = -8.0576, Cosine Similarity = 0.4075
# Epoch 500: Loss = 0.1028, Residual = 1.8107, Avg Reward = -7.1668, Cosine Similarity = 0.4540
# Epoch 600: Loss = 0.1187, Residual = 1.8107, Avg Reward = -5.9379, Cosine Similarity = 0.4540
# Epoch 700: Loss = 0.1233, Residual = 1.8107, Avg Reward = -5.0245, Cosine Similarity = 0.4540
# Epoch 800: Loss = 0.1280, Residual = 1.8107, Avg Reward = -4.0794, Cosine Similarity = 0.4540
# Epoch 900: Loss = 0.1326, Residual = 1.7786, Avg Reward = -3.9017, Cosine Similarity = 0.4683
# Epoch 1000: Loss = 0.1372, Residual = 1.6712, Avg Reward = -3.8202, Cosine Similarity = 0.3957
#
# Predicted eigenvector: [ 0.09112818 -0.46685728  0.17089154 -0.67008424  0.2670509  -0.04469552
#  -0.34285742  0.06043112  0.31412384  0.04829375]
# True eigenvector: [-0.04242318 -0.69638157 -0.20218435 -0.03391425 -0.08574392  0.06864477
#  -0.46085858  0.12012623 -0.23351067  0.42167756]
# Cosine similarity: 0.3957
# Run 4
# True dominant eigenvalue: 10.72587458712874
# Epoch 0: Loss = -0.0508, Residual = 7.3668, Avg Reward = -12.4784, Cosine Similarity = 0.2204
# Epoch 100: Loss = 0.0841, Residual = 3.7823, Avg Reward = -9.9078, Cosine Similarity = 0.8129
# Epoch 200: Loss = 0.1560, Residual = 2.2800, Avg Reward = -9.7729, Cosine Similarity = 0.9448
# Epoch 300: Loss = 0.1110, Residual = 2.2800, Avg Reward = -8.1478, Cosine Similarity = 0.9448
# Epoch 400: Loss = 0.1144, Residual = 2.2800, Avg Reward = -8.2097, Cosine Similarity = 0.9448
# Epoch 500: Loss = 0.1184, Residual = 2.2800, Avg Reward = -7.2396, Cosine Similarity = 0.9448
# Epoch 600: Loss = 0.1225, Residual = 2.2800, Avg Reward = -6.4249, Cosine Similarity = 0.9448
# Epoch 700: Loss = 0.1267, Residual = 2.2202, Avg Reward = -6.4018, Cosine Similarity = 0.9556
# Epoch 800: Loss = 0.1312, Residual = 2.1454, Avg Reward = -5.1719, Cosine Similarity = 0.9010
# Epoch 900: Loss = 0.1351, Residual = 2.1454, Avg Reward = -5.1009, Cosine Similarity = 0.9010
# Epoch 1000: Loss = 0.1393, Residual = 2.1454, Avg Reward = -4.6661, Cosine Similarity = 0.9010
#
# Predicted eigenvector: [ 0.3869254  -0.2546087   0.07468685  0.25910583  0.0714113  -0.08095727
#  -0.16883357  0.78313756  0.2390981   0.04602542]
# True eigenvector: [ 0.20115139 -0.38821307  0.0483869   0.41742182  0.29813185 -0.07725242
#  -0.01330501  0.6904476   0.13652207  0.20460367]
# Cosine similarity: 0.9010
# Run 5
# True dominant eigenvalue: 10.023438531182865
# Epoch 0: Loss = -0.2602, Residual = 6.3696, Avg Reward = -10.5062, Cosine Similarity = 0.4888
# Epoch 100: Loss = 0.1494, Residual = 3.1712, Avg Reward = -10.7115, Cosine Similarity = 0.8806
# Epoch 200: Loss = 0.1066, Residual = 2.6331, Avg Reward = -10.1145, Cosine Similarity = 0.9536
# Epoch 300: Loss = 0.1194, Residual = 2.2641, Avg Reward = -7.7279, Cosine Similarity = 0.9766
# Epoch 400: Loss = 0.1489, Residual = 2.1366, Avg Reward = -6.9025, Cosine Similarity = 0.9744
# Epoch 500: Loss = 0.1200, Residual = 1.7181, Avg Reward = -6.6752, Cosine Similarity = 0.9731
# Epoch 600: Loss = 0.0685, Residual = 1.1231, Avg Reward = -5.0285, Cosine Similarity = 0.9856
# Epoch 700: Loss = 0.1288, Residual = 1.1231, Avg Reward = -4.3516, Cosine Similarity = 0.9856
# Epoch 800: Loss = 0.1334, Residual = 1.1231, Avg Reward = -3.9624, Cosine Similarity = 0.9856
# Epoch 900: Loss = 0.1370, Residual = 1.0668, Avg Reward = -4.0118, Cosine Similarity = 0.9926
# Epoch 1000: Loss = 0.1428, Residual = 0.8858, Avg Reward = -2.9869, Cosine Similarity = 0.9921
#
# Predicted eigenvector: [ 0.09047431  0.12459861 -0.16304182  0.23791529 -0.4221267  -0.38173488
#   0.13754386 -0.10396704  0.2576235  -0.68781793]
# True eigenvector: [ 0.06298075  0.09147517 -0.1264828   0.21529415 -0.41847664 -0.3920148
#   0.15135123 -0.18900955  0.31882253 -0.6604834 ]
# Cosine similarity: 0.9921
# Run 6
# True dominant eigenvalue: -7.595470390740948
# Epoch 0: Loss = 0.3675, Residual = 5.6882, Avg Reward = -8.1179, Cosine Similarity = 0.7642
# Epoch 100: Loss = 0.2789, Residual = 1.6491, Avg Reward = -8.2582, Cosine Similarity = -0.8620
# Epoch 200: Loss = 0.1384, Residual = 1.6491, Avg Reward = -7.2036, Cosine Similarity = -0.8620
# Epoch 300: Loss = 0.1138, Residual = 1.6491, Avg Reward = -6.9298, Cosine Similarity = -0.8620
# Epoch 400: Loss = 0.1074, Residual = 1.6225, Avg Reward = -5.1312, Cosine Similarity = -0.6881
# Epoch 500: Loss = 0.1188, Residual = 1.6225, Avg Reward = -4.8605, Cosine Similarity = -0.6881
# Epoch 600: Loss = 0.1605, Residual = 1.5697, Avg Reward = -4.0786, Cosine Similarity = -0.3025
# Epoch 700: Loss = 0.0930, Residual = 1.5028, Avg Reward = -3.3192, Cosine Similarity = -0.4890
# Epoch 800: Loss = 0.1665, Residual = 1.2954, Avg Reward = -3.5275, Cosine Similarity = -0.3596
# Epoch 900: Loss = 0.1368, Residual = 1.2851, Avg Reward = -2.6298, Cosine Similarity = -0.3856
# Epoch 1000: Loss = 0.1317, Residual = 1.2839, Avg Reward = -2.4932, Cosine Similarity = -0.4146
#
# Predicted eigenvector: [ 0.19448686  0.30579692 -0.06934074  0.09159444  0.25808218  0.6385411
#  -0.31874537  0.09378526 -0.28878263  0.4328218 ]
# True eigenvector: [ 0.05067525  0.09086353 -0.26774925  0.33951002 -0.23838338 -0.5030977
#  -0.13327223 -0.25257695  0.63247883  0.10343659]
# Cosine similarity: -0.4146
# Run 7
# True dominant eigenvalue: 9.124967085598058
# Epoch 0: Loss = 0.1968, Residual = 6.3151, Avg Reward = -9.6535, Cosine Similarity = 0.5404
# Epoch 100: Loss = 0.0666, Residual = 3.7368, Avg Reward = -11.0725, Cosine Similarity = 0.9295
# Epoch 200: Loss = 0.0973, Residual = 2.7738, Avg Reward = -8.6168, Cosine Similarity = 0.8978
# Epoch 300: Loss = 0.1505, Residual = 2.4318, Avg Reward = -8.3794, Cosine Similarity = 0.9676
# Epoch 400: Loss = 0.0848, Residual = 1.9375, Avg Reward = -7.4629, Cosine Similarity = 0.9780
# Epoch 500: Loss = 0.1216, Residual = 1.8637, Avg Reward = -7.7233, Cosine Similarity = 0.9761
# Epoch 600: Loss = 0.1216, Residual = 1.8611, Avg Reward = -5.7862, Cosine Similarity = 0.9813
# Epoch 700: Loss = 0.1250, Residual = 1.4799, Avg Reward = -5.0957, Cosine Similarity = 0.9569
# Epoch 800: Loss = 0.1280, Residual = 1.3690, Avg Reward = -4.5109, Cosine Similarity = 0.9825
# Epoch 900: Loss = 0.1414, Residual = 1.0482, Avg Reward = -4.0569, Cosine Similarity = 0.9952
# Epoch 1000: Loss = 0.1374, Residual = 1.0482, Avg Reward = -3.8334, Cosine Similarity = 0.9952
#
# Predicted eigenvector: [-0.20586853 -0.60082185 -0.65535533  0.01518451  0.20791762 -0.0029162
#   0.17152281 -0.02005273 -0.2704913   0.14381944]
# True eigenvector: [-0.20470555 -0.5779521  -0.664704    0.0013398   0.18335368  0.07568821
#   0.16280562 -0.02331675 -0.31360263  0.13225177]
# Cosine similarity: 0.9952
# Run 8
# True dominant eigenvalue: 9.093044322038967
# Epoch 0: Loss = -0.0551, Residual = 7.4396, Avg Reward = -10.1369, Cosine Similarity = 0.1076
# Epoch 100: Loss = 0.2520, Residual = 2.8607, Avg Reward = -9.8381, Cosine Similarity = -0.7957
# Epoch 200: Loss = 0.0810, Residual = 2.4440, Avg Reward = -7.7554, Cosine Similarity = -0.8561
# Epoch 300: Loss = 0.1135, Residual = 2.0760, Avg Reward = -7.0516, Cosine Similarity = -0.9400
# Epoch 400: Loss = 0.1278, Residual = 1.7925, Avg Reward = -5.5847, Cosine Similarity = -0.9270
# Epoch 500: Loss = 0.1209, Residual = 1.2185, Avg Reward = -5.4601, Cosine Similarity = -0.9537
# Epoch 600: Loss = 0.1228, Residual = 0.9564, Avg Reward = -4.4879, Cosine Similarity = -0.9907
# Epoch 700: Loss = 0.1284, Residual = 0.9564, Avg Reward = -3.2795, Cosine Similarity = -0.9907
# Epoch 800: Loss = 0.1289, Residual = 0.8653, Avg Reward = -3.2708, Cosine Similarity = -0.9768
# Epoch 900: Loss = 0.1362, Residual = 0.6259, Avg Reward = -3.0472, Cosine Similarity = -0.9914
# Epoch 1000: Loss = 0.1509, Residual = 0.4755, Avg Reward = -1.9598, Cosine Similarity = -0.9940
#
# Predicted eigenvector: [ 0.2435123   0.20214841 -0.29949355 -0.3079733   0.29699603 -0.16244265
#  -0.47546116  0.03111527 -0.44362366 -0.42055458]
# True eigenvector: [-0.21791252 -0.24937926  0.28497735  0.3477344  -0.23354197  0.16291453
#   0.46063983  0.01773542  0.44018823  0.44815236]
# Cosine similarity: -0.9940
# Run 9
# True dominant eigenvalue: 8.240448434065268
# Epoch 0: Loss = 0.2837, Residual = 5.1796, Avg Reward = -10.1483, Cosine Similarity = 0.3682
# Epoch 100: Loss = 0.2131, Residual = 2.8557, Avg Reward = -9.9916, Cosine Similarity = 0.9423
# Epoch 200: Loss = 0.2342, Residual = 2.7723, Avg Reward = -9.6084, Cosine Similarity = 0.9278
# Epoch 300: Loss = 0.1225, Residual = 2.4414, Avg Reward = -7.9963, Cosine Similarity = 0.9705
# Epoch 400: Loss = 0.1009, Residual = 1.4385, Avg Reward = -6.7061, Cosine Similarity = 0.9758
# Epoch 500: Loss = 0.1169, Residual = 1.4385, Avg Reward = -6.6045, Cosine Similarity = 0.9758
# Epoch 600: Loss = 0.1245, Residual = 1.1321, Avg Reward = -4.6332, Cosine Similarity = 0.9851
# Epoch 700: Loss = 0.1218, Residual = 1.0576, Avg Reward = -4.0615, Cosine Similarity = 0.9710
# Epoch 800: Loss = 0.1313, Residual = 1.0576, Avg Reward = -4.4837, Cosine Similarity = 0.9710
# Epoch 900: Loss = 0.1459, Residual = 1.0437, Avg Reward = -2.9326, Cosine Similarity = 0.9622
# Epoch 1000: Loss = 0.1400, Residual = 1.0437, Avg Reward = -2.7879, Cosine Similarity = 0.9622
#
# Predicted eigenvector: [ 0.19112499 -0.13812125  0.10509109 -0.16401914  0.22113666  0.42342368
#   0.40390775 -0.5642562  -0.15303749 -0.41630676]
# True eigenvector: [ 0.05422744 -0.22859356 -0.01185723 -0.11884877  0.06774662  0.5118638
#   0.40444684 -0.55059856 -0.11670606 -0.42847198]
# Cosine similarity: 0.9622
# Run 10
# True dominant eigenvalue: -7.395387006126591
# Epoch 0: Loss = -0.1549, Residual = 4.7856, Avg Reward = -7.9277, Cosine Similarity = 0.6425
# Epoch 100: Loss = -0.0367, Residual = 2.1261, Avg Reward = -7.6858, Cosine Similarity = 0.8443
# Epoch 200: Loss = 0.1188, Residual = 1.7941, Avg Reward = -6.4058, Cosine Similarity = 0.9505
# Epoch 300: Loss = 0.1309, Residual = 1.4929, Avg Reward = -4.9273, Cosine Similarity = 0.9487
# Epoch 400: Loss = 0.0504, Residual = 1.0765, Avg Reward = -4.1671, Cosine Similarity = 0.9533
# Epoch 500: Loss = 0.1165, Residual = 0.9623, Avg Reward = -3.9344, Cosine Similarity = 0.9581
# Epoch 600: Loss = 0.1464, Residual = 0.8117, Avg Reward = -3.2810, Cosine Similarity = 0.9919
# Epoch 700: Loss = 0.1138, Residual = 0.5629, Avg Reward = -2.9449, Cosine Similarity = 0.9880
# Epoch 800: Loss = 0.1321, Residual = 0.5594, Avg Reward = -2.0535, Cosine Similarity = 0.9908
# Epoch 900: Loss = 0.1364, Residual = 0.5594, Avg Reward = -2.3652, Cosine Similarity = 0.9908
# Epoch 1000: Loss = 0.1409, Residual = 0.5594, Avg Reward = -2.1556, Cosine Similarity = 0.9908
#
# Predicted eigenvector: [ 0.44985795  0.12153088  0.3763098   0.07662943 -0.2771297   0.25954655
#  -0.5020824   0.0359004   0.27463734  0.4030017 ]
# True eigenvector: [ 0.34995022  0.16684422  0.40914977  0.07380318 -0.3142897   0.2887332
#  -0.48319787  0.06281183  0.25158507  0.44043386]
# Cosine similarity: 0.9908
#
# Testing with dimension: 20
# Run 1
# True dominant eigenvalue: 11.490195949474074
# Epoch 0: Loss = 0.0179, Residual = 8.0073, Avg Reward = -12.3031, Cosine Similarity = 0.0115
# Epoch 100: Loss = -0.0106, Residual = 6.7062, Avg Reward = -12.2747, Cosine Similarity = 0.2463
# Epoch 200: Loss = -0.0239, Residual = 5.6973, Avg Reward = -10.5596, Cosine Similarity = 0.7595
# Epoch 300: Loss = -0.0335, Residual = 4.9232, Avg Reward = -11.0178, Cosine Similarity = 0.4964
# Epoch 400: Loss = -0.0411, Residual = 3.6854, Avg Reward = -7.7072, Cosine Similarity = 0.7990
# Epoch 500: Loss = -0.0198, Residual = 3.3043, Avg Reward = -7.1982, Cosine Similarity = 0.8703
# Epoch 600: Loss = -0.0120, Residual = 3.3043, Avg Reward = -6.3262, Cosine Similarity = 0.8703
# Epoch 700: Loss = -0.0132, Residual = 2.8635, Avg Reward = -5.3968, Cosine Similarity = 0.8883
# Epoch 800: Loss = 0.0024, Residual = 2.5448, Avg Reward = -5.0874, Cosine Similarity = 0.8989
# Epoch 900: Loss = 0.0116, Residual = 2.4010, Avg Reward = -4.5874, Cosine Similarity = 0.9314
# Epoch 1000: Loss = 0.0255, Residual = 1.9109, Avg Reward = -4.2234, Cosine Similarity = 0.9346
#
# Predicted eigenvector: [-0.04977016 -0.28052968 -0.02699092  0.11318827  0.44054276  0.26237532
#   0.05913732 -0.03485481 -0.15426841 -0.26825666 -0.10033835  0.27202258
#  -0.21418916 -0.25970063 -0.2043186  -0.01884825  0.1269749   0.3532109
#   0.20708746 -0.34444484]
# True eigenvector: [-0.06859624 -0.19185267 -0.10323457  0.1318007   0.44020662  0.25048268
#   0.09229723 -0.09966459 -0.08979492 -0.26653942  0.09465805  0.22583953
#  -0.16780162 -0.3727772  -0.18681331 -0.05963164  0.15969592  0.4845374
#   0.12142548 -0.18924655]
# Cosine similarity: 0.9346
# Run 2
# True dominant eigenvalue: 11.035472091825067
# Epoch 0: Loss = 0.0172, Residual = 8.7051, Avg Reward = -11.6481, Cosine Similarity = 0.1136
# Epoch 100: Loss = -0.0416, Residual = 6.4167, Avg Reward = -13.4911, Cosine Similarity = -0.0701
# Epoch 200: Loss = 0.0158, Residual = 5.7686, Avg Reward = -12.9010, Cosine Similarity = -0.8826
# Epoch 300: Loss = -0.0412, Residual = 5.2410, Avg Reward = -11.5767, Cosine Similarity = -0.5747
# Epoch 400: Loss = -0.0265, Residual = 4.8923, Avg Reward = -9.7674, Cosine Similarity = -0.7127
# Epoch 500: Loss = -0.0252, Residual = 4.4683, Avg Reward = -9.3119, Cosine Similarity = -0.7532
# Epoch 600: Loss = -0.0215, Residual = 4.2634, Avg Reward = -8.1761, Cosine Similarity = -0.6847
# Epoch 700: Loss = -0.0674, Residual = 3.0073, Avg Reward = -7.0171, Cosine Similarity = -0.7191
# Epoch 800: Loss = -0.0043, Residual = 3.0073, Avg Reward = -6.1779, Cosine Similarity = -0.7191
# Epoch 900: Loss = 0.0060, Residual = 2.6816, Avg Reward = -5.2853, Cosine Similarity = -0.6517
# Epoch 1000: Loss = 0.0335, Residual = 2.2796, Avg Reward = -4.4752, Cosine Similarity = -0.7483
#
# Predicted eigenvector: [-0.15560926 -0.01467896  0.04201498  0.17787051  0.16304757  0.2535698
#  -0.18084233  0.0789624   0.42897797  0.10666279 -0.32369852  0.21808401
#  -0.32156512 -0.08827168 -0.11295055  0.0421436   0.18709986 -0.34964404
#  -0.16607264  0.392477  ]
# True eigenvector: [-0.09704614  0.29495296 -0.04416271 -0.22240607 -0.33067793  0.08552703
#   0.40396002 -0.13860959 -0.24639837 -0.06172914  0.24066873 -0.0769943
#   0.2785815   0.04500356  0.14998633  0.0599585   0.07681632  0.25084996
#   0.19211327 -0.4618234 ]
# Cosine similarity: -0.7483
# Run 3
# True dominant eigenvalue: 12.505759019226463
# Epoch 0: Loss = -0.1146, Residual = 10.9420, Avg Reward = -13.5476, Cosine Similarity = -0.2676
# Epoch 100: Loss = -0.0401, Residual = 6.8193, Avg Reward = -13.8699, Cosine Similarity = 0.8414
# Epoch 200: Loss = -0.0488, Residual = 6.7618, Avg Reward = -14.2303, Cosine Similarity = 0.7641
# Epoch 300: Loss = -0.0088, Residual = 5.7121, Avg Reward = -11.4064, Cosine Similarity = 0.8445
# Epoch 400: Loss = -0.0087, Residual = 4.5237, Avg Reward = -10.7261, Cosine Similarity = 0.8528
# Epoch 500: Loss = -0.0318, Residual = 4.0912, Avg Reward = -8.1483, Cosine Similarity = 0.9358
# Epoch 600: Loss = -0.0082, Residual = 3.6399, Avg Reward = -7.5967, Cosine Similarity = 0.9479
# Epoch 700: Loss = 0.0038, Residual = 2.9730, Avg Reward = -6.4762, Cosine Similarity = 0.9700
# Epoch 800: Loss = 0.0039, Residual = 2.5663, Avg Reward = -5.6551, Cosine Similarity = 0.9785
# Epoch 900: Loss = 0.0117, Residual = 2.4485, Avg Reward = -4.8000, Cosine Similarity = 0.9703
# Epoch 1000: Loss = 0.0205, Residual = 2.1578, Avg Reward = -4.3533, Cosine Similarity = 0.9703
#
# Predicted eigenvector: [ 0.1776718   0.07994545  0.0428722  -0.17836513  0.19996755  0.11060867
#  -0.27277693 -0.04532059  0.3529521  -0.10351049 -0.02054084  0.23895872
#  -0.0810368  -0.4854225  -0.24504939  0.21023479 -0.16368449 -0.18720913
#  -0.09532196 -0.43533662]
# True eigenvector: [ 0.16883518  0.10264511 -0.00889968 -0.23428737  0.17645162  0.13331024
#  -0.21258423 -0.06614072  0.33956173 -0.02976966  0.03476127  0.19355161
#  -0.11751878 -0.5435716  -0.16807018  0.30024952 -0.21480244 -0.18879475
#   0.01629082 -0.3780601 ]
# Cosine similarity: 0.9703
# Run 4
# True dominant eigenvalue: 11.882355561465772
# Epoch 0: Loss = -0.1152, Residual = 9.2818, Avg Reward = -13.6811, Cosine Similarity = -0.4506
# Epoch 100: Loss = -0.0499, Residual = 7.3049, Avg Reward = -13.7663, Cosine Similarity = -0.0325
# Epoch 200: Loss = 0.0234, Residual = 6.8995, Avg Reward = -12.5977, Cosine Similarity = 0.7533
# Epoch 300: Loss = 0.0100, Residual = 5.4324, Avg Reward = -12.8123, Cosine Similarity = -0.0585
# Epoch 400: Loss = -0.0260, Residual = 4.7764, Avg Reward = -10.7347, Cosine Similarity = 0.0819
# Epoch 500: Loss = -0.0247, Residual = 4.3480, Avg Reward = -8.9290, Cosine Similarity = 0.2393
# Epoch 600: Loss = 0.0029, Residual = 4.0472, Avg Reward = -8.5946, Cosine Similarity = 0.2304
# Epoch 700: Loss = 0.0172, Residual = 3.4044, Avg Reward = -7.3342, Cosine Similarity = -0.0148
# Epoch 800: Loss = -0.0036, Residual = 3.3911, Avg Reward = -6.2440, Cosine Similarity = 0.1176
# Epoch 900: Loss = 0.0046, Residual = 3.0343, Avg Reward = -6.1207, Cosine Similarity = 0.1549
# Epoch 1000: Loss = 0.0077, Residual = 2.9501, Avg Reward = -5.1653, Cosine Similarity = 0.0393
#
# Predicted eigenvector: [ 0.11832594 -0.07542943 -0.33233473  0.07809422 -0.08550111 -0.42202413
#  -0.0998091   0.02368766 -0.50978976 -0.03260955 -0.2236017  -0.08152409
#  -0.17974663 -0.1621545  -0.10482958  0.39894983  0.14584026 -0.09722514
#   0.15643495 -0.2574616 ]
# True eigenvector: [ 0.35677934  0.0657344  -0.15971698 -0.14795308  0.3256898  -0.24032356
#   0.19936034  0.12216415 -0.14591217 -0.03805125  0.41583797  0.10233267
#  -0.16631624  0.18368432  0.35244298 -0.10519947 -0.24739678  0.24692026
#  -0.01906189 -0.27773437]
# Cosine similarity: 0.0393
# Run 5
# True dominant eigenvalue: 9.884819759367725
# Epoch 0: Loss = -0.1722, Residual = 7.9614, Avg Reward = -11.5711, Cosine Similarity = 0.1356
# Epoch 100: Loss = -0.0362, Residual = 6.4942, Avg Reward = -12.4247, Cosine Similarity = -0.5538
# Epoch 200: Loss = -0.0357, Residual = 5.5168, Avg Reward = -12.5345, Cosine Similarity = 0.7545
# Epoch 300: Loss = -0.0056, Residual = 4.7704, Avg Reward = -11.2291, Cosine Similarity = 0.8861
# Epoch 400: Loss = -0.0389, Residual = 4.1814, Avg Reward = -10.0176, Cosine Similarity = 0.8209
# Epoch 500: Loss = -0.0278, Residual = 4.1814, Avg Reward = -8.8885, Cosine Similarity = 0.8209
# Epoch 600: Loss = -0.0442, Residual = 2.9906, Avg Reward = -8.0292, Cosine Similarity = 0.9152
# Epoch 700: Loss = -0.0376, Residual = 2.7442, Avg Reward = -6.7711, Cosine Similarity = 0.9201
# Epoch 800: Loss = -0.0136, Residual = 2.1290, Avg Reward = -5.9068, Cosine Similarity = 0.9064
# Epoch 900: Loss = -0.0024, Residual = 2.1290, Avg Reward = -4.7714, Cosine Similarity = 0.9064
# Epoch 1000: Loss = 0.0163, Residual = 2.0393, Avg Reward = -4.6299, Cosine Similarity = 0.9419
#
# Predicted eigenvector: [-0.13073485  0.06674756  0.17469953  0.16726033 -0.14065035 -0.19387427
#   0.09089101  0.10604999  0.02266421  0.2172988   0.09383889 -0.44286782
#  -0.18844594  0.09253414 -0.33832595 -0.3220343  -0.05881889  0.15416373
#  -0.5474941   0.03447798]
# True eigenvector: [-0.08835685  0.04645693  0.19601944  0.25124493 -0.31615362 -0.00437807
#   0.11963274  0.03327126 -0.01503365  0.21174106  0.040031   -0.34741828
#  -0.13351724  0.11018667 -0.29610476 -0.2990158  -0.10809008  0.08465431
#  -0.61606586 -0.01703963]
# Cosine similarity: 0.9419
# Run 6
# True dominant eigenvalue: 11.012346456980985
# Epoch 0: Loss = -0.1413, Residual = 8.9623, Avg Reward = -12.3544, Cosine Similarity = -0.5612
# Epoch 100: Loss = -0.0266, Residual = 6.3148, Avg Reward = -12.3407, Cosine Similarity = 0.0051
# Epoch 200: Loss = -0.0391, Residual = 5.8010, Avg Reward = -11.4319, Cosine Similarity = 0.2356
# Epoch 300: Loss = -0.0311, Residual = 5.5621, Avg Reward = -10.0311, Cosine Similarity = 0.0192
# Epoch 400: Loss = 0.0196, Residual = 4.8221, Avg Reward = -8.8473, Cosine Similarity = 0.1747
# Epoch 500: Loss = -0.0388, Residual = 4.2333, Avg Reward = -7.6539, Cosine Similarity = 0.1235
# Epoch 600: Loss = -0.0454, Residual = 3.5361, Avg Reward = -5.8641, Cosine Similarity = 0.1595
# Epoch 700: Loss = -0.0043, Residual = 3.5141, Avg Reward = -5.8774, Cosine Similarity = 0.1603
# Epoch 800: Loss = 0.0225, Residual = 3.3655, Avg Reward = -5.2608, Cosine Similarity = 0.1540
# Epoch 900: Loss = 0.0090, Residual = 3.3549, Avg Reward = -4.9369, Cosine Similarity = 0.0124
# Epoch 1000: Loss = 0.0161, Residual = 2.9795, Avg Reward = -4.1944, Cosine Similarity = 0.0937
#
# Predicted eigenvector: [ 0.31487414  0.28005823  0.09203915  0.29521585  0.09994049  0.01749175
#   0.31281683  0.3382331  -0.27831626  0.16451146 -0.25314498  0.12218952
#   0.09311751 -0.09101988  0.21812603 -0.17164911  0.29607865  0.34378988
#  -0.02980965  0.1413185 ]
# True eigenvector: [ 0.26420394 -0.11741965 -0.35264823  0.55871797  0.02026445  0.30701652
#  -0.01682849  0.16584176 -0.15524144 -0.03584477  0.30887982 -0.12481336
#   0.25492117 -0.07534306 -0.1100603   0.28014466 -0.21787561  0.02625781
#   0.08954903  0.06018354]
# Cosine similarity: 0.0937
# Run 7
# True dominant eigenvalue: -12.899819199499538
# Epoch 0: Loss = -0.0142, Residual = 10.4768, Avg Reward = -13.8970, Cosine Similarity = -0.5356
# Epoch 100: Loss = -0.0392, Residual = 6.2801, Avg Reward = -13.7870, Cosine Similarity = 0.7083
# Epoch 200: Loss = -0.0345, Residual = 5.9478, Avg Reward = -11.9560, Cosine Similarity = 0.4978
# Epoch 300: Loss = -0.0039, Residual = 5.6582, Avg Reward = -10.4445, Cosine Similarity = 0.8482
# Epoch 400: Loss = -0.0697, Residual = 4.0668, Avg Reward = -9.3712, Cosine Similarity = 0.5887
# Epoch 500: Loss = 0.0009, Residual = 3.4625, Avg Reward = -7.1384, Cosine Similarity = 0.7247
# Epoch 600: Loss = -0.0091, Residual = 3.4625, Avg Reward = -6.1688, Cosine Similarity = 0.7247
# Epoch 700: Loss = -0.0015, Residual = 3.3235, Avg Reward = -5.3005, Cosine Similarity = 0.7919
# Epoch 800: Loss = 0.0067, Residual = 3.0589, Avg Reward = -5.2098, Cosine Similarity = 0.7388
# Epoch 900: Loss = 0.0132, Residual = 2.6841, Avg Reward = -4.4557, Cosine Similarity = 0.8228
# Epoch 1000: Loss = 0.0050, Residual = 2.3627, Avg Reward = -4.2179, Cosine Similarity = 0.8572
#
# Predicted eigenvector: [-0.28762868 -0.2634089   0.12365891 -0.03867052 -0.05630176  0.1023264
#   0.3097369  -0.21760131  0.22829108  0.3553529   0.2054731   0.01001603
#  -0.11332086  0.3435277  -0.31712234 -0.29262915  0.26850432  0.03606488
#  -0.2081761   0.1402674 ]
# True eigenvector: [-0.24226677 -0.17859727 -0.07681227 -0.02387888 -0.02069269 -0.08218313
#   0.2872356  -0.09026027  0.13862216  0.37080264  0.08341488  0.20407034
#  -0.22725946  0.36239347 -0.4266698  -0.3982538   0.14491518  0.15074275
#   0.02986622  0.17761672]
# Cosine similarity: 0.8572
# Run 8
# True dominant eigenvalue: -13.167006372250693
# Epoch 0: Loss = -0.1391, Residual = 8.4064, Avg Reward = -14.0798, Cosine Similarity = -0.6740
# Epoch 100: Loss = -0.0043, Residual = 7.4218, Avg Reward = -14.2729, Cosine Similarity = -0.4697
# Epoch 200: Loss = -0.0235, Residual = 6.2762, Avg Reward = -13.8699, Cosine Similarity = -0.1407
# Epoch 300: Loss = -0.0381, Residual = 5.5689, Avg Reward = -11.7839, Cosine Similarity = -0.2189
# Epoch 400: Loss = -0.0238, Residual = 4.8077, Avg Reward = -9.7435, Cosine Similarity = -0.2445
# Epoch 500: Loss = -0.0132, Residual = 4.4566, Avg Reward = -8.8707, Cosine Similarity = -0.1224
# Epoch 600: Loss = -0.0429, Residual = 3.6952, Avg Reward = -7.5983, Cosine Similarity = -0.3651
# Epoch 700: Loss = 0.0362, Residual = 3.6027, Avg Reward = -6.6835, Cosine Similarity = -0.2950
# Epoch 800: Loss = 0.0098, Residual = 3.0064, Avg Reward = -6.1341, Cosine Similarity = -0.4295
# Epoch 900: Loss = -0.0093, Residual = 2.9991, Avg Reward = -5.3920, Cosine Similarity = -0.3519
# Epoch 1000: Loss = 0.0294, Residual = 2.7373, Avg Reward = -4.9052, Cosine Similarity = -0.3919
#
# Predicted eigenvector: [ 0.2943352   0.1278909   0.24461648 -0.0290204   0.34547603  0.20993131
#  -0.17650971 -0.08357301 -0.11942033  0.00960364 -0.3436577   0.01966451
#  -0.33266133  0.117877   -0.11309104  0.20215861 -0.05529837  0.13875046
#  -0.48768675  0.25211382]
# True eigenvector: [-0.49341616 -0.46300173 -0.09825551 -0.21188985 -0.07673697  0.018369
#   0.11580603  0.13178943 -0.06098164  0.22247896 -0.2132791   0.27966434
#   0.24676272 -0.19576734  0.24618465 -0.15929854  0.03481398  0.23311542
#   0.17165743  0.05896203]
# Cosine similarity: -0.3919
# Run 9
# True dominant eigenvalue: 11.473359017795438
# Epoch 0: Loss = 0.1260, Residual = 9.8348, Avg Reward = -11.3002, Cosine Similarity = 0.1630
# Epoch 100: Loss = -0.0579, Residual = 6.9016, Avg Reward = -14.3135, Cosine Similarity = 0.4270
# Epoch 200: Loss = -0.0388, Residual = 5.9107, Avg Reward = -12.7800, Cosine Similarity = 0.4749
# Epoch 300: Loss = -0.0332, Residual = 5.2262, Avg Reward = -10.8618, Cosine Similarity = 0.4497
# Epoch 400: Loss = -0.0064, Residual = 4.8445, Avg Reward = -9.5616, Cosine Similarity = 0.3690
# Epoch 500: Loss = -0.0514, Residual = 4.5344, Avg Reward = -9.4917, Cosine Similarity = 0.4582
# Epoch 600: Loss = 0.0209, Residual = 3.8812, Avg Reward = -7.5144, Cosine Similarity = 0.5521
# Epoch 700: Loss = -0.0097, Residual = 3.2506, Avg Reward = -7.0072, Cosine Similarity = 0.3303
# Epoch 800: Loss = -0.0033, Residual = 2.8408, Avg Reward = -5.7128, Cosine Similarity = 0.3504
# Epoch 900: Loss = 0.0051, Residual = 2.5443, Avg Reward = -4.9314, Cosine Similarity = 0.1653
# Epoch 1000: Loss = 0.0191, Residual = 2.3282, Avg Reward = -4.7733, Cosine Similarity = 0.1289
#
# Predicted eigenvector: [-0.45436674 -0.05703377  0.00673482  0.16981576  0.25534505 -0.2840798
#   0.03701273 -0.20298463 -0.20574357  0.10795996  0.4230188  -0.20850383
#  -0.1477931   0.11136486 -0.07499571 -0.33081424 -0.01566196  0.00386523
#  -0.37530702  0.07818332]
# True eigenvector: [-3.0698988e-01  6.0473460e-01 -1.1325907e-01  3.4960562e-01
#  -9.5718987e-03  1.5089111e-01  4.2107649e-02 -5.9937770e-03
#  -2.5850630e-01  4.9100798e-02  4.0843487e-02  1.0893466e-01
#   6.4014107e-02 -2.4460782e-01 -5.6207553e-02  2.4648592e-01
#   6.6428889e-05 -2.2691553e-02 -2.5145811e-01 -3.2553038e-01]
# Cosine similarity: 0.1289
# Run 10
# True dominant eigenvalue: -13.320025877400441
# Epoch 0: Loss = -0.1954, Residual = 10.1410, Avg Reward = -14.0656, Cosine Similarity = -0.1382
# Epoch 100: Loss = -0.1563, Residual = 7.8879, Avg Reward = -14.2536, Cosine Similarity = -0.6668
# Epoch 200: Loss = -0.0116, Residual = 5.4346, Avg Reward = -13.3715, Cosine Similarity = -0.8255
# Epoch 300: Loss = -0.0305, Residual = 5.4346, Avg Reward = -10.8650, Cosine Similarity = -0.8255
# Epoch 400: Loss = -0.0428, Residual = 4.6868, Avg Reward = -9.4485, Cosine Similarity = -0.8379
# Epoch 500: Loss = -0.0452, Residual = 4.0307, Avg Reward = -8.3985, Cosine Similarity = -0.9279
# Epoch 600: Loss = 0.0201, Residual = 3.2335, Avg Reward = -6.8014, Cosine Similarity = -0.9596
# Epoch 700: Loss = -0.0028, Residual = 2.9443, Avg Reward = -5.7805, Cosine Similarity = -0.9493
# Epoch 800: Loss = 0.0023, Residual = 2.3444, Avg Reward = -5.5433, Cosine Similarity = -0.9796
# Epoch 900: Loss = 0.0283, Residual = 2.0981, Avg Reward = -5.1186, Cosine Similarity = -0.9882
# Epoch 1000: Loss = 0.0203, Residual = 1.8456, Avg Reward = -4.2998, Cosine Similarity = -0.9905
#
# Predicted eigenvector: [-0.04492909 -0.40333676 -0.20582089  0.15586774  0.2032077   0.31332156
#   0.04125524  0.11133811  0.12077878  0.23549229  0.15207371 -0.1822163
#   0.12724791 -0.03128126 -0.19008769 -0.41655344 -0.3271913  -0.11781143
#   0.30123192 -0.22408393]
# True eigenvector: [ 0.06877125  0.3955124   0.19034187 -0.20194493 -0.19604029 -0.3009547
#   0.02243339 -0.16990474 -0.12285822 -0.24982086 -0.16545044  0.18320224
#  -0.11366295 -0.00959464  0.13281937  0.44985524  0.2924276   0.12098448
#  -0.27907357  0.23228326]
# Cosine similarity: -0.9905
#
# Testing with dimension: 50
# Run 1
# True dominant eigenvalue: 19.887163912131836
# Epoch 0: Loss = -0.2739, Residual = 19.2356, Avg Reward = -21.5905, Cosine Similarity = 0.0347
# Epoch 100: Loss = -0.4303, Residual = 15.6242, Avg Reward = -23.6464, Cosine Similarity = 0.1153
# Epoch 200: Loss = -0.4710, Residual = 15.5429, Avg Reward = -21.7351, Cosine Similarity = -0.0005
# Epoch 300: Loss = -0.4787, Residual = 13.9099, Avg Reward = -21.5161, Cosine Similarity = 0.0722
# Epoch 400: Loss = -0.4346, Residual = 12.3255, Avg Reward = -19.5937, Cosine Similarity = 0.1302
# Epoch 500: Loss = -0.4437, Residual = 10.9887, Avg Reward = -16.0965, Cosine Similarity = 0.0097
# Epoch 600: Loss = -0.4310, Residual = 9.7233, Avg Reward = -13.7407, Cosine Similarity = 0.0110
# Epoch 700: Loss = -0.4412, Residual = 7.8707, Avg Reward = -11.8689, Cosine Similarity = 0.0517
# Epoch 800: Loss = -0.3724, Residual = 7.6228, Avg Reward = -10.4240, Cosine Similarity = 0.0200
# Epoch 900: Loss = -0.3951, Residual = 7.2598, Avg Reward = -9.5853, Cosine Similarity = 0.0451
# Epoch 1000: Loss = -0.3884, Residual = 6.6937, Avg Reward = -8.5028, Cosine Similarity = 0.0437
#
# Predicted eigenvector: [-0.1648054   0.17116609 -0.04755783 -0.16857688  0.03145958 -0.13440959
#   0.19052058  0.00849316 -0.23463619 -0.04017074  0.03380047  0.24455693
#  -0.03559418  0.2323459  -0.07023301 -0.12974432 -0.10108088  0.06384513
#  -0.08327577  0.03125058  0.08442984 -0.13892876 -0.0816671  -0.02004556
#  -0.06468375 -0.12617734  0.10872731 -0.06997435  0.18771611  0.02774983
#  -0.26434287  0.22703323 -0.26185277 -0.13051325 -0.15821385 -0.1148106
#   0.01839742  0.13509226  0.14842908 -0.16417433  0.09681278  0.16588183
#  -0.15584528 -0.20097807  0.10900567 -0.05126367  0.13236761  0.09067113
#  -0.11303597 -0.2585659 ]
# True eigenvector: [ 0.34843606  0.3133109   0.0849044  -0.11506805  0.00503259  0.0311044
#   0.10601819  0.10435387 -0.08361686  0.05787555 -0.01608496  0.10880349
#   0.02887538 -0.01405936  0.045565    0.0908351  -0.01625121 -0.12818816
#  -0.12587458  0.20343725  0.07694159  0.31596828 -0.14107928  0.15494962
#  -0.08102445  0.3259962   0.16896886  0.0622099  -0.00157255 -0.14878936
#  -0.11943162  0.02273676  0.17262945 -0.09287585 -0.0160022   0.02016694
#  -0.00403524 -0.1218551   0.28352842 -0.08275424  0.1273239   0.23302367
#   0.03765366  0.07580331 -0.20051263  0.08588151  0.04185592  0.11364258
#   0.11624812  0.05153077]
# Cosine similarity: 0.0437
# Run 2
# True dominant eigenvalue: 20.54603814882823
# Epoch 0: Loss = -0.4243, Residual = 16.5353, Avg Reward = -22.5335, Cosine Similarity = -0.0954
# Epoch 100: Loss = -0.4865, Residual = 15.3107, Avg Reward = -23.6404, Cosine Similarity = -0.1996
# Epoch 200: Loss = -0.4624, Residual = 15.3107, Avg Reward = -21.5093, Cosine Similarity = -0.1996
# Epoch 300: Loss = -0.4647, Residual = 14.8887, Avg Reward = -21.2394, Cosine Similarity = -0.2001
# Epoch 400: Loss = -0.4903, Residual = 11.9979, Avg Reward = -19.2564, Cosine Similarity = -0.3458
# Epoch 500: Loss = -0.4261, Residual = 11.0455, Avg Reward = -16.5731, Cosine Similarity = -0.3109
# Epoch 600: Loss = -0.4262, Residual = 9.9758, Avg Reward = -14.2917, Cosine Similarity = -0.3563
# Epoch 700: Loss = -0.4236, Residual = 9.7131, Avg Reward = -12.8207, Cosine Similarity = -0.2952
# Epoch 800: Loss = -0.4090, Residual = 8.2475, Avg Reward = -11.2484, Cosine Similarity = -0.3436
# Epoch 900: Loss = -0.3895, Residual = 8.0132, Avg Reward = -10.7978, Cosine Similarity = -0.2976
# Epoch 1000: Loss = -0.3735, Residual = 7.5954, Avg Reward = -9.5815, Cosine Similarity = -0.3746
#
# Predicted eigenvector: [ 0.27288792  0.06579624 -0.05830653 -0.16440928  0.00704402 -0.1520042
#  -0.02128222  0.04077292  0.01136031  0.12666786  0.09841479  0.03309208
#   0.1684035   0.04558512 -0.06195767  0.09098125  0.05755064  0.08302064
#   0.07880785 -0.26705492  0.09008874 -0.10843029 -0.23442777  0.01943292
#  -0.04793169 -0.26931155 -0.06555538 -0.10415681  0.18030639 -0.21217303
#   0.07367617  0.09681873  0.2925388  -0.08160676  0.22602521  0.12922321
#  -0.12341049  0.2100606   0.00826175 -0.04161764 -0.07338186  0.1018324
#   0.07665699  0.2100952  -0.2227473   0.04645578 -0.28969657 -0.1263986
#   0.10560492  0.03118157]
# True eigenvector: [-0.03796497 -0.09247781 -0.28254187  0.10904254  0.13585787  0.24298586
#   0.15781419 -0.0167605  -0.24618287 -0.13018203 -0.1238168  -0.04350783
#  -0.1899254  -0.11294153  0.22647217  0.04317176 -0.08844923 -0.22818516
# ...
#  -0.09235978 -0.13424464  0.02378739  0.14867562  0.03911933  0.18346266
#   0.04187929  0.00184874  0.26445767 -0.08750162 -0.06795858 -0.00630176
#   0.13115965  0.09671634  0.08008165 -0.08191194  0.03536195  0.2215886
#   0.10493915  0.0705378  -0.05921178 -0.12869412  0.11423632  0.12770347
#   0.02113563 -0.00536632  0.04785572  0.07398796  0.10830285 -0.03926224
#   0.07184345 -0.09826846  0.09849105 -0.07309603  0.01476509 -0.07654323
#  -0.00815113 -0.03660257 -0.0032388  -0.11315749  0.06545604  0.06474748
#  -0.06159362  0.05320599  0.0205181   0.09895678 -0.00248598  0.05924547
#  -0.1461339   0.03116994 -0.16156234 -0.05486503]
# Cosine similarity: -0.5723
# Run 7
# True dominant eigenvalue: 27.843854258268763
# Epoch 0: Loss = -1.1066, Residual = 27.4085, Avg Reward = -29.2651, Cosine Similarity = -0.1362
# Epoch 100: Loss = -1.1386, Residual = 24.5299, Avg Reward = -32.6868, Cosine Similarity = 0.0259
# Epoch 200: Loss = -1.1792, Residual = 24.1977, Avg Reward = -31.6368, Cosine Similarity = -0.0685
# Epoch 300: Loss = -1.1703, Residual = 22.3459, Avg Reward = -30.4859, Cosine Similarity = 0.1898
# Epoch 400: Loss = -1.1706, Residual = 21.1689, Avg Reward = -29.8348, Cosine Similarity = -0.2016
# Epoch 500: Loss = -1.1200, Residual = 18.3306, Avg Reward = -29.0239, Cosine Similarity = -0.0014
# Epoch 600: Loss = -1.1239, Residual = 17.6067, Avg Reward = -25.4870, Cosine Similarity = -0.0055
# Epoch 700: Loss = -1.1197, Residual = 15.7464, Avg Reward = -21.5493, Cosine Similarity = -0.1242
# Epoch 800: Loss = -1.1414, Residual = 14.2130, Avg Reward = -17.7494, Cosine Similarity = -0.0251
# Epoch 900: Loss = -1.1463, Residual = 12.2118, Avg Reward = -16.0661, Cosine Similarity = -0.0429
# Epoch 1000: Loss = -1.1153, Residual = 11.2461, Avg Reward = -14.4541, Cosine Similarity = 0.0011
#
# Predicted eigenvector: [ 1.13576893e-02 -1.06895089e-01  1.19309954e-01  6.38739541e-02
#  -8.31196085e-02  1.78873956e-01 -9.75487456e-02  7.27906004e-02
#  -4.07573320e-02  7.55410716e-02  1.45896338e-02 -4.46460024e-02
#  -3.09288017e-02  5.33289798e-02 -7.34166130e-02  8.30528792e-03
#   1.43270537e-01  5.10025302e-06 -6.37526661e-02 -7.55618662e-02
#   7.52823502e-02  6.80519566e-02  4.51600850e-02  9.84226018e-02
#  -6.40512034e-02  2.60599013e-02  2.07157627e-01  3.31456810e-02
#  -2.70078510e-01  1.76451594e-01 -5.91739565e-02  4.14108671e-03
#   4.88936231e-02  6.29835725e-02  9.47011560e-02  1.16064645e-01
#  -6.48573786e-02  2.01112069e-02  7.35673457e-02  5.19973449e-02
#  -2.95184553e-02 -1.07435800e-01  4.50981781e-02  7.13279992e-02
#   1.94468305e-01 -1.87998172e-02  3.95564288e-02 -5.79690300e-02
#  -7.64332190e-02 -9.57742706e-02 -1.82307690e-01  1.07518919e-01
#   1.25917450e-01 -4.21514437e-02 -1.24275424e-02 -1.19936608e-01
#   8.24343711e-02 -3.72913741e-02  2.48922799e-02  2.24122658e-01
#   1.38394833e-01  3.35518792e-02 -5.73930964e-02  1.04584612e-01
#  -2.11640801e-02  5.17454408e-02 -9.77690797e-03 -6.16205484e-02
#  -1.09737724e-01 -4.58783321e-02  8.48654192e-03 -1.58389747e-01
#  -1.24450304e-01  5.48916496e-02  5.51606119e-02  7.08189905e-02
#  -2.81022023e-02  1.30470186e-01  8.22039247e-02 -2.54464131e-02
#   6.34064302e-02  2.05186293e-01 -1.19336471e-02 -1.12462603e-01
#   1.70990244e-01  7.93378353e-02 -4.40808721e-02  6.48301467e-02
#   8.17507207e-02 -1.18182018e-01  2.21500382e-01 -4.61232327e-02
#  -1.57856867e-01 -5.08125946e-02 -1.38999060e-01 -1.06018931e-01
#  -7.97337517e-02 -7.63919801e-02  2.40110219e-01 -2.71513965e-02]
# True eigenvector: [ 0.15987764 -0.03364804 -0.1153761   0.06231187 -0.08834791 -0.04454467
#  -0.00996417  0.06645215 -0.04995843 -0.04658272  0.11933131 -0.28032652
#   0.02102903  0.10361496  0.18938586 -0.05153734 -0.03258989  0.04454701
#   0.1861068  -0.13461047 -0.00386868  0.1054326  -0.09597392  0.16196
#  -0.00634467 -0.18167746 -0.07915491 -0.01880143 -0.06707706 -0.2873184
#   0.1231507  -0.00791473  0.0367601   0.00039782 -0.06463279 -0.00990929
#   0.01723705 -0.05074674 -0.04979831 -0.20292138  0.07009786  0.18743163
#   0.1299222   0.03784873 -0.06899164  0.03546434 -0.0210268  -0.03013176
#  -0.00615199 -0.0598161  -0.13103384 -0.10414527  0.16626586 -0.05021178
#   0.10730426  0.07688662 -0.12399302 -0.08262249  0.16777994  0.01370926
#  -0.16297592  0.08028776 -0.05359032  0.05986445  0.09265315  0.00145059
#  -0.12501778  0.09416654  0.0886843  -0.07386252 -0.10243279 -0.02853977
#   0.0664634  -0.11856002 -0.17164126  0.01519687 -0.17651118  0.02915531
#   0.05479679  0.02957357  0.02072947  0.0991372  -0.02490409 -0.08321245
#   0.17294309  0.07389174  0.11965843 -0.01705934  0.05514412 -0.00290092
#   0.0589666   0.03846123 -0.05067039  0.02379928  0.01481671 -0.02253863
#   0.06275387  0.05556276  0.05990076 -0.17654891]
# Cosine similarity: 0.0011
# Run 8
# True dominant eigenvalue: -28.480989876485665
# Epoch 0: Loss = -1.0348, Residual = 27.8060, Avg Reward = -29.8126, Cosine Similarity = -0.0771
# Epoch 100: Loss = -1.1610, Residual = 25.9350, Avg Reward = -33.0709, Cosine Similarity = 0.0867
# Epoch 200: Loss = -1.1780, Residual = 25.8178, Avg Reward = -31.8967, Cosine Similarity = 0.0346
# Epoch 300: Loss = -1.1613, Residual = 24.4305, Avg Reward = -32.4847, Cosine Similarity = -0.2181
# Epoch 400: Loss = -1.1800, Residual = 24.4305, Avg Reward = -31.0242, Cosine Similarity = -0.2181
# Epoch 500: Loss = -1.2435, Residual = 22.4109, Avg Reward = -31.1228, Cosine Similarity = -0.2385
# Epoch 600: Loss = -1.1721, Residual = 21.8538, Avg Reward = -28.4941, Cosine Similarity = -0.2354
# Epoch 700: Loss = -1.1470, Residual = 21.2997, Avg Reward = -26.7428, Cosine Similarity = -0.1550
# Epoch 800: Loss = -1.1723, Residual = 17.3161, Avg Reward = -23.1584, Cosine Similarity = -0.2603
# Epoch 900: Loss = -1.1934, Residual = 15.2718, Avg Reward = -20.2741, Cosine Similarity = -0.2637
# Epoch 1000: Loss = -1.1163, Residual = 12.9209, Avg Reward = -17.2924, Cosine Similarity = -0.2544
#
# Predicted eigenvector: [-5.44782728e-02  1.19112723e-01 -8.14603865e-02  1.85555741e-01
#  -1.02909945e-01  6.35621771e-02 -7.52010420e-02 -3.19017209e-02
#   1.06470808e-01  1.05271004e-01  1.69272423e-02  1.24367215e-02
#   3.18868994e-03 -2.14417931e-02  1.25134349e-01  3.74528952e-02
#   1.21573135e-02 -4.06330153e-02 -1.34125859e-01 -7.48753473e-02
#   1.09386258e-01  1.43722802e-01 -1.33144915e-01  1.64458334e-01
#   6.54290104e-03  4.07738835e-02  1.11529909e-01  2.02764705e-01
#   4.42866758e-02  1.51558474e-01 -4.06262986e-02  9.90452990e-02
#   8.12798068e-02 -6.48179650e-02  6.94971904e-02 -6.98875636e-02
#  -6.37749135e-02  4.69988249e-02 -8.34715366e-02  2.30541676e-01
#   3.52745317e-02 -1.18485101e-01  7.02362433e-02 -8.04288536e-02
#  -1.30357862e-01  5.35790659e-02 -1.79931909e-01 -9.65253413e-02
#   7.21018538e-02  5.80715090e-02 -1.29070431e-01 -2.14465447e-02
#   5.55142909e-02  1.00461347e-02 -1.79918446e-02  6.23272173e-02
#   2.43848950e-01 -9.28188264e-02 -2.18413351e-03  3.38157453e-02
#   4.28047031e-02  3.10191866e-02 -3.27754617e-02 -1.99895874e-02
#   1.33822873e-01  1.50127202e-01 -9.19311028e-03  5.18476218e-03
#  -1.23042688e-01  8.11039936e-03 -1.36835784e-01  3.54194245e-03
#   1.91909879e-01  5.25605306e-02  2.14362293e-02  1.22333914e-01
#  -1.00111693e-01 -1.52804898e-02 -3.03680692e-02  2.05618039e-01
#   2.08078548e-01  1.77433848e-01 -3.08233928e-02  5.32188416e-02
#  -1.82221439e-02 -1.19016394e-01 -3.69275212e-02  1.17052637e-01
#   9.45081860e-02  6.36039898e-02 -3.34390425e-05 -9.38196108e-02
#   1.08075954e-01  2.11992308e-01  7.80259222e-02 -3.13324668e-02
#   9.32626892e-03 -1.13198943e-01 -5.87543771e-02 -1.04836263e-01]
# True eigenvector: [-0.05282043  0.09646948  0.23031904 -0.0769891   0.16750944 -0.03962605
#   0.11468983 -0.15694422 -0.1216868  -0.05319951  0.05213238  0.26716247
#  -0.20201392  0.26101315  0.01121546 -0.10176772 -0.04890602 -0.0950703
#  -0.02051412  0.18103676 -0.07688042 -0.15939502  0.04430771 -0.03502794
#  -0.04789036 -0.04117807 -0.08975136 -0.14825821 -0.08733115 -0.13233793
#  -0.01586112 -0.04486378 -0.10790102 -0.0584507  -0.07189481 -0.02385153
#   0.11716486  0.17728163  0.1465882   0.00321197  0.17226695  0.10095288
#   0.02091723 -0.11862855  0.03201112 -0.06618097 -0.00466728 -0.11476507
#   0.06456922  0.03701206  0.08306717 -0.04224221 -0.04811637 -0.03320195
#  -0.12474403 -0.10204606 -0.19380596  0.04614166 -0.00630149 -0.04777568
#   0.17171818  0.05697887  0.15686595 -0.11675201 -0.00582517 -0.04824197
#  -0.07288352 -0.15454626 -0.10780021  0.16116643 -0.05141627  0.01164302
#  -0.01448351 -0.02093711 -0.01481189  0.00525646 -0.10163608 -0.03403235
#   0.04830818  0.01048671  0.06316704 -0.00820679  0.05403441 -0.05573766
#   0.00034005 -0.0027862   0.06425867 -0.05856936  0.03185277  0.09938449
#  -0.07656229  0.03790038 -0.09111107 -0.12921236  0.17235984 -0.05368016
#  -0.04849753 -0.03350715  0.08833165  0.03620029]
# Cosine similarity: -0.2544
# Run 9
# True dominant eigenvalue: 28.307893790800144
# Epoch 0: Loss = -1.0334, Residual = 27.7368, Avg Reward = -30.5096, Cosine Similarity = 0.1634
# Epoch 100: Loss = -1.1741, Residual = 24.4981, Avg Reward = -32.5875, Cosine Similarity = 0.0016
# Epoch 200: Loss = -1.1923, Residual = 24.0635, Avg Reward = -31.6920, Cosine Similarity = -0.3290
# Epoch 300: Loss = -1.1695, Residual = 22.3731, Avg Reward = -32.3739, Cosine Similarity = -0.1662
# Epoch 400: Loss = -1.1995, Residual = 22.0897, Avg Reward = -28.7915, Cosine Similarity = -0.1503
# Epoch 500: Loss = -1.1484, Residual = 20.3483, Avg Reward = -26.3661, Cosine Similarity = -0.2187
# Epoch 600: Loss = -1.1156, Residual = 17.5028, Avg Reward = -23.8314, Cosine Similarity = -0.2608
# Epoch 700: Loss = -1.0965, Residual = 15.6267, Avg Reward = -20.7149, Cosine Similarity = -0.2591
# Epoch 800: Loss = -1.1359, Residual = 13.8828, Avg Reward = -17.3351, Cosine Similarity = -0.3847
# Epoch 900: Loss = -1.1148, Residual = 12.4783, Avg Reward = -16.4031, Cosine Similarity = -0.3360
# Epoch 1000: Loss = -1.0588, Residual = 11.1301, Avg Reward = -14.1632, Cosine Similarity = -0.3199
#
# Predicted eigenvector: [ 0.06870461  0.09634425  0.06803604  0.19017127  0.03271125 -0.1955672
#   0.09053876  0.0117096  -0.00768393  0.12217381 -0.04816353  0.02655179
#  -0.15844999  0.07957796 -0.07359237 -0.13096894 -0.0015749  -0.09835748
#  -0.03776329 -0.02296116 -0.06840141  0.05523459  0.06132289 -0.2356764
#  -0.11114632  0.15208995 -0.06740275 -0.02319097 -0.15035081  0.08464549
#   0.14313793  0.07100054  0.04765216 -0.09955681 -0.10266662 -0.09506633
#  -0.0295573  -0.06262315 -0.04930674  0.06369735 -0.10920285 -0.16490284
#  -0.06289047  0.02721369 -0.01931805  0.03826902 -0.09510691 -0.00825259
#   0.02302068 -0.16290018 -0.11051371  0.1938256   0.06153629  0.04374658
#   0.06184953  0.11645744  0.00724559 -0.15181147 -0.21964142  0.15614264
#  -0.01731451 -0.13758059 -0.03424652 -0.05115113 -0.14013927  0.00552738
#  -0.16669334 -0.07220204 -0.13054942 -0.14638737  0.1150867  -0.12522595
#   0.19820517 -0.00680103 -0.0251514   0.03203695 -0.10335498 -0.01269844
#   0.02336628  0.11356484  0.06882919 -0.14984094 -0.09562936  0.08303452
#   0.06025438  0.03768043 -0.03941157  0.06116058  0.05059157  0.17579268
#  -0.02116455  0.01859869  0.14209487 -0.13429134  0.06411447 -0.04304657
#  -0.04911591  0.09670997 -0.06527547  0.033618  ]
# True eigenvector: [-0.1148375  -0.06537043  0.20371948 -0.04946622  0.04388319  0.11715472
#  -0.11543426 -0.09506719  0.03974429 -0.1517601   0.02222073 -0.07028905
#   0.12861522  0.04659176  0.00690177  0.07750202  0.1362205  -0.06299398
#   0.01003829  0.03957194 -0.2995522  -0.13011149 -0.17193486  0.07942934
#   0.02046983  0.03123716  0.02088221  0.04826519  0.01442747 -0.0949401
#  -0.10948943 -0.00678582  0.02378882 -0.02214616 -0.11053353 -0.12958145
#   0.04778422  0.02602614  0.06229774 -0.12881647  0.19399141 -0.04414843
#  -0.11527371 -0.00577791 -0.07256262 -0.05255684  0.11447188 -0.07725424
#  -0.01446358 -0.02655969  0.08530756  0.01527303 -0.1980086  -0.06087034
#  -0.03830852  0.01242508 -0.02091851  0.08761916  0.08144313 -0.19979472
#  -0.09284834  0.00198404  0.04742135  0.23244005  0.01560824 -0.07503178
#   0.10288995 -0.11094943 -0.18422993  0.06059761 -0.05160727 -0.04812954
#  -0.19756818  0.10234445  0.07843439 -0.06146919  0.02137901  0.08835214
#  -0.08976472 -0.12764548 -0.03473635 -0.01757937  0.01723712 -0.01836039
#  -0.10083368 -0.26198736 -0.08867965 -0.0882863  -0.10037287  0.09005255
#   0.09983431 -0.04903545  0.02638102  0.14434758  0.06294203  0.16744815
#   0.03704167  0.03553016  0.01728284 -0.02338452]
# Cosine similarity: -0.3199
# Run 10
# True dominant eigenvalue: -27.583677266428985
# Epoch 0: Loss = -1.3727, Residual = 26.3090, Avg Reward = -28.4694, Cosine Similarity = -0.2667
# Epoch 100: Loss = -1.1721, Residual = 23.7196, Avg Reward = -31.9981, Cosine Similarity = -0.0604
# Epoch 200: Loss = -1.1756, Residual = 23.7196, Avg Reward = -29.5600, Cosine Similarity = -0.0604
# Epoch 300: Loss = -1.1940, Residual = 23.1649, Avg Reward = -31.1475, Cosine Similarity = -0.0501
# Epoch 400: Loss = -1.1663, Residual = 22.5618, Avg Reward = -28.9045, Cosine Similarity = 0.0650
# Epoch 500: Loss = -1.1484, Residual = 20.2285, Avg Reward = -26.1043, Cosine Similarity = -0.0392
# Epoch 600: Loss = -1.2013, Residual = 18.1040, Avg Reward = -23.4183, Cosine Similarity = 0.1761
# Epoch 700: Loss = -1.1373, Residual = 15.6691, Avg Reward = -20.2189, Cosine Similarity = 0.1332
# Epoch 800: Loss = -1.1258, Residual = 13.6928, Avg Reward = -17.1061, Cosine Similarity = 0.0973
# Epoch 900: Loss = -1.1132, Residual = 12.0605, Avg Reward = -15.1902, Cosine Similarity = 0.1126
# Epoch 1000: Loss = -1.0968, Residual = 10.6921, Avg Reward = -13.3012, Cosine Similarity = 0.1274
#
# Predicted eigenvector: [ 0.19451481  0.04854489  0.04620793  0.07621203 -0.00939991 -0.09037621
#   0.07115944 -0.02054322  0.11880462 -0.16006626  0.01945608  0.10439606
#  -0.03793948 -0.08070523  0.11329094  0.10781331  0.04876266  0.16283998
#   0.03390907  0.01799546 -0.05630083 -0.01590562 -0.07694834 -0.18752663
#   0.05288114  0.19671579 -0.06088145 -0.06570148  0.09578348  0.16986881
#  -0.01197994 -0.00072541  0.10802305 -0.07040598  0.15231065 -0.1529071
#   0.127447    0.17993464 -0.01274127 -0.11011322  0.14784478  0.05465031
#   0.09026876 -0.08194675  0.00889791 -0.09354829  0.11553776  0.05081268
#  -0.1395038  -0.16490476  0.13089858  0.05200894 -0.04320624  0.02340054
#  -0.09050051 -0.02787154 -0.06679568  0.15372501 -0.11873159 -0.05025394
#  -0.00510436  0.09471624 -0.02928647 -0.10309527  0.09694591 -0.12062763
#   0.03815392  0.09094999 -0.01664177 -0.16309212  0.03613158 -0.05048293
#  -0.03246018 -0.03003678 -0.10851014 -0.04977487  0.05378167  0.06404824
#   0.21136114  0.06895392  0.05320199  0.08376724 -0.13240631 -0.10828444
#  -0.05638992  0.13577083  0.00481852  0.13814849 -0.12729451  0.00586224
#  -0.01318713 -0.08372595 -0.2281718  -0.13822196 -0.09859461 -0.10467276
#  -0.09745867 -0.02890794 -0.11406046 -0.07069363]
# True eigenvector: [ 0.0451409  -0.1306489   0.11582894  0.08969155 -0.19753292 -0.10470273
#  -0.00436784 -0.00863288  0.0087038  -0.13667107  0.00915388  0.10009345
#   0.09608968 -0.06734409  0.12213713 -0.02806743 -0.06120556  0.00662543
#   0.21053086  0.2691434   0.08248211  0.05074529  0.10348362  0.12135468
#   0.02284268 -0.00709422  0.04188393 -0.06764596 -0.01539976 -0.00569862
#   0.02821642  0.0846853   0.15583327  0.08362403 -0.00639677 -0.12410097
#   0.13706933  0.16387771  0.10560756  0.09365308 -0.00075137  0.12623459
#  -0.2908944   0.06437351 -0.00666199  0.05174509  0.02869348  0.05109724
#  -0.00740335  0.0103442   0.12587862 -0.02256784  0.06066518 -0.19474338
#   0.12112202  0.05935076  0.03561877  0.01130571 -0.06356459 -0.08090279
#  -0.00216349 -0.10088576  0.14320356 -0.15572229  0.00552157  0.03312387
#   0.00634718  0.08058783  0.07908821 -0.0512752   0.0014883   0.02643082
#   0.11841898 -0.12121174 -0.02645884  0.05211143 -0.00254516  0.07642801
#  -0.17676158  0.06955185 -0.00618224  0.10418025 -0.1170141  -0.00237764
#   0.07264219 -0.11399335 -0.09908295 -0.1781684  -0.05514064 -0.06164015
#   0.04872452 -0.10408323 -0.10300622  0.11915083 -0.02560064 -0.26908296
#  -0.04751139 -0.02339664 -0.0532265  -0.12189282]
# Cosine similarity: 0.1274

# %%
print(results)
# Out:
# [[-0.99989378  0.99989712 -0.99969399 -0.99979639 -0.99949962 -0.99879837
#   -0.99980378 -0.99987417  0.99800885  0.99893636]
#  [ 0.98868424  0.98912501  0.39573392  0.90100849  0.99213219 -0.41455376
#    0.99516791 -0.99395812  0.96217597  0.9908163 ]
#  [ 0.93460745 -0.74831402  0.97032142  0.0392857   0.94186842  0.09373933
#    0.85724699 -0.39186513  0.12892543 -0.99045336]
#  [ 0.04372105 -0.37457335 -0.13406821 -0.53124219 -0.19299236  0.7946744
#    0.06214511 -0.639027    0.46845335 -0.87433743]
#  [-0.2202062   0.4366408  -0.00737423  0.30844855  0.78106272  0.28384042
#    0.57013911  0.56508613 -0.63855362  0.29097843]
#  [ 0.10769464  0.13857806 -0.30613685 -0.31653365 -0.20451172 -0.57231629
#    0.00109701 -0.25444061 -0.31986678  0.12743297]]

# %%
perf = [np.mean(np.abs(results[i])) for i in range(len(choices))]

# %%
for i in range(len(choices)):
  print(f"{choices[i]} :  {perf[i]}")
# Out:
# 5 :  0.9994202435016633
# 10 :  0.8623355895280838
# 20 :  0.609662726148963
# 50 :  0.41152344457805157
# 75 :  0.4102330206893384
# 100 :  0.23486085711047053
