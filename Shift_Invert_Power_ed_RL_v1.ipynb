# %%
# !pip install 'shimmy>=2.0'
# Out:
# Collecting shimmy>=2.0
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from shimmy>=2.0) (1.26.4)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.11/dist-packages (from shimmy>=2.0) (1.1.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy
# Successfully installed shimmy-2.0.0

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.1.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 46.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 21.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 59.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable_baselines3-2.6.0

# %%
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO
from scipy.sparse import issparse, csr_matrix
from scipy.sparse.linalg import eigsh, splu, spsolve
from scipy.sparse import identity
from scipy.sparse import random as sparse_random

# Hybrid Shift-and-Invert Power Method + RL
class ShiftInvertPowerRL:
    def __init__(self, A, sigma=0.0, shift_tol=1e-6):
        self.A = A
        self.sigma = sigma  # Shift value
        self.shift_tol = shift_tol
        self.dim = A.shape[0]
        self._precompute_shifted_matrix()

    def _precompute_shifted_matrix(self):
        """Precompute (A - σI)^-1 for sparse systems"""
        if issparse(self.A):
            I = identity(self.dim, format='csr')
            self.M = self.A - self.sigma * I
            self.M_solver = splu(self.M.tocsc())
        else:
            self.M = self.A - self.sigma * np.eye(self.dim)
            self.M_inv = np.linalg.inv(self.M)

    def solve_shifted_system(self, b):
        """Solve (A - σI)x = b"""
        if issparse(self.A):
            return self.M_solver.solve(b)
        else:
            return np.linalg.solve(self.M, b)

    def hybrid_power_iteration(self, num_iter=10):
        """Warm start using shift-and-invert power method"""
        x = np.random.randn(self.dim)
        x /= np.linalg.norm(x)

        for _ in range(num_iter):
            x = self.solve_shifted_system(x)
            x /= np.linalg.norm(x) + 1e-8
        return x

# RL Environment for Eigenvector Refinement
class ShiftInvertEnv(gym.Env):
    def __init__(self, A, sigma, target_eigenvalue):
        super().__init__()
        self.solver = ShiftInvertPowerRL(A, sigma)
        self.target_eigenvalue = target_eigenvalue
        self.dim = A.shape[0]

        # Observation: current vector + residual history
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf,
                                           shape=(self.dim + 3,), dtype=np.float32)

        # Action: vector adjustment directions
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.dim,), dtype=np.float32)

        # Initialize with hybrid power method
        self.state = self.solver.hybrid_power_iteration(num_iter=20)
        self.residual_history = []

    def reset(self):
        self.state = self.solver.hybrid_power_iteration(num_iter=20)
        self.residual_history = []
        return self._get_obs()

    def step(self, action):
        # RL-guided adjustment
        adjusted_vec = self.state + 0.1 * action
        adjusted_vec /= np.linalg.norm(adjusted_vec) + 1e-8

        # Power method step for stability
        refined_vec = self.solver.solve_shifted_system(adjusted_vec)
        refined_vec /= np.linalg.norm(refined_vec) + 1e-8

        # Calculate metrics
        residual = self.solver.A @ refined_vec - self.target_eigenvalue * refined_vec
        residual_norm = np.linalg.norm(residual)
        self.residual_history.append(residual_norm)

        # Reward shaping
        reward = -residual_norm - 0.1 * np.log(residual_norm + 1e-8)

        self.state = refined_vec
        done = residual_norm < self.solver.shift_tol

        return self._get_obs(), reward, done, {}

    def _get_obs(self):
        """Augment state with residual statistics"""
        residual_stats = [
            np.mean(self.residual_history[-10:]),
            np.min(self.residual_history[-10:]),
            np.std(self.residual_history[-10:])
        ] if self.residual_history else [0, 0, 0]
        return np.concatenate([self.state, residual_stats])


def train_hybrid_eigen_solver(A, sigma=0.0, total_timesteps=50000):

    eigvals, eigvecs = eigsh(A, k=1, sigma=sigma)
    target_eigenvalue = eigvals[0]
    actual_eigenvector = eigvecs[:, 0]


    env = ShiftInvertEnv(A, sigma, target_eigenvalue)


    policy_kwargs = dict(net_arch=[256, 256, 128])
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=1e-4,
        gamma=0.99,
        policy_kwargs=policy_kwargs,
        verbose=1
    )


    model.learn(total_timesteps=total_timesteps)


    obs = env.reset()
    best_vec = env.state
    best_residual = np.inf

    for _ in range(1000):
        action, _ = model.predict(obs)
        obs, _, _, _ = env.step(action)
        current_residual = np.linalg.norm(A @ env.state - target_eigenvalue * env.state)

        if current_residual < best_residual:
            best_residual = current_residual
            best_vec = env.state

    v1 = best_vec / (np.linalg.norm(best_vec) + 1e-8)
    v2 = actual_eigenvector / (np.linalg.norm(actual_eigenvector) + 1e-8)
    cos_sim = np.dot(v1, v2)
    cos_sim = np.clip(cos_sim, -1.0, 1.0)  # Handle numerical errors
    cos_dist = 2 * np.arccos(abs(cos_sim))/ np.pi

    print(f"Final residual norm: {best_residual:.4e}")
    print(f"Eigenvector norm check: {np.linalg.norm(best_vec):.4f}")
    print(f"Cosine distance to actual eigenvector: {cos_dist:.6f}")

    return best_vec, best_residual, cos_dist

# %%
import numpy as np
from scipy.sparse import random as sparse_random
import pandas as pd

# Settings
sizes = [5, 10, 50, 100, 500, 1000]
runs_per_size = 4
sigma = 0.5

# Storage for results
results = []

for size in sizes:
    for run in range(1, runs_per_size + 1):
        print(f"\nRunning size {size}, iteration {run}")
        np.random.seed(42 + run)  # Different seed for variability

        A = sparse_random(size, size, density=0.01, format='csr')
        A = (A + A.T) * 0.5  # Make symmetric

        _, residual, cos_dist = train_hybrid_eigen_solver(A, sigma=sigma)

        results.append({
            "Matrix Size": size,
            "Run": run,
            "Final Residual": residual,
            "Cosine Distance": cos_dist
        })

# Convert to DataFrame for display
df_results = pd.DataFrame(results)
print(df_results.to_string(index=False))
# Out:
# Streaming output truncated to the last 5000 lines.
# |    time_elapsed         | 57          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.031803377 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | -1.3e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0224     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0325     |
# |    std                  | 0.991       |
# |    value_loss           | 0.168       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 13          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.030206192 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | 0.000318    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0468     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0307     |
# |    std                  | 0.99        |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 14          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.032107122 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | 6.95e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0568     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0374     |
# |    std                  | 0.988       |
# |    value_loss           | 0.0647      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 15          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.034096636 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | -8.96e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.036      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0388     |
# |    std                  | 0.987       |
# |    value_loss           | 0.0403      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 16          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.035249084 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | 0.000637    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0449     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0408     |
# |    std                  | 0.985       |
# |    value_loss           | 0.0259      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 425        |
# |    iterations           | 17         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.03522271 |
# |    clip_fraction        | 0.379      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -140       |
# |    explained_variance   | -0.000404  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0574    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0445    |
# |    std                  | 0.983      |
# |    value_loss           | 0.0175     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 18          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.031831212 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | 5.54e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0514     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0416     |
# |    std                  | 0.981       |
# |    value_loss           | 0.0124      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 19          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.038087048 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | -0.000104   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0696     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.045      |
# |    std                  | 0.979       |
# |    value_loss           | 0.00912     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 20          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.037376896 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | 5.71e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0581     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0403     |
# |    std                  | 0.977       |
# |    value_loss           | 0.00644     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 426        |
# |    iterations           | 21         |
# |    time_elapsed         | 100        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.03368751 |
# |    clip_fraction        | 0.385      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -139       |
# |    explained_variance   | 0.000126   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0281    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0419    |
# |    std                  | 0.975      |
# |    value_loss           | 0.00461    |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 425       |
# |    iterations           | 22        |
# |    time_elapsed         | 105       |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0333671 |
# |    clip_fraction        | 0.39      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -139      |
# |    explained_variance   | -2.15e-06 |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.0576   |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -0.0429   |
# |    std                  | 0.973     |
# |    value_loss           | 0.00369   |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 426        |
# |    iterations           | 23         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.03608697 |
# |    clip_fraction        | 0.389      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -139       |
# |    explained_variance   | 0.000144   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0282    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0452    |
# |    std                  | 0.971      |
# |    value_loss           | 0.00292    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 24          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.040799115 |
# |    clip_fraction        | 0.419       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -139        |
# |    explained_variance   | 3.1e-06     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.044      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0474     |
# |    std                  | 0.969       |
# |    value_loss           | 0.00231     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 25          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.046365023 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -139        |
# |    explained_variance   | -4.96e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0528     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0477     |
# |    std                  | 0.967       |
# |    value_loss           | 0.00195     |
# -----------------------------------------
# Final residual norm: 5.9906e-03
# Eigenvector norm check: 1.0000
# Cosine distance to actual eigenvector: 0.018514
#
# Running size 100, iteration 3
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 623  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013631769 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -0.0194     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.178       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 1           |
# |    value_loss           | 26.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016845874 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -0.005      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.413       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.999       |
# |    value_loss           | 6.69        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 454        |
# |    iterations           | 4          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01223181 |
# |    clip_fraction        | 0.0502     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -142       |
# |    explained_variance   | -0.00262   |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0102     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00904   |
# |    std                  | 0.999      |
# |    value_loss           | 9.8        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018186528 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | 8.94e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00196     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.999       |
# |    value_loss           | 7.84        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 448         |
# |    iterations           | 6           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.022135105 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -0.000174   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0176      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.998       |
# |    value_loss           | 5.02        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.025423264 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -2.41e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.019      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.022      |
# |    std                  | 0.998       |
# |    value_loss           | 3.15        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 442       |
# |    iterations           | 8         |
# |    time_elapsed         | 37        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0301091 |
# |    clip_fraction        | 0.253     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -142      |
# |    explained_variance   | 1.38e-05  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 0.0149    |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.0216   |
# |    std                  | 0.997     |
# |    value_loss           | 1.84      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 9           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026864637 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -8.32e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.013      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.996       |
# |    value_loss           | 1.09        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 437        |
# |    iterations           | 10         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.03214068 |
# |    clip_fraction        | 0.275      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -141       |
# |    explained_variance   | 6.25e-05   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00961   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0246    |
# |    std                  | 0.994      |
# |    value_loss           | 0.641      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 11          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.030550752 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | -0.000102   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0122     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0283     |
# |    std                  | 0.993       |
# |    value_loss           | 0.378       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 12          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.028984595 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | 1.48e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.021       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0296     |
# |    std                  | 0.992       |
# |    value_loss           | 0.225       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 13          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.032689966 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | 5.56e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0487     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0321     |
# |    std                  | 0.99        |
# |    value_loss           | 0.135       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 14          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.031067397 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | -5.5e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0586     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0316     |
# |    std                  | 0.988       |
# |    value_loss           | 0.0847      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 15          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.030802643 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | -0.00012    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0355     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.035      |
# |    std                  | 0.987       |
# |    value_loss           | 0.05        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 16          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.032962624 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | 2.68e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0345     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 0.985       |
# |    value_loss           | 0.0325      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 17          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.032257378 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | 7.31e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.039      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 0.984       |
# |    value_loss           | 0.022       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 431        |
# |    iterations           | 18         |
# |    time_elapsed         | 85         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.03471142 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -140       |
# |    explained_variance   | 1.65e-05   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0571    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0391    |
# |    std                  | 0.982      |
# |    value_loss           | 0.0144     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 429        |
# |    iterations           | 19         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03426691 |
# |    clip_fraction        | 0.382      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -140       |
# |    explained_variance   | -3.08e-05  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0222    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0369    |
# |    std                  | 0.98       |
# |    value_loss           | 0.0101     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 429        |
# |    iterations           | 20         |
# |    time_elapsed         | 95         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03154593 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -140       |
# |    explained_variance   | -9.17e-05  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0116    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0385    |
# |    std                  | 0.979      |
# |    value_loss           | 0.00742    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 430        |
# |    iterations           | 21         |
# |    time_elapsed         | 99         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.03509869 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -140       |
# |    explained_variance   | -0.000208  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0383    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0423    |
# |    std                  | 0.977      |
# |    value_loss           | 0.00531    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 22          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.033010274 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -139        |
# |    explained_variance   | 0.000164    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0186     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0354     |
# |    std                  | 0.975       |
# |    value_loss           | 0.00419     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 23          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.035516396 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -139        |
# |    explained_variance   | -0.000113   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0319     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.038      |
# |    std                  | 0.973       |
# |    value_loss           | 0.0033      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 24          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.032438405 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -139        |
# |    explained_variance   | 2.97e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.049      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0401     |
# |    std                  | 0.971       |
# |    value_loss           | 0.00243     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 25          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.034313362 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -139        |
# |    explained_variance   | -3.96e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0547     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 0.969       |
# |    value_loss           | 0.00222     |
# -----------------------------------------
# Final residual norm: 3.7227e-03
# Eigenvector norm check: 1.0000
# Cosine distance to actual eigenvector: 0.011703
#
# Running size 100, iteration 4
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 633  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014388854 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | 0.0019      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00365    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 1           |
# |    value_loss           | 8.49        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012691271 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -0.00151    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00714    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00698    |
# |    std                  | 0.999       |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012173674 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -0.000272   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.536       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00944    |
# |    std                  | 0.999       |
# |    value_loss           | 13.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016908683 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -5.85e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.117       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.999       |
# |    value_loss           | 9.17        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 6           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.023356084 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -1.88e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.172       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.998       |
# |    value_loss           | 5.96        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.026467225 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | 1.46e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0384     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 0.997       |
# |    value_loss           | 3.69        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 8           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.027419029 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -142        |
# |    explained_variance   | -4.05e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0148     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.996       |
# |    value_loss           | 2.23        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 9           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023355272 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | -3.83e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.000937    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0211     |
# |    std                  | 0.995       |
# |    value_loss           | 1.3         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 431        |
# |    iterations           | 10         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.02236332 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -141       |
# |    explained_variance   | -1.22e-05  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.015     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0149    |
# |    std                  | 0.994      |
# |    value_loss           | 0.766      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 11          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021282945 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | 2.78e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0274     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.992       |
# |    value_loss           | 0.443       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 428       |
# |    iterations           | 12        |
# |    time_elapsed         | 57        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0206394 |
# |    clip_fraction        | 0.271     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -141      |
# |    explained_variance   | 5.48e-05  |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.0498   |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -0.0264   |
# |    std                  | 0.99      |
# |    value_loss           | 0.257     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 428        |
# |    iterations           | 13         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.02661195 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -141       |
# |    explained_variance   | -8.11e-06  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0169    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0271    |
# |    std                  | 0.989      |
# |    value_loss           | 0.153      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 14          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018303704 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -141        |
# |    explained_variance   | 2.56e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0395     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.987       |
# |    value_loss           | 0.0933      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 419        |
# |    iterations           | 15         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.02114879 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -140       |
# |    explained_variance   | 2.22e-05   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0347    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.023     |
# |    std                  | 0.985      |
# |    value_loss           | 0.058      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 16          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.025676886 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | -5.96e-06   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0273     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0285     |
# |    std                  | 0.984       |
# |    value_loss           | 0.0352      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 17          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.022911362 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | 0.000103    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.043      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0275     |
# |    std                  | 0.982       |
# |    value_loss           | 0.0224      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 18          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021797277 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | 3.89e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0254     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0286     |
# |    std                  | 0.98        |
# |    value_loss           | 0.0149      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 19          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.023684986 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -140        |
# |    explained_variance   | -6.87e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00399    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0282     |
# |    std                  | 0.978       |
# |    value_loss           | 0.00974     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 420        |
# |    iterations           | 20         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02118117 |
# |    clip_fraction        | 0.289      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -140       |
# |    explained_variance   | 8.05e-06   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.027     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0253    |
# |    std                  | 0.976      |
# |    value_loss           | 0.00661    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 418        |
# |    iterations           | 21         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01995042 |
# |    clip_fraction        | 0.301      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -139       |
# |    explained_variance   | -0.00018   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0428    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0296    |
# |    std                  | 0.974      |
# |    value_loss           | 0.00457    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 22          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.019464519 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -139        |
# |    explained_variance   | 6.85e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00367    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0295     |
# |    std                  | 0.972       |
# |    value_loss           | 0.00346     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 23          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.021623956 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -139        |
# |    explained_variance   | 4.18e-05    |
# ...
# |    time_elapsed         | 49          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.058551654 |
# |    clip_fraction        | 0.446       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42e+03   |
# |    explained_variance   | -1.43e-06   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.52        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0446     |
# |    std                  | 1           |
# |    value_loss           | 16.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 286        |
# |    iterations           | 8          |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.07511795 |
# |    clip_fraction        | 0.488      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.518      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0443    |
# |    std                  | 1          |
# |    value_loss           | 11.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 287        |
# |    iterations           | 9          |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.11928485 |
# |    clip_fraction        | 0.518      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | 2.09e-06   |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0245     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0447    |
# |    std                  | 1          |
# |    value_loss           | 7.53       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 286        |
# |    iterations           | 10         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.12732719 |
# |    clip_fraction        | 0.529      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | -1.55e-06  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0475     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0431    |
# |    std                  | 1          |
# |    value_loss           | 4.67       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 11         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.13185659 |
# |    clip_fraction        | 0.511      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | 4.77e-07   |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0172     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0486    |
# |    std                  | 0.999      |
# |    value_loss           | 2.96       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 12         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.11622437 |
# |    clip_fraction        | 0.508      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | 4.17e-07   |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0319     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0457    |
# |    std                  | 0.999      |
# |    value_loss           | 1.74       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 284        |
# |    iterations           | 13         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.11385319 |
# |    clip_fraction        | 0.482      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | 1.25e-06   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.109     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0519    |
# |    std                  | 0.999      |
# |    value_loss           | 1.01       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 14          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.109260224 |
# |    clip_fraction        | 0.549       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42e+03   |
# |    explained_variance   | 3.52e-06    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0831     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0571     |
# |    std                  | 0.999       |
# |    value_loss           | 0.596       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 284        |
# |    iterations           | 15         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.12163357 |
# |    clip_fraction        | 0.551      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | -1.07e-06  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.02      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0636    |
# |    std                  | 0.999      |
# |    value_loss           | 0.349      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 16         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.10814664 |
# |    clip_fraction        | 0.563      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | -5.96e-07  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0793    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0611    |
# |    std                  | 0.999      |
# |    value_loss           | 0.212      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 17         |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.11973351 |
# |    clip_fraction        | 0.597      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | 6.91e-06   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0621    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0672    |
# |    std                  | 0.999      |
# |    value_loss           | 0.129      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 285       |
# |    iterations           | 18        |
# |    time_elapsed         | 129       |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.130627  |
# |    clip_fraction        | 0.602     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.42e+03 |
# |    explained_variance   | 8.58e-06  |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.12     |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -0.0717   |
# |    std                  | 0.998     |
# |    value_loss           | 0.0812    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 286        |
# |    iterations           | 19         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.13845962 |
# |    clip_fraction        | 0.628      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | 3.58e-06   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.073     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0775    |
# |    std                  | 0.998      |
# |    value_loss           | 0.0503     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 20         |
# |    time_elapsed         | 143        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.14141656 |
# |    clip_fraction        | 0.632      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | -7.03e-06  |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0559    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0832    |
# |    std                  | 0.998      |
# |    value_loss           | 0.0332     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 286       |
# |    iterations           | 21        |
# |    time_elapsed         | 150       |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.1441439 |
# |    clip_fraction        | 0.639     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.42e+03 |
# |    explained_variance   | 6.97e-06  |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.13     |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -0.0899   |
# |    std                  | 0.998     |
# |    value_loss           | 0.0217    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 284       |
# |    iterations           | 22        |
# |    time_elapsed         | 158       |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.1546957 |
# |    clip_fraction        | 0.667     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.42e+03 |
# |    explained_variance   | 2.56e-05  |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.112    |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -0.0875   |
# |    std                  | 0.997     |
# |    value_loss           | 0.0143    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 23         |
# |    time_elapsed         | 165        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.16063932 |
# |    clip_fraction        | 0.665      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | 4.55e-05   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.11      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0933    |
# |    std                  | 0.997      |
# |    value_loss           | 0.00994    |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 285       |
# |    iterations           | 24        |
# |    time_elapsed         | 172       |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.1828947 |
# |    clip_fraction        | 0.677     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.42e+03 |
# |    explained_variance   | 2.22e-05  |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.131    |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0897   |
# |    std                  | 0.997     |
# |    value_loss           | 0.00746   |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 284        |
# |    iterations           | 25         |
# |    time_elapsed         | 179        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.17803875 |
# |    clip_fraction        | 0.685      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42e+03  |
# |    explained_variance   | 1.08e-05   |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.104     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0937    |
# |    std                  | 0.997      |
# |    value_loss           | 0.00529    |
# ----------------------------------------
# Final residual norm: 6.5594e-04
# Eigenvector norm check: 1.0000
# Cosine distance to actual eigenvector: 0.005756
#  Matrix Size  Run  Final Residual  Cosine Distance
#            5    1        0.000000         0.503978
#            5    2        0.000000         0.868879
#            5    3        0.000000         0.695649
#            5    4        0.000000         0.560645
#           10    1        0.008423         0.018226
#           10    2        0.007683         0.016295
#           10    3        0.000150         0.000230
#           10    4        0.005279         0.009124
#           50    1        0.011114         0.028979
#           50    2        0.009512         0.025034
#           50    3        0.004368         0.012059
#           50    4        0.008233         0.031928
#          100    1        0.011504         0.057718
#          100    2        0.005991         0.018514
#          100    3        0.003723         0.011703
#          100    4        0.004545         0.018749
#          500    1        0.000181         0.001595
#          500    2        0.000272         0.001413
#          500    3        0.000812         0.004121
#          500    4        0.002420         0.033679
#         1000    1        0.000530         0.009286
#         1000    2        0.004888         0.071430
#         1000    3        0.000997         0.005613
#         1000    4        0.000656         0.005756
