# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.distributions import MultivariateNormal
from collections import deque
import random
import matplotlib.pyplot as plt

class Policy(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.fc_mean = nn.Linear(dim, dim)
        self.log_std = nn.Parameter(torch.zeros(dim))

        # Value function baseline
        self.value_net = nn.Linear(dim, 1)

    def forward(self, x):
        mean = self.fc_mean(x)
        cov = torch.diag(torch.exp(self.log_std))
        return MultivariateNormal(mean, cov), self.value_net(x)



class ExperienceReplay:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        return random.sample(self.buffer, min(batch_size, len(self.buffer)))

    def __len__(self):
        return len(self.buffer)

def compute_reward(v_new, v_prev, A, lambda_):
    """Reward function using Rayleigh quotient"""
    # Compute Rayleigh quotient
    with torch.no_grad():
        R = (v_new @ A @ v_new) / (v_new @ v_new)

    # 1. Rayleigh quotient component (closer to true eigenvalue is better)
    rayleigh_component = -torch.abs(R - lambda_).item()

    # 2. Direction consistency component
    cosine_sim = torch.nn.functional.cosine_similarity(
        v_new.unsqueeze(0), v_prev.unsqueeze(0)
    ).item()
    direction_component = 0.3 * cosine_sim

    # 3. Improvement component (compared to previous Rayleigh quotient)
    with torch.no_grad():
        prev_R = (v_prev @ A @ v_prev) / (v_prev @ v_prev)
    improvement_component = 0.2 * (torch.abs(prev_R - lambda_).item() - torch.abs(R - lambda_).item())

    # Combined reward
    reward = rayleigh_component + direction_component + improvement_component

    # Also compute residual for tracking
    residual = torch.linalg.norm((A - lambda_ * torch.eye(A.shape[0])) @ v_new)

    return reward, residual.item(), cosine_sim

def train(A, lambda_, policy, epochs=500, batch_size=32, replay_size=1000, dominant_v=None):
    optimizer = optim.Adam(policy.parameters(), lr=1e-3)
    replay_buffer = ExperienceReplay(replay_size)
    v = torch.randn(A.shape[0])
    v = v / torch.norm(v)

    # Tracking variables
    best_v = v.clone()
    best_residual = float('inf')
    moving_avg_reward = 0
    alpha = 0.1  # For moving average

    for epoch in range(epochs):
        # Generate multiple trajectories for batch update
        states = []
        actions = []
        rewards = []
        values = []

        for _ in range(batch_size):
            v_prev = v.clone()
            dist, value_est = policy(v_prev)
            delta_v = dist.sample()

            with torch.no_grad():
                v_new = v_prev + delta_v
                v_new = v_new / torch.norm(v_new)
                reward, residual, cos_sim = compute_reward(v_new, v_prev, A, lambda_)

                # Update best solution found
                if residual < best_residual:
                    best_residual = residual
                    best_v = v_new.clone()

                # Update moving average for baseline
                moving_avg_reward = alpha * reward + (1 - alpha) * moving_avg_reward

            # Store experience
            replay_buffer.push((v_prev, delta_v, reward, value_est))

            # Store for batch update
            states.append(v_prev)
            actions.append(delta_v)
            rewards.append(reward)
            values.append(value_est)

        # Sample from replay buffer
        if len(replay_buffer) > batch_size:
            replay_batch = replay_buffer.sample(batch_size)
            replay_states, replay_actions, replay_rewards, replay_values = zip(*replay_batch)

            # Combine with current batch
            states.extend(replay_states)
            actions.extend(replay_actions)
            rewards.extend(replay_rewards)
            values.extend(replay_values)

        # Convert to tensors
        states = torch.stack(states)
        actions = torch.stack(actions)
        rewards = torch.tensor(rewards, dtype=torch.float32)
        old_values = torch.cat(values).squeeze()

        # Normalize rewards
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-8)

        # Compute advantages
        advantages = rewards - old_values.detach()

        # Policy loss
        dists, value_ests = policy(states)
        log_probs = dists.log_prob(actions)

        # PPO-style clipped objective
        ratios = torch.exp(log_probs - dists.log_prob(actions).detach())
        clipped_ratios = torch.clamp(ratios, 0.8, 1.2)
        policy_loss = -torch.min(ratios * advantages, clipped_ratios * advantages).mean()

        # Value loss (MSE)
        value_loss = 0.5 * (value_ests.squeeze() - rewards).pow(2).mean()

        # Entropy bonus
        entropy = dists.entropy().mean()

        # Total loss
        loss = policy_loss + 0.5 * value_loss - 0.01 * entropy

        # Update
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(policy.parameters(), 1.0)
        optimizer.step()

        # Update v with best candidate from batch
        v = best_v.clone()

        if epoch % 100 == 0:
            print(
                f'Epoch {epoch}: Loss = {loss.item():.4f}, '
                f'Residual = {best_residual:.4f}, '
                f'Avg Reward = {moving_avg_reward:.4f}'
                f', Cosine Similarity = {torch.nn.functional.cosine_similarity(best_v.unsqueeze(0), dominant_v.unsqueeze(0)).item():.4f}'
                )

    return best_v

# Test function with improved training
def test_improved_policy(dim=5, epochs=1000):
    # Generate random symmetric matrix
    A_np = np.random.randn(dim, dim)
    A_np = A_np + A_np.T
    A = torch.tensor(A_np, dtype=torch.float32)

    # Get ground truth
    eigenvalues, eigenvectors = np.linalg.eig(A_np)
    dominant_idx = np.argmax(np.abs(eigenvalues))
    dominant_lambda = eigenvalues[dominant_idx]
    dominant_v = torch.tensor(eigenvectors[:, dominant_idx], dtype=torch.float32)

    print(f"True dominant eigenvalue: {dominant_lambda}")

    # Train
    policy = Policy(dim)
    predicted_v = train(A, dominant_lambda, policy, epochs=epochs, dominant_v=dominant_v)

    # Compare
    cosine_sim = torch.nn.functional.cosine_similarity(
        predicted_v.unsqueeze(0), dominant_v.unsqueeze(0)
    ).item()

    print(f"\nPredicted eigenvector: {predicted_v.detach().numpy()}")
    print(f"True eigenvector: {dominant_v.numpy()}")
    print(f"Cosine similarity: {cosine_sim:.4f}")

    return cosine_sim

# %% [markdown]
# # Evaluating on different sizes

# %%
choices = [5, 10, 20, 50, 75, 100]
results = []
for dim in choices:
    print(f"\nTesting with dimension: {dim}")
    for i in range(10):
        print(f"Run {i + 1}")
        x = test_improved_policy(dim=dim, epochs=1001)
        results.append(x)
results = np.array(results)
results = results.reshape(len(choices), 10)
# Out:
# Testing with dimension: 5
# Run 1
# True dominant eigenvalue: 4.423332709445424
# Epoch 0: Loss = 0.4892, Residual = 3.0350, Avg Reward = -5.4627, Cosine Similarity = 0.4257
# Epoch 100: Loss = 0.3540, Residual = 0.6296, Avg Reward = -5.3484, Cosine Similarity = 0.9924
# Epoch 200: Loss = 0.2140, Residual = 0.4287, Avg Reward = -4.1241, Cosine Similarity = 0.9923
# Epoch 300: Loss = 0.1668, Residual = 0.2956, Avg Reward = -2.6510, Cosine Similarity = 0.9991
# Epoch 400: Loss = 0.1789, Residual = 0.2956, Avg Reward = -2.0786, Cosine Similarity = 0.9991
# Epoch 500: Loss = 0.1856, Residual = 0.1921, Avg Reward = -1.2532, Cosine Similarity = 0.9992
# Epoch 600: Loss = 0.1808, Residual = 0.1113, Avg Reward = -1.2476, Cosine Similarity = 0.9997
# Epoch 700: Loss = 0.1897, Residual = 0.1113, Avg Reward = -0.4516, Cosine Similarity = 0.9997
# Epoch 800: Loss = 0.1924, Residual = 0.0831, Avg Reward = -0.1138, Cosine Similarity = 0.9999
# Epoch 900: Loss = 0.1951, Residual = 0.0831, Avg Reward = -0.1146, Cosine Similarity = 0.9999
# Epoch 1000: Loss = 0.1978, Residual = 0.0831, Avg Reward = -0.0250, Cosine Similarity = 0.9999
#
# Predicted eigenvector: [0.41380277 0.13615438 0.44053093 0.54555905 0.564382  ]
# True eigenvector: [0.40884614 0.14300613 0.43220735 0.5454265  0.5728009 ]
# Cosine similarity: 0.9999
# Run 2
# True dominant eigenvalue: 3.3270228658794556
# Epoch 0: Loss = 0.0241, Residual = 1.6159, Avg Reward = -2.6451, Cosine Similarity = -0.1363
# Epoch 100: Loss = -0.0830, Residual = 0.2730, Avg Reward = -2.4944, Cosine Similarity = -0.9071
# Epoch 200: Loss = 0.1069, Residual = 0.1964, Avg Reward = -1.4239, Cosine Similarity = -0.9583
# Epoch 300: Loss = 0.1716, Residual = 0.1964, Avg Reward = -1.4765, Cosine Similarity = -0.9583
# Epoch 400: Loss = 0.1781, Residual = 0.1873, Avg Reward = -0.6760, Cosine Similarity = -0.9375
# Epoch 500: Loss = 0.2235, Residual = 0.1056, Avg Reward = -0.5622, Cosine Similarity = -0.9991
# Epoch 600: Loss = 0.1905, Residual = 0.1056, Avg Reward = -0.3913, Cosine Similarity = -0.9991
# Epoch 700: Loss = 0.1828, Residual = 0.0769, Avg Reward = -0.2951, Cosine Similarity = -0.9790
# Epoch 800: Loss = 0.2081, Residual = 0.0315, Avg Reward = 0.0144, Cosine Similarity = -1.0000
# Epoch 900: Loss = 0.1955, Residual = 0.0315, Avg Reward = 0.0550, Cosine Similarity = -1.0000
# Epoch 1000: Loss = 0.1978, Residual = 0.0315, Avg Reward = 0.1322, Cosine Similarity = -1.0000
#
# Predicted eigenvector: [ 0.4913504  -0.24071842  0.42185622  0.16060834  0.70489126]
# True eigenvector: [-0.4837254   0.24474947 -0.42624262 -0.16292512 -0.70560616]
# Cosine similarity: -1.0000
# Run 3
# True dominant eigenvalue: 4.100598749917559
# Epoch 0: Loss = 0.2377, Residual = 1.4377, Avg Reward = -3.7465, Cosine Similarity = 0.9403
# Epoch 100: Loss = 0.1916, Residual = 0.8017, Avg Reward = -4.2200, Cosine Similarity = 0.9810
# Epoch 200: Loss = 0.2175, Residual = 0.5572, Avg Reward = -2.4393, Cosine Similarity = 0.9916
# Epoch 300: Loss = 0.1462, Residual = 0.3844, Avg Reward = -1.8263, Cosine Similarity = 0.9957
# Epoch 400: Loss = 0.1856, Residual = 0.2633, Avg Reward = -1.8017, Cosine Similarity = 0.9988
# Epoch 500: Loss = 0.1846, Residual = 0.2633, Avg Reward = -1.0395, Cosine Similarity = 0.9988
# Epoch 600: Loss = 0.1974, Residual = 0.2585, Avg Reward = -0.4030, Cosine Similarity = 0.9985
# Epoch 700: Loss = 0.1900, Residual = 0.1221, Avg Reward = -0.4407, Cosine Similarity = 0.9996
# Epoch 800: Loss = 0.1927, Residual = 0.1221, Avg Reward = -0.3767, Cosine Similarity = 0.9996
# Epoch 900: Loss = 0.1954, Residual = 0.1221, Avg Reward = -0.1257, Cosine Similarity = 0.9996
# Epoch 1000: Loss = 0.1979, Residual = 0.1221, Avg Reward = -0.0075, Cosine Similarity = 0.9996
#
# Predicted eigenvector: [ 0.30898002 -0.16436541  0.5568786  -0.47675955 -0.58318263]
# True eigenvector: [ 0.3090368  -0.17943054  0.5631209  -0.48811868 -0.56297064]
# Cosine similarity: 0.9996
# Run 4
# True dominant eigenvalue: 6.665018911223642
# Epoch 0: Loss = 0.0410, Residual = 3.5790, Avg Reward = -6.9338, Cosine Similarity = 0.7483
# Epoch 100: Loss = 0.1767, Residual = 0.8981, Avg Reward = -4.3407, Cosine Similarity = 0.9933
# Epoch 200: Loss = 0.1767, Residual = 0.8135, Avg Reward = -4.0845, Cosine Similarity = 0.9963
# Epoch 300: Loss = 0.1814, Residual = 0.5260, Avg Reward = -2.3602, Cosine Similarity = 0.9967
# Epoch 400: Loss = 0.1864, Residual = 0.1738, Avg Reward = -1.4630, Cosine Similarity = 0.9999
# Epoch 500: Loss = 0.1865, Residual = 0.1738, Avg Reward = -1.0730, Cosine Similarity = 0.9999
# Epoch 600: Loss = 0.1891, Residual = 0.1738, Avg Reward = -0.8954, Cosine Similarity = 0.9999
# Epoch 700: Loss = 0.1918, Residual = 0.1738, Avg Reward = -0.4061, Cosine Similarity = 0.9999
# Epoch 800: Loss = 0.1944, Residual = 0.1738, Avg Reward = -0.2177, Cosine Similarity = 0.9999
# Epoch 900: Loss = 0.1970, Residual = 0.1738, Avg Reward = -0.3517, Cosine Similarity = 0.9999
# Epoch 1000: Loss = 0.1998, Residual = 0.1015, Avg Reward = -0.1439, Cosine Similarity = 0.9999
#
# Predicted eigenvector: [ 0.59818876  0.39791292  0.55286777 -0.14278899  0.39722046]
# True eigenvector: [ 0.59941113  0.39540476  0.54659057 -0.15349227  0.4025422 ]
# Cosine similarity: 0.9999
# Run 5
# True dominant eigenvalue: -6.622977166485405
# Epoch 0: Loss = 0.3256, Residual = 5.1146, Avg Reward = -6.4541, Cosine Similarity = -0.4813
# Epoch 100: Loss = 0.3862, Residual = 1.6232, Avg Reward = -8.2569, Cosine Similarity = -0.9838
# Epoch 200: Loss = 0.2647, Residual = 1.3258, Avg Reward = -5.5250, Cosine Similarity = -0.9800
# Epoch 300: Loss = 0.1932, Residual = 0.5246, Avg Reward = -5.2931, Cosine Similarity = -0.9963
# Epoch 400: Loss = 0.1722, Residual = 0.3732, Avg Reward = -4.4500, Cosine Similarity = -0.9981
# Epoch 500: Loss = 0.1818, Residual = 0.3732, Avg Reward = -4.3348, Cosine Similarity = -0.9981
# Epoch 600: Loss = 0.1852, Residual = 0.3732, Avg Reward = -3.4057, Cosine Similarity = -0.9981
# Epoch 700: Loss = 0.1892, Residual = 0.3537, Avg Reward = -1.6872, Cosine Similarity = -0.9991
# Epoch 800: Loss = 0.1902, Residual = 0.3537, Avg Reward = -1.3280, Cosine Similarity = -0.9991
# Epoch 900: Loss = 0.1926, Residual = 0.3537, Avg Reward = -1.0197, Cosine Similarity = -0.9991
# Epoch 1000: Loss = 0.1966, Residual = 0.2482, Avg Reward = -1.2770, Cosine Similarity = -0.9994
#
# Predicted eigenvector: [-0.47531676  0.85823536  0.16698542 -0.05225898 -0.08301228]
# True eigenvector: [ 0.48288792 -0.8557718  -0.17358679  0.02655438  0.06030285]
# Cosine similarity: -0.9994
# Run 6
# True dominant eigenvalue: -5.736558364534988
# Epoch 0: Loss = 0.0418, Residual = 3.5626, Avg Reward = -4.4869, Cosine Similarity = -0.7230
# Epoch 100: Loss = -0.0755, Residual = 0.5215, Avg Reward = -3.4770, Cosine Similarity = -0.9964
# Epoch 200: Loss = 0.0800, Residual = 0.3447, Avg Reward = -4.4509, Cosine Similarity = -0.9963
# Epoch 300: Loss = 0.1502, Residual = 0.3447, Avg Reward = -2.0925, Cosine Similarity = -0.9963
# Epoch 400: Loss = 0.1769, Residual = 0.3447, Avg Reward = -1.2943, Cosine Similarity = -0.9963
# Epoch 500: Loss = 0.1898, Residual = 0.1911, Avg Reward = -0.5871, Cosine Similarity = -0.9994
# Epoch 600: Loss = 0.1893, Residual = 0.1911, Avg Reward = -0.7107, Cosine Similarity = -0.9994
# Epoch 700: Loss = 0.1914, Residual = 0.1911, Avg Reward = -0.2031, Cosine Similarity = -0.9994
# Epoch 800: Loss = 0.1965, Residual = 0.1205, Avg Reward = -0.2522, Cosine Similarity = -0.9995
# Epoch 900: Loss = 0.1956, Residual = 0.1205, Avg Reward = -0.1314, Cosine Similarity = -0.9995
# Epoch 1000: Loss = 0.2018, Residual = 0.1146, Avg Reward = -0.0085, Cosine Similarity = -0.9998
#
# Predicted eigenvector: [ 0.564541    0.11503909  0.5340515  -0.30936414 -0.53585666]
# True eigenvector: [-0.559238   -0.1096912  -0.5507311   0.29910505  0.53146225]
# Cosine similarity: -0.9998
# Run 7
# True dominant eigenvalue: 4.648584442847914
# Epoch 0: Loss = 0.4052, Residual = 2.1885, Avg Reward = -3.0857, Cosine Similarity = 0.8539
# Epoch 100: Loss = 0.8473, Residual = 0.3885, Avg Reward = -4.3208, Cosine Similarity = 0.9957
# Epoch 200: Loss = 0.5497, Residual = 0.3264, Avg Reward = -3.8936, Cosine Similarity = 0.9956
# Epoch 300: Loss = 0.3596, Residual = 0.2467, Avg Reward = -1.7655, Cosine Similarity = 0.9975
# Epoch 400: Loss = 0.2634, Residual = 0.2467, Avg Reward = -1.1063, Cosine Similarity = 0.9975
# Epoch 500: Loss = 0.2219, Residual = 0.2020, Avg Reward = -0.6920, Cosine Similarity = 0.9973
# Epoch 600: Loss = 0.1987, Residual = 0.2020, Avg Reward = -0.4836, Cosine Similarity = 0.9973
# Epoch 700: Loss = 0.1904, Residual = 0.1507, Avg Reward = -0.3711, Cosine Similarity = 0.9989
# Epoch 800: Loss = 0.1918, Residual = 0.1507, Avg Reward = -0.0612, Cosine Similarity = 0.9989
# Epoch 900: Loss = 0.1969, Residual = 0.1153, Avg Reward = -0.0695, Cosine Similarity = 0.9998
# Epoch 1000: Loss = 0.1931, Residual = 0.0881, Avg Reward = 0.0349, Cosine Similarity = 0.9998
#
# Predicted eigenvector: [ 0.21458387  0.64366937  0.44705406  0.49864686 -0.30188975]
# True eigenvector: [ 0.20563427  0.6479226   0.45963225  0.48647186 -0.2999904 ]
# Cosine similarity: 0.9998
# Run 8
# True dominant eigenvalue: 4.125692924549026
# Epoch 0: Loss = 0.6128, Residual = 0.5361, Avg Reward = -2.7267, Cosine Similarity = -0.9774
# Epoch 100: Loss = 0.1577, Residual = 0.3890, Avg Reward = -2.9912, Cosine Similarity = -0.9870
# Epoch 200: Loss = 0.1857, Residual = 0.3312, Avg Reward = -2.7489, Cosine Similarity = -0.9588
# Epoch 300: Loss = 0.1785, Residual = 0.3312, Avg Reward = -2.0657, Cosine Similarity = -0.9588
# Epoch 400: Loss = 0.1805, Residual = 0.2437, Avg Reward = -1.1131, Cosine Similarity = -0.9986
# Epoch 500: Loss = 0.1819, Residual = 0.2437, Avg Reward = -0.6788, Cosine Similarity = -0.9986
# Epoch 600: Loss = 0.1850, Residual = 0.1075, Avg Reward = -0.7431, Cosine Similarity = -0.9984
# Epoch 700: Loss = 0.1858, Residual = 0.1075, Avg Reward = -0.8039, Cosine Similarity = -0.9984
# Epoch 800: Loss = 0.1877, Residual = 0.1075, Avg Reward = -0.2657, Cosine Similarity = -0.9984
# Epoch 900: Loss = 0.1899, Residual = 0.1075, Avg Reward = -0.3891, Cosine Similarity = -0.9984
# Epoch 1000: Loss = 0.1913, Residual = 0.0991, Avg Reward = -0.2307, Cosine Similarity = -0.9999
#
# Predicted eigenvector: [-0.07244193 -0.19496976 -0.48557207  0.10587373 -0.8424663 ]
# True eigenvector: [ 0.06575306  0.1951525   0.48640123 -0.09348938  0.8439583 ]
# Cosine similarity: -0.9999
# Run 9
# True dominant eigenvalue: 5.373892353446345
# Epoch 0: Loss = -0.1938, Residual = 2.6135, Avg Reward = -3.6369, Cosine Similarity = -0.4243
# Epoch 100: Loss = 0.1927, Residual = 0.5691, Avg Reward = -3.7089, Cosine Similarity = -0.9942
# Epoch 200: Loss = 0.1797, Residual = 0.2484, Avg Reward = -3.0524, Cosine Similarity = -0.9976
# Epoch 300: Loss = 0.1801, Residual = 0.2484, Avg Reward = -2.0544, Cosine Similarity = -0.9976
# Epoch 400: Loss = 0.1823, Residual = 0.2484, Avg Reward = -1.3918, Cosine Similarity = -0.9976
# Epoch 500: Loss = 0.1847, Residual = 0.2484, Avg Reward = -1.1731, Cosine Similarity = -0.9976
# Epoch 600: Loss = 0.1892, Residual = 0.1895, Avg Reward = -0.4600, Cosine Similarity = -0.9921
# Epoch 700: Loss = 0.1896, Residual = 0.1895, Avg Reward = -0.2543, Cosine Similarity = -0.9921
# Epoch 800: Loss = 0.1905, Residual = 0.1655, Avg Reward = -0.2775, Cosine Similarity = -0.9985
# Epoch 900: Loss = 0.1943, Residual = 0.1655, Avg Reward = -0.2754, Cosine Similarity = -0.9985
# Epoch 1000: Loss = 0.1965, Residual = 0.1525, Avg Reward = -0.0618, Cosine Similarity = -0.9993
#
# Predicted eigenvector: [-0.7328661  -0.43431094  0.36235553 -0.36284223  0.10642026]
# True eigenvector: [ 0.7301975   0.4570967  -0.36643845  0.3345919  -0.10791351]
# Cosine similarity: -0.9993
# Run 10
# True dominant eigenvalue: 4.770758054926123
# Epoch 0: Loss = 0.3143, Residual = 1.5502, Avg Reward = -2.9389, Cosine Similarity = -0.9225
# Epoch 100: Loss = -0.1420, Residual = 0.4396, Avg Reward = -3.1564, Cosine Similarity = -0.9972
# Epoch 200: Loss = 0.0268, Residual = 0.4396, Avg Reward = -2.4234, Cosine Similarity = -0.9972
# Epoch 300: Loss = 0.0974, Residual = 0.4043, Avg Reward = -1.5476, Cosine Similarity = -0.9951
# Epoch 400: Loss = 0.1912, Residual = 0.2122, Avg Reward = -1.2155, Cosine Similarity = -0.9978
# Epoch 500: Loss = 0.1872, Residual = 0.2122, Avg Reward = -1.0218, Cosine Similarity = -0.9978
# Epoch 600: Loss = 0.1883, Residual = 0.2122, Avg Reward = -0.4447, Cosine Similarity = -0.9978
# Epoch 700: Loss = 0.1888, Residual = 0.1445, Avg Reward = -0.3100, Cosine Similarity = -0.9996
# Epoch 800: Loss = 0.2028, Residual = 0.1302, Avg Reward = -0.1685, Cosine Similarity = -0.9989
# Epoch 900: Loss = 0.1978, Residual = 0.1302, Avg Reward = -0.0600, Cosine Similarity = -0.9989
# Epoch 1000: Loss = 0.1899, Residual = 0.1048, Avg Reward = -0.0825, Cosine Similarity = -0.9994
#
# Predicted eigenvector: [-0.22428897 -0.30726713  0.5286856   0.6512058   0.38949192]
# True eigenvector: [ 0.25503474  0.3072924  -0.53065693 -0.6354044  -0.39394554]
# Cosine similarity: -0.9994
#
# Testing with dimension: 10
# Run 1
# True dominant eigenvalue: 8.434124687291984
# Epoch 0: Loss = 0.2378, Residual = 5.9807, Avg Reward = -7.2820, Cosine Similarity = 0.1027
# Epoch 100: Loss = 0.1403, Residual = 2.4782, Avg Reward = -8.0808, Cosine Similarity = -0.9356
# Epoch 200: Loss = 0.0933, Residual = 2.4187, Avg Reward = -6.2852, Cosine Similarity = -0.9408
# Epoch 300: Loss = 0.1132, Residual = 2.0777, Avg Reward = -5.1578, Cosine Similarity = -0.9365
# Epoch 400: Loss = 0.0695, Residual = 1.6305, Avg Reward = -3.7936, Cosine Similarity = -0.9584
# Epoch 500: Loss = 0.1427, Residual = 1.3565, Avg Reward = -2.3788, Cosine Similarity = -0.9696
# Epoch 600: Loss = 0.1228, Residual = 1.3565, Avg Reward = -1.7612, Cosine Similarity = -0.9696
# Epoch 700: Loss = 0.1232, Residual = 0.9640, Avg Reward = -1.4365, Cosine Similarity = -0.9721
# Epoch 800: Loss = 0.1065, Residual = 0.9135, Avg Reward = -1.2582, Cosine Similarity = -0.9453
# Epoch 900: Loss = 0.1476, Residual = 0.7721, Avg Reward = -0.8947, Cosine Similarity = -0.9766
# Epoch 1000: Loss = 0.1401, Residual = 0.7721, Avg Reward = -0.7025, Cosine Similarity = -0.9766
#
# Predicted eigenvector: [-0.09696396 -0.2544267   0.34901023 -0.24782121 -0.2960121   0.0975131
#  -0.6147827  -0.3579206  -0.03440152 -0.37183493]
# True eigenvector: [ 0.00478194  0.33000505 -0.34739274  0.17982675  0.18375678 -0.01445214
#   0.67683274  0.3845379   0.01373045  0.3129194 ]
# Cosine similarity: -0.9766
# Run 2
# True dominant eigenvalue: 6.9570387559713405
# Epoch 0: Loss = 0.0176, Residual = 5.2482, Avg Reward = -5.7804, Cosine Similarity = 0.5427
# Epoch 100: Loss = 0.0697, Residual = 1.6789, Avg Reward = -7.5346, Cosine Similarity = 0.9580
# Epoch 200: Loss = 0.1045, Residual = 1.6789, Avg Reward = -5.0857, Cosine Similarity = 0.9580
# Epoch 300: Loss = 0.0887, Residual = 1.5579, Avg Reward = -3.3545, Cosine Similarity = 0.9399
# Epoch 400: Loss = 0.1141, Residual = 1.4004, Avg Reward = -2.6969, Cosine Similarity = 0.9680
# Epoch 500: Loss = 0.1174, Residual = 0.7676, Avg Reward = -1.9446, Cosine Similarity = 0.9530
# Epoch 600: Loss = 0.1249, Residual = 0.7676, Avg Reward = -1.5318, Cosine Similarity = 0.9530
# Epoch 700: Loss = 0.1295, Residual = 0.7676, Avg Reward = -1.4435, Cosine Similarity = 0.9530
# Epoch 800: Loss = 0.1339, Residual = 0.7661, Avg Reward = -0.7583, Cosine Similarity = 0.9529
# Epoch 900: Loss = 0.1387, Residual = 0.7661, Avg Reward = -0.6255, Cosine Similarity = 0.9529
# Epoch 1000: Loss = 0.1433, Residual = 0.7661, Avg Reward = -0.4238, Cosine Similarity = 0.9529
#
# Predicted eigenvector: [ 0.30230755  0.13081206 -0.68753326  0.05355183 -0.2951333   0.19820733
#   0.01778169 -0.33435187  0.280032    0.31466419]
# True eigenvector: [ 0.336182    0.00760757 -0.7373785  -0.01673294 -0.27323946  0.18161449
#   0.13319308 -0.15677054  0.3900588   0.20201463]
# Cosine similarity: 0.9529
# Run 3
# True dominant eigenvalue: 7.7664730099102925
# Epoch 0: Loss = -0.1317, Residual = 5.9207, Avg Reward = -7.4433, Cosine Similarity = -0.7927
# Epoch 100: Loss = 0.1073, Residual = 2.8509, Avg Reward = -6.4307, Cosine Similarity = -0.8486
# Epoch 200: Loss = 0.1224, Residual = 2.0067, Avg Reward = -5.0708, Cosine Similarity = -0.9321
# Epoch 300: Loss = 0.1210, Residual = 1.2919, Avg Reward = -4.7511, Cosine Similarity = -0.9397
# Epoch 400: Loss = 0.1172, Residual = 1.2919, Avg Reward = -3.1746, Cosine Similarity = -0.9397
# Epoch 500: Loss = 0.1216, Residual = 1.2919, Avg Reward = -2.5126, Cosine Similarity = -0.9397
# Epoch 600: Loss = 0.1262, Residual = 1.2919, Avg Reward = -2.3962, Cosine Similarity = -0.9397
# Epoch 700: Loss = 0.1300, Residual = 1.0810, Avg Reward = -1.8784, Cosine Similarity = -0.9881
# Epoch 800: Loss = 0.1404, Residual = 0.6658, Avg Reward = -1.0709, Cosine Similarity = -0.9896
# Epoch 900: Loss = 0.1679, Residual = 0.5204, Avg Reward = -1.1685, Cosine Similarity = -0.9980
# Epoch 1000: Loss = 0.1448, Residual = 0.5204, Avg Reward = -0.6211, Cosine Similarity = -0.9980
#
# Predicted eigenvector: [ 0.69852114  0.15163016 -0.0131525   0.21092358 -0.07362604  0.42428422
#  -0.17585331 -0.15898323  0.43508345 -0.11609985]
# True eigenvector: [-0.6992794  -0.135988    0.02010547 -0.22706155  0.09736336 -0.43043134
#   0.12232295  0.15465324 -0.44079587  0.11234797]
# Cosine similarity: -0.9980
# Run 4
# True dominant eigenvalue: 7.229879647225795
# Epoch 0: Loss = -0.3126, Residual = 4.8313, Avg Reward = -7.8009, Cosine Similarity = 0.1992
# Epoch 100: Loss = 0.0786, Residual = 1.9168, Avg Reward = -7.1379, Cosine Similarity = -0.8987
# Epoch 200: Loss = 0.1083, Residual = 1.9168, Avg Reward = -6.4057, Cosine Similarity = -0.8987
# Epoch 300: Loss = 0.1102, Residual = 1.9168, Avg Reward = -4.2588, Cosine Similarity = -0.8987
# Epoch 400: Loss = 0.1137, Residual = 1.9168, Avg Reward = -4.6906, Cosine Similarity = -0.8987
# Epoch 500: Loss = 0.1355, Residual = 1.6075, Avg Reward = -3.5897, Cosine Similarity = -0.9307
# Epoch 600: Loss = 0.1106, Residual = 1.2002, Avg Reward = -2.9733, Cosine Similarity = -0.9415
# Epoch 700: Loss = 0.1251, Residual = 1.2002, Avg Reward = -2.6685, Cosine Similarity = -0.9415
# Epoch 800: Loss = 0.1306, Residual = 1.1116, Avg Reward = -2.0715, Cosine Similarity = -0.9802
# Epoch 900: Loss = 0.1387, Residual = 1.0073, Avg Reward = -1.5010, Cosine Similarity = -0.9682
# Epoch 1000: Loss = 0.1376, Residual = 1.0073, Avg Reward = -1.7109, Cosine Similarity = -0.9682
#
# Predicted eigenvector: [ 0.09107193  0.34871906 -0.19502649 -0.21901047 -0.05463    -0.05096699
#   0.03435326  0.01485673  0.87530833  0.10465397]
# True eigenvector: [-0.08388118 -0.36733133  0.11905175  0.18837312 -0.10295846  0.0562021
#   0.06194568  0.08737298 -0.8591115  -0.21229911]
# Cosine similarity: -0.9682
# Run 5
# True dominant eigenvalue: 9.691438383562812
# Epoch 0: Loss = -0.0178, Residual = 6.4801, Avg Reward = -9.6278, Cosine Similarity = -0.6549
# Epoch 100: Loss = 0.0990, Residual = 4.1910, Avg Reward = -9.8740, Cosine Similarity = 0.8827
# Epoch 200: Loss = 0.1141, Residual = 3.4582, Avg Reward = -7.4229, Cosine Similarity = 0.9085
# Epoch 300: Loss = 0.0609, Residual = 2.4697, Avg Reward = -6.4380, Cosine Similarity = 0.9105
# Epoch 400: Loss = 0.0688, Residual = 2.0238, Avg Reward = -5.1555, Cosine Similarity = 0.9833
# Epoch 500: Loss = 0.1294, Residual = 1.8296, Avg Reward = -3.0024, Cosine Similarity = 0.9688
# Epoch 600: Loss = 0.1594, Residual = 1.6279, Avg Reward = -2.2984, Cosine Similarity = 0.9782
# Epoch 700: Loss = 0.1373, Residual = 1.2226, Avg Reward = -1.6029, Cosine Similarity = 0.9919
# Epoch 800: Loss = 0.1343, Residual = 1.2226, Avg Reward = -1.3854, Cosine Similarity = 0.9919
# Epoch 900: Loss = 0.1390, Residual = 0.8900, Avg Reward = -0.8954, Cosine Similarity = 0.9892
# Epoch 1000: Loss = 0.1441, Residual = 0.8679, Avg Reward = -0.7730, Cosine Similarity = 0.9946
#
# Predicted eigenvector: [-0.15785149  0.41280845  0.3115209   0.04189732  0.13881437 -0.434373
#   0.09666765  0.38576603 -0.56591654  0.13964428]
# True eigenvector: [-0.12742878  0.46554458  0.2912261  -0.00068265  0.12409373 -0.42265534
#   0.13985834  0.41705322 -0.5246007   0.139573  ]
# Cosine similarity: 0.9946
# Run 6
# True dominant eigenvalue: 5.788293060163912
# Epoch 0: Loss = -0.1492, Residual = 4.6810, Avg Reward = -5.0199, Cosine Similarity = 0.1850
# Epoch 100: Loss = 0.0248, Residual = 1.5981, Avg Reward = -4.9728, Cosine Similarity = -0.8651
# Epoch 200: Loss = -0.0202, Residual = 1.5299, Avg Reward = -4.5084, Cosine Similarity = -0.3773
# Epoch 300: Loss = 0.0287, Residual = 1.4550, Avg Reward = -3.2215, Cosine Similarity = -0.0939
# Epoch 400: Loss = 0.1871, Residual = 1.1519, Avg Reward = -2.7203, Cosine Similarity = -0.3737
# Epoch 500: Loss = 0.1183, Residual = 1.0060, Avg Reward = -1.9586, Cosine Similarity = -0.3884
# Epoch 600: Loss = 0.1199, Residual = 0.7771, Avg Reward = -1.3562, Cosine Similarity = -0.1707
# Epoch 700: Loss = 0.1767, Residual = 0.7257, Avg Reward = -1.1078, Cosine Similarity = -0.6072
# Epoch 800: Loss = 0.1303, Residual = 0.7257, Avg Reward = -0.7868, Cosine Similarity = -0.6072
# Epoch 900: Loss = 0.1603, Residual = 0.6514, Avg Reward = -0.6962, Cosine Similarity = -0.4506
# Epoch 1000: Loss = 0.1413, Residual = 0.6433, Avg Reward = -0.6405, Cosine Similarity = -0.3291
#
# Predicted eigenvector: [-0.4749685   0.30808988  0.20971908  0.05100995 -0.19224471  0.18438594
#  -0.01569442  0.29490754 -0.6707691  -0.15747178]
# True eigenvector: [-0.16424383 -0.23728068 -0.6377609  -0.15802273 -0.01578319 -0.39198864
#   0.00795386 -0.16113724  0.23016892 -0.5020969 ]
# Cosine similarity: -0.3291
# Run 7
# True dominant eigenvalue: -6.832695085515021
# Epoch 0: Loss = 0.4284, Residual = 4.6085, Avg Reward = -4.9215, Cosine Similarity = -0.5261
# Epoch 100: Loss = 0.2245, Residual = 2.0221, Avg Reward = -6.3223, Cosine Similarity = -0.8204
# Epoch 200: Loss = 0.2005, Residual = 1.5906, Avg Reward = -4.5649, Cosine Similarity = -0.7312
# Epoch 300: Loss = 0.1120, Residual = 0.6611, Avg Reward = -2.7947, Cosine Similarity = -0.9578
# Epoch 400: Loss = 0.1141, Residual = 0.6611, Avg Reward = -1.8615, Cosine Similarity = -0.9578
# Epoch 500: Loss = 0.1184, Residual = 0.6611, Avg Reward = -1.6298, Cosine Similarity = -0.9578
# Epoch 600: Loss = 0.1227, Residual = 0.6611, Avg Reward = -1.2592, Cosine Similarity = -0.9578
# Epoch 700: Loss = 0.1271, Residual = 0.6611, Avg Reward = -0.9164, Cosine Similarity = -0.9578
# Epoch 800: Loss = 0.1352, Residual = 0.5780, Avg Reward = -0.6562, Cosine Similarity = -0.9723
# Epoch 900: Loss = 0.1400, Residual = 0.4779, Avg Reward = -0.4285, Cosine Similarity = -0.9771
# Epoch 1000: Loss = 0.1404, Residual = 0.4779, Avg Reward = -0.3766, Cosine Similarity = -0.9771
#
# Predicted eigenvector: [ 0.18834874  0.53126854 -0.1853024  -0.25130078  0.04972152 -0.0085036
#   0.26811713  0.5432432   0.36026657  0.29232317]
# True eigenvector: [-0.2036526  -0.6158385   0.15340176  0.27434552  0.02143892 -0.07038869
#  -0.28123742 -0.39384    -0.4107429  -0.2685938 ]
# Cosine similarity: -0.9771
# Run 8
# True dominant eigenvalue: 7.782450878761922
# Epoch 0: Loss = 0.2651, Residual = 5.5501, Avg Reward = -7.1546, Cosine Similarity = -0.2635
# Epoch 100: Loss = 0.0634, Residual = 2.1481, Avg Reward = -5.4895, Cosine Similarity = -0.6566
# Epoch 200: Loss = 0.1467, Residual = 1.6685, Avg Reward = -3.8879, Cosine Similarity = -0.6847
# Epoch 300: Loss = 0.1303, Residual = 1.3752, Avg Reward = -3.5453, Cosine Similarity = -0.9326
# Epoch 400: Loss = 0.1181, Residual = 1.1723, Avg Reward = -2.3545, Cosine Similarity = -0.8981
# Epoch 500: Loss = 0.1225, Residual = 1.0108, Avg Reward = -1.4759, Cosine Similarity = -0.8917
# Epoch 600: Loss = 0.1002, Residual = 0.7710, Avg Reward = -1.2596, Cosine Similarity = -0.9843
# Epoch 700: Loss = 0.1650, Residual = 0.6384, Avg Reward = -0.8178, Cosine Similarity = -0.9905
# Epoch 800: Loss = 0.1370, Residual = 0.6384, Avg Reward = -0.4328, Cosine Similarity = -0.9905
# Epoch 900: Loss = 0.1413, Residual = 0.6384, Avg Reward = -0.3176, Cosine Similarity = -0.9905
# Epoch 1000: Loss = 0.1462, Residual = 0.5661, Avg Reward = -0.3263, Cosine Similarity = -0.9780
#
# Predicted eigenvector: [ 0.20616668 -0.18606092 -0.40326136 -0.18636657  0.2936212   0.44474885
#  -0.25307804  0.07764957  0.4159122   0.44547558]
# True eigenvector: [-0.24257033  0.2759627   0.35381913  0.22680597 -0.28655127 -0.48938188
#   0.10273583 -0.05247561 -0.35185766 -0.47922528]
# Cosine similarity: -0.9780
# Run 9
# True dominant eigenvalue: -8.849979693407132
# Epoch 0: Loss = 0.2436, Residual = 5.4150, Avg Reward = -8.8920, Cosine Similarity = -0.3382
# Epoch 100: Loss = 0.1081, Residual = 3.4971, Avg Reward = -7.5201, Cosine Similarity = -0.8793
# Epoch 200: Loss = 0.1134, Residual = 3.3924, Avg Reward = -7.8061, Cosine Similarity = -0.9004
# Epoch 300: Loss = 0.0949, Residual = 1.9252, Avg Reward = -5.5337, Cosine Similarity = -0.9775
# Epoch 400: Loss = 0.1141, Residual = 1.9252, Avg Reward = -4.4781, Cosine Similarity = -0.9775
# Epoch 500: Loss = 0.1635, Residual = 1.7406, Avg Reward = -2.7553, Cosine Similarity = -0.9850
# Epoch 600: Loss = 0.1236, Residual = 1.2504, Avg Reward = -2.6246, Cosine Similarity = -0.9684
# Epoch 700: Loss = 0.1271, Residual = 1.2324, Avg Reward = -1.1533, Cosine Similarity = -0.9836
# Epoch 800: Loss = 0.1335, Residual = 0.9859, Avg Reward = -1.3200, Cosine Similarity = -0.9917
# Epoch 900: Loss = 0.1375, Residual = 0.8729, Avg Reward = -1.3397, Cosine Similarity = -0.9952
# Epoch 1000: Loss = 0.1422, Residual = 0.6085, Avg Reward = -0.5559, Cosine Similarity = -0.9974
#
# Predicted eigenvector: [-0.24853094  0.5824917   0.02872289  0.30740336 -0.54691166 -0.30031815
#   0.15620765  0.04428008  0.17769046 -0.23743458]
# True eigenvector: [ 0.25878435 -0.60946137 -0.01877905 -0.313479    0.49995947  0.28984
#  -0.19402651 -0.02064098 -0.18013975  0.24181892]
# Cosine similarity: -0.9974
# Run 10
# True dominant eigenvalue: 8.466952712003538
# Epoch 0: Loss = -0.1459, Residual = 3.3514, Avg Reward = -7.1162, Cosine Similarity = -0.7909
# Epoch 100: Loss = 0.4073, Residual = 2.4880, Avg Reward = -7.4679, Cosine Similarity = -0.2852
# Epoch 200: Loss = 0.1090, Residual = 2.0965, Avg Reward = -6.4963, Cosine Similarity = -0.2280
# Epoch 300: Loss = 0.1087, Residual = 2.0965, Avg Reward = -5.4186, Cosine Similarity = -0.2280
# Epoch 400: Loss = 0.1445, Residual = 1.8510, Avg Reward = -4.5722, Cosine Similarity = -0.2672
# Epoch 500: Loss = 0.1202, Residual = 1.8510, Avg Reward = -3.3552, Cosine Similarity = -0.2672
# Epoch 600: Loss = -0.0266, Residual = 1.6688, Avg Reward = -3.0112, Cosine Similarity = 0.2736
# Epoch 700: Loss = 0.1212, Residual = 1.5633, Avg Reward = -1.7780, Cosine Similarity = 0.5006
# Epoch 800: Loss = 0.1187, Residual = 1.2496, Avg Reward = -1.5792, Cosine Similarity = 0.6220
# Epoch 900: Loss = 0.1256, Residual = 1.1106, Avg Reward = -1.1673, Cosine Similarity = 0.6637
# Epoch 1000: Loss = 0.1545, Residual = 0.9619, Avg Reward = -0.9033, Cosine Similarity = 0.7681
#
# Predicted eigenvector: [-0.06665526 -0.44774264 -0.10496279  0.49201724 -0.30144683  0.43541738
#   0.4129492   0.23492318 -0.18241231 -0.05036644]
# True eigenvector: [ 0.42760032 -0.27970538  0.02285787  0.45978206  0.07934353  0.4281749
#   0.45392868  0.26257393 -0.22598548  0.10632937]
# Cosine similarity: 0.7681
#
# Testing with dimension: 20
# Run 1
# True dominant eigenvalue: 12.13752778870516
# Epoch 0: Loss = 0.1508, Residual = 10.6243, Avg Reward = -12.4669, Cosine Similarity = 0.6702
# Epoch 100: Loss = -0.0201, Residual = 6.7495, Avg Reward = -11.7663, Cosine Similarity = 0.6895
# Epoch 200: Loss = -0.0748, Residual = 5.7162, Avg Reward = -9.8194, Cosine Similarity = 0.6571
# Epoch 300: Loss = -0.0183, Residual = 5.1124, Avg Reward = -8.2347, Cosine Similarity = 0.8418
# Epoch 400: Loss = -0.0349, Residual = 3.8913, Avg Reward = -5.8217, Cosine Similarity = 0.9088
# Epoch 500: Loss = -0.0012, Residual = 3.1847, Avg Reward = -3.8930, Cosine Similarity = 0.9438
# Epoch 600: Loss = -0.0005, Residual = 2.3543, Avg Reward = -2.8738, Cosine Similarity = 0.9602
# Epoch 700: Loss = 0.0061, Residual = 2.1260, Avg Reward = -1.8575, Cosine Similarity = 0.9889
# Epoch 800: Loss = 0.0081, Residual = 2.1260, Avg Reward = -1.4824, Cosine Similarity = 0.9889
# Epoch 900: Loss = 0.0163, Residual = 1.7982, Avg Reward = -1.0341, Cosine Similarity = 0.9780
# Epoch 1000: Loss = 0.0250, Residual = 1.7982, Avg Reward = -0.6718, Cosine Similarity = 0.9780
#
# Predicted eigenvector: [ 0.4064867  -0.12525533 -0.33760723  0.00077592  0.12159152  0.23344705
#   0.04910453  0.22256556 -0.12599093 -0.26717615  0.35650036 -0.1545183
#  -0.18598801 -0.12082292 -0.3413543   0.0503105   0.20381711  0.07159302
#   0.36043876  0.02863388]
# True eigenvector: [ 0.4341917  -0.20934606 -0.28867355  0.06430755  0.1309656   0.21866108
#  -0.00724671  0.18218873 -0.00963409 -0.2891243   0.38928267 -0.16315661
#  -0.17204386 -0.13124087 -0.34502894 -0.0011866   0.23298451  0.10441063
#   0.29845035  0.00126923]
# Cosine similarity: 0.9780
# Run 2
# True dominant eigenvalue: 11.792995356479528
# Epoch 0: Loss = 0.2483, Residual = 7.2327, Avg Reward = -10.2075, Cosine Similarity = -0.4257
# Epoch 100: Loss = -0.0186, Residual = 5.9122, Avg Reward = -9.5062, Cosine Similarity = 0.2261
# Epoch 200: Loss = -0.0335, Residual = 4.5940, Avg Reward = -8.4457, Cosine Similarity = 0.1974
# Epoch 300: Loss = -0.0368, Residual = 3.5628, Avg Reward = -6.7742, Cosine Similarity = 0.7492
# Epoch 400: Loss = 0.0471, Residual = 3.3759, Avg Reward = -5.0030, Cosine Similarity = 0.8305
# Epoch 500: Loss = 0.0386, Residual = 2.6732, Avg Reward = -4.0194, Cosine Similarity = 0.8055
# Epoch 600: Loss = -0.0054, Residual = 2.6517, Avg Reward = -2.8710, Cosine Similarity = 0.8294
# Epoch 700: Loss = 0.0025, Residual = 2.2112, Avg Reward = -2.1338, Cosine Similarity = 0.8001
# Epoch 800: Loss = 0.0088, Residual = 2.1238, Avg Reward = -1.4343, Cosine Similarity = 0.8991
# Epoch 900: Loss = 0.0223, Residual = 1.9645, Avg Reward = -1.0082, Cosine Similarity = 0.9363
# Epoch 1000: Loss = 0.0264, Residual = 1.5687, Avg Reward = -0.8455, Cosine Similarity = 0.9243
#
# Predicted eigenvector: [-0.24110061 -0.11811797 -0.27239034 -0.47924343 -0.25921813 -0.0376846
#  -0.2057008   0.16938247 -0.01205848  0.33263606  0.32849774 -0.2075452
#  -0.05306565 -0.09349085  0.25605673 -0.02783193  0.10516987  0.14643055
#  -0.12306308  0.3116237 ]
# True eigenvector: [-0.26574183 -0.00318084 -0.28389847 -0.41239414 -0.26986372 -0.05053278
#  -0.17878024  0.21030043 -0.02746586  0.30924687  0.27507493 -0.32039082
#   0.11685577 -0.13439171  0.02772296 -0.07748182  0.25236908  0.075528
#  -0.14116813  0.3530146 ]
# Cosine similarity: 0.9243
# Run 3
# True dominant eigenvalue: -12.699189898519137
# Epoch 0: Loss = 0.1985, Residual = 8.9248, Avg Reward = -11.3060, Cosine Similarity = -0.7604
# Epoch 100: Loss = -0.0372, Residual = 7.2342, Avg Reward = -11.2474, Cosine Similarity = -0.7489
# Epoch 200: Loss = -0.0317, Residual = 6.8444, Avg Reward = -11.0016, Cosine Similarity = -0.7244
# Epoch 300: Loss = -0.0216, Residual = 6.0393, Avg Reward = -8.2098, Cosine Similarity = -0.8267
# Epoch 400: Loss = -0.0560, Residual = 4.3718, Avg Reward = -6.3111, Cosine Similarity = -0.8743
# Epoch 500: Loss = 0.0032, Residual = 3.5018, Avg Reward = -4.3260, Cosine Similarity = -0.9560
# Epoch 600: Loss = -0.0060, Residual = 3.1195, Avg Reward = -2.8628, Cosine Similarity = -0.9411
# Epoch 700: Loss = -0.0033, Residual = 2.4891, Avg Reward = -2.2757, Cosine Similarity = -0.9546
# Epoch 800: Loss = 0.0088, Residual = 2.4891, Avg Reward = -1.6329, Cosine Similarity = -0.9546
# Epoch 900: Loss = 0.0156, Residual = 1.8716, Avg Reward = -1.3735, Cosine Similarity = -0.9578
# Epoch 1000: Loss = 0.0253, Residual = 1.5011, Avg Reward = -1.1988, Cosine Similarity = -0.9846
#
# Predicted eigenvector: [-0.49636048  0.09515995  0.15576082 -0.26561972  0.10076112  0.15825565
#  -0.11262279  0.34586483 -0.0346995  -0.40458974  0.26720923 -0.21212755
#   0.23895694  0.03435732 -0.14431791  0.05272813  0.02892774 -0.20163828
#   0.27231807  0.05843822]
# True eigenvector: [ 0.5138087  -0.13013537 -0.15949686  0.20729794 -0.12190111 -0.16748257
#   0.0991952  -0.38408712 -0.02740024  0.39273208 -0.27412617  0.17481256
#  -0.2536199   0.01925739  0.13250768  0.05128469 -0.0704141   0.15234864
#  -0.27216503 -0.0506222 ]
# Cosine similarity: -0.9846
# Run 4
# True dominant eigenvalue: -12.12776278776846
# Epoch 0: Loss = -0.3180, Residual = 10.8003, Avg Reward = -10.8389, Cosine Similarity = 0.4334
# Epoch 100: Loss = -0.1425, Residual = 8.2784, Avg Reward = -11.3447, Cosine Similarity = -0.1565
# Epoch 200: Loss = -0.1662, Residual = 6.7737, Avg Reward = -9.6156, Cosine Similarity = -0.5103
# Epoch 300: Loss = -0.0798, Residual = 5.5178, Avg Reward = -8.2397, Cosine Similarity = -0.5069
# Epoch 400: Loss = 0.0662, Residual = 4.2634, Avg Reward = -7.4502, Cosine Similarity = -0.8554
# Epoch 500: Loss = 0.0254, Residual = 3.8513, Avg Reward = -5.1087, Cosine Similarity = -0.8756
# Epoch 600: Loss = -0.0044, Residual = 3.2722, Avg Reward = -3.4245, Cosine Similarity = -0.8272
# Epoch 700: Loss = 0.0226, Residual = 2.9288, Avg Reward = -3.0862, Cosine Similarity = -0.9317
# Epoch 800: Loss = -0.0009, Residual = 2.9024, Avg Reward = -2.6281, Cosine Similarity = -0.9413
# Epoch 900: Loss = 0.0129, Residual = 2.3324, Avg Reward = -1.7334, Cosine Similarity = -0.9812
# Epoch 1000: Loss = 0.0192, Residual = 2.2857, Avg Reward = -1.4589, Cosine Similarity = -0.9765
#
# Predicted eigenvector: [ 0.16436939  0.2666481   0.4037326   0.6287265   0.05095444  0.05616806
#   0.07456936 -0.01275771 -0.37756187 -0.17651908 -0.10560072  0.21300396
#   0.03359143 -0.05688298  0.1309468  -0.09696832 -0.06902851  0.0144859
#  -0.25586367 -0.02282098]
# True eigenvector: [-0.19867696 -0.29258943 -0.36432478 -0.61905146 -0.1117505  -0.14333563
#  -0.07527313  0.07662017  0.31258363  0.10966676  0.03445029 -0.20006792
#  -0.08407902  0.11236104 -0.14452928  0.15921777  0.11200979 -0.01941109
#   0.29037154 -0.01644586]
# Cosine similarity: -0.9765
# Run 5
# True dominant eigenvalue: 12.372012577230297
# Epoch 0: Loss = -0.1968, Residual = 10.0930, Avg Reward = -11.9939, Cosine Similarity = 0.1910
# Epoch 100: Loss = -0.0510, Residual = 6.2903, Avg Reward = -11.0035, Cosine Similarity = -0.4007
# Epoch 200: Loss = -0.0427, Residual = 6.2615, Avg Reward = -12.3283, Cosine Similarity = -0.5892
# Epoch 300: Loss = -0.0283, Residual = 6.0470, Avg Reward = -7.7833, Cosine Similarity = -0.3781
# Epoch 400: Loss = -0.0205, Residual = 3.9112, Avg Reward = -6.5174, Cosine Similarity = -0.7636
# Epoch 500: Loss = -0.0151, Residual = 3.9112, Avg Reward = -5.1626, Cosine Similarity = -0.7636
# Epoch 600: Loss = 0.0060, Residual = 2.7137, Avg Reward = -3.5798, Cosine Similarity = -0.8621
# Epoch 700: Loss = -0.0008, Residual = 2.7137, Avg Reward = -2.7971, Cosine Similarity = -0.8621
# Epoch 800: Loss = -0.0246, Residual = 2.5060, Avg Reward = -2.1369, Cosine Similarity = -0.9366
# Epoch 900: Loss = 0.0155, Residual = 2.1627, Avg Reward = -1.4024, Cosine Similarity = -0.9752
# Epoch 1000: Loss = 0.0235, Residual = 1.9983, Avg Reward = -1.0049, Cosine Similarity = -0.9676
#
# Predicted eigenvector: [-0.0614255   0.0419444   0.26704738 -0.18869364  0.0721089  -0.27740926
#   0.3363629  -0.05772044  0.41666374  0.03656166  0.16200103  0.40091437
#  -0.16711633  0.18909523  0.08517743 -0.04251482 -0.37961152 -0.24767442
#  -0.06920443 -0.2097957 ]
# True eigenvector: [ 0.11477091  0.04151045 -0.2355129   0.20075725 -0.00062532  0.25846627
#  -0.31755096 -0.04570844 -0.44883564 -0.09587282 -0.26329514 -0.41577148
#   0.15595451 -0.10418654 -0.02620465  0.00625165  0.3038831   0.2378917
#   0.08992708  0.2717345 ]
# Cosine similarity: -0.9676
# Run 6
# True dominant eigenvalue: 14.5444624751616
# Epoch 0: Loss = -0.1282, Residual = 13.0612, Avg Reward = -14.2752, Cosine Similarity = 0.0481
# Epoch 100: Loss = 0.0210, Residual = 8.0120, Avg Reward = -13.5930, Cosine Similarity = 0.7847
# Epoch 200: Loss = -0.0465, Residual = 6.5276, Avg Reward = -11.4437, Cosine Similarity = 0.7602
# Epoch 300: Loss = -0.0647, Residual = 5.9965, Avg Reward = -8.7086, Cosine Similarity = 0.8440
# Epoch 400: Loss = 0.0152, Residual = 4.8838, Avg Reward = -7.3735, Cosine Similarity = 0.9384
# Epoch 500: Loss = -0.0028, Residual = 3.8617, Avg Reward = -4.6819, Cosine Similarity = 0.9563
# Epoch 600: Loss = -0.0040, Residual = 3.2842, Avg Reward = -3.0246, Cosine Similarity = 0.9729
# Epoch 700: Loss = -0.0061, Residual = 3.1530, Avg Reward = -2.3005, Cosine Similarity = 0.9663
# Epoch 800: Loss = 0.0234, Residual = 2.5065, Avg Reward = -1.5864, Cosine Similarity = 0.9812
# Epoch 900: Loss = 0.0157, Residual = 2.4453, Avg Reward = -1.3342, Cosine Similarity = 0.9802
# Epoch 1000: Loss = 0.0527, Residual = 2.1569, Avg Reward = -0.9695, Cosine Similarity = 0.9820
#
# Predicted eigenvector: [-0.01550141 -0.12213778  0.12558842 -0.13129596  0.03098907  0.44400203
#  -0.10960996 -0.29993042  0.02076878  0.32690832  0.06260304 -0.16679437
#   0.35304105 -0.28813165  0.27351952  0.00730047 -0.1629895  -0.05763034
#   0.38035262  0.23588422]
# True eigenvector: [-0.03431972 -0.1365874   0.12653309 -0.15668954  0.01720235  0.47787985
#  -0.0611393  -0.26191106  0.01934596  0.30681854  0.03709233 -0.12719384
#   0.33949697 -0.30399182  0.25526866  0.08742383 -0.2670446   0.02329445
#   0.33291352  0.25174636]
# Cosine similarity: 0.9820
# Run 7
# True dominant eigenvalue: -12.679662228636035
# Epoch 0: Loss = 0.4016, Residual = 8.5891, Avg Reward = -11.2408, Cosine Similarity = 0.1325
# Epoch 100: Loss = 0.1499, Residual = 7.3542, Avg Reward = -12.4242, Cosine Similarity = 0.1640
# Epoch 200: Loss = 0.0110, Residual = 7.2069, Avg Reward = -11.3438, Cosine Similarity = 0.3628
# Epoch 300: Loss = -0.0252, Residual = 5.4911, Avg Reward = -12.0544, Cosine Similarity = -0.7142
# Epoch 400: Loss = -0.0235, Residual = 4.7323, Avg Reward = -6.6753, Cosine Similarity = -0.4194
# Epoch 500: Loss = -0.0523, Residual = 4.3262, Avg Reward = -5.7059, Cosine Similarity = -0.5199
# Epoch 600: Loss = -0.0342, Residual = 3.2392, Avg Reward = -4.2964, Cosine Similarity = -0.7254
# Epoch 700: Loss = 0.0179, Residual = 2.8773, Avg Reward = -3.2306, Cosine Similarity = -0.8079
# Epoch 800: Loss = -0.0227, Residual = 2.4108, Avg Reward = -2.2975, Cosine Similarity = -0.8740
# Epoch 900: Loss = 0.0083, Residual = 2.4108, Avg Reward = -1.6707, Cosine Similarity = -0.8740
# Epoch 1000: Loss = 0.0259, Residual = 2.0280, Avg Reward = -1.2498, Cosine Similarity = -0.8749
#
# Predicted eigenvector: [-0.06453039  0.32137161  0.03238906 -0.39357227 -0.19411948  0.03063829
#  -0.4462965  -0.30970928 -0.15145051 -0.15651251  0.17115949  0.13803624
#   0.21480836 -0.00962199 -0.32658082 -0.14420816  0.10100774  0.24114136
#   0.22273017  0.1243257 ]
# True eigenvector: [ 0.280123   -0.16973507 -0.05208358  0.48206863  0.2587883  -0.20515552
#   0.40503383  0.29753903  0.1010261   0.12712029 -0.09125181  0.14177655
#  -0.07436644 -0.00219288  0.32957447  0.0754884  -0.13304135 -0.28619447
#  -0.08067251 -0.12334722]
# Cosine similarity: -0.8749
# Run 8
# True dominant eigenvalue: 11.488665803556543
# Epoch 0: Loss = 0.1112, Residual = 9.1682, Avg Reward = -12.0168, Cosine Similarity = 0.1028
# Epoch 100: Loss = -0.0505, Residual = 5.9122, Avg Reward = -10.9771, Cosine Similarity = -0.1694
# Epoch 200: Loss = -0.1374, Residual = 5.6942, Avg Reward = -9.1262, Cosine Similarity = -0.1547
# Epoch 300: Loss = -0.0224, Residual = 4.9921, Avg Reward = -7.5503, Cosine Similarity = -0.1649
# Epoch 400: Loss = -0.0273, Residual = 4.3273, Avg Reward = -6.1542, Cosine Similarity = -0.1256
# Epoch 500: Loss = -0.0320, Residual = 4.0313, Avg Reward = -5.4780, Cosine Similarity = -0.0123
# Epoch 600: Loss = -0.0088, Residual = 4.0313, Avg Reward = -4.8955, Cosine Similarity = -0.0123
# Epoch 700: Loss = 0.0347, Residual = 3.5805, Avg Reward = -4.6377, Cosine Similarity = -0.4518
# Epoch 800: Loss = -0.0181, Residual = 2.9755, Avg Reward = -3.8183, Cosine Similarity = -0.4557
# Epoch 900: Loss = 0.0145, Residual = 2.8506, Avg Reward = -3.4252, Cosine Similarity = -0.4729
# Epoch 1000: Loss = -0.0177, Residual = 2.7944, Avg Reward = -2.7808, Cosine Similarity = -0.6044
#
# Predicted eigenvector: [-0.02683664 -0.13745978  0.2845497  -0.49492747  0.13854565 -0.20604253
#  -0.13159412  0.21690823 -0.37321874 -0.27294412  0.01468929  0.0538356
#   0.2773895   0.16064872 -0.04348342 -0.33684728 -0.265797    0.14612885
#   0.01700767 -0.033803  ]
# True eigenvector: [ 0.17488721  0.2742256  -0.3403836   0.27181464  0.32726252 -0.00950982
#   0.17652552 -0.35083145  0.24610771 -0.12804033 -0.17355248  0.09252033
#   0.12879372 -0.25849348  0.02063526  0.37180766  0.23092374 -0.19737488
#  -0.11417218 -0.00051596]
# Cosine similarity: -0.6044
# Run 9
# True dominant eigenvalue: 12.296934121233342
# Epoch 0: Loss = 0.3427, Residual = 9.2402, Avg Reward = -11.1847, Cosine Similarity = 0.1075
# Epoch 100: Loss = -0.0534, Residual = 7.5001, Avg Reward = -11.9832, Cosine Similarity = -0.0633
# Epoch 200: Loss = -0.0404, Residual = 6.8695, Avg Reward = -9.9118, Cosine Similarity = -0.7582
# Epoch 300: Loss = 0.0029, Residual = 6.3065, Avg Reward = -8.3380, Cosine Similarity = -0.7490
# Epoch 400: Loss = -0.0359, Residual = 4.3105, Avg Reward = -7.4405, Cosine Similarity = -0.8658
# Epoch 500: Loss = -0.0635, Residual = 3.2462, Avg Reward = -4.9685, Cosine Similarity = -0.9569
# Epoch 600: Loss = 0.0024, Residual = 3.2327, Avg Reward = -3.5382, Cosine Similarity = -0.9517
# Epoch 700: Loss = -0.0013, Residual = 2.7202, Avg Reward = -2.3627, Cosine Similarity = -0.9477
# Epoch 800: Loss = 0.0080, Residual = 2.2521, Avg Reward = -2.1519, Cosine Similarity = -0.9753
# Epoch 900: Loss = 0.0161, Residual = 2.1829, Avg Reward = -1.4241, Cosine Similarity = -0.9716
# Epoch 1000: Loss = 0.0290, Residual = 1.9679, Avg Reward = -1.3174, Cosine Similarity = -0.9819
#
# Predicted eigenvector: [ 0.06125556  0.4782234  -0.02169312  0.1328556   0.15957458  0.03878199
#   0.27376235 -0.41943732  0.3409196   0.05372129  0.05449817 -0.09824876
#   0.02459522 -0.22442524  0.187574    0.1547667  -0.06312138 -0.03102226
#  -0.08467467 -0.46650553]
# True eigenvector: [-0.11910679 -0.44583485  0.05070347 -0.07427812 -0.24100307 -0.10652218
#  -0.27301693  0.4412449  -0.3798683   0.02448968 -0.02595347  0.08316194
#   0.00670451  0.16322091 -0.19094911 -0.12797819  0.06020357  0.04156242
#   0.10988887  0.43686312]
# Cosine similarity: -0.9819
# Run 10
# True dominant eigenvalue: -11.023945224302356
# Epoch 0: Loss = -0.1542, Residual = 9.0628, Avg Reward = -10.8279, Cosine Similarity = 0.2331
# Epoch 100: Loss = -0.0291, Residual = 5.8953, Avg Reward = -9.8052, Cosine Similarity = -0.2585
# Epoch 200: Loss = -0.0616, Residual = 5.7515, Avg Reward = -9.4118, Cosine Similarity = -0.2024
# Epoch 300: Loss = -0.0502, Residual = 4.5446, Avg Reward = -7.5577, Cosine Similarity = 0.0760
# Epoch 400: Loss = -0.0068, Residual = 3.1567, Avg Reward = -6.1460, Cosine Similarity = -0.1408
# Epoch 500: Loss = -0.0149, Residual = 3.1567, Avg Reward = -4.7517, Cosine Similarity = -0.1408
# Epoch 600: Loss = -0.0078, Residual = 3.0509, Avg Reward = -3.5996, Cosine Similarity = -0.1202
# Epoch 700: Loss = -0.0001, Residual = 2.5877, Avg Reward = -2.8154, Cosine Similarity = -0.2071
# Epoch 800: Loss = 0.0079, Residual = 2.5877, Avg Reward = -2.5747, Cosine Similarity = -0.2071
# Epoch 900: Loss = 0.0017, Residual = 2.3335, Avg Reward = -2.3761, Cosine Similarity = -0.1245
# Epoch 1000: Loss = 0.0238, Residual = 2.1459, Avg Reward = -1.9476, Cosine Similarity = -0.4136
#
# Predicted eigenvector: [-0.37413996  0.15855871  0.27575076  0.3288809   0.11761809 -0.25631687
#   0.21493842 -0.03339721 -0.14921811  0.13267149 -0.14183424  0.28188974
#   0.3155207  -0.32683322 -0.12231915 -0.17337626  0.16368239  0.29442158
#   0.13945442 -0.00814827]
# True eigenvector: [-0.04876703  0.06414454 -0.29897493 -0.20675749  0.07633499 -0.20538656
#  -0.14580138  0.09702146  0.18026002  0.40559196  0.38583714 -0.26792833
#  -0.19536923  0.10833009  0.22030962  0.08968865 -0.07073179  0.02058636
#  -0.49999285  0.0559622 ]
# Cosine similarity: -0.4136
#
# Testing with dimension: 50
# Run 1
# True dominant eigenvalue: -18.309163104117196
# Epoch 0: Loss = -0.3646, Residual = 17.8293, Avg Reward = -17.0032, Cosine Similarity = 0.1210
# Epoch 100: Loss = -0.4622, Residual = 13.2569, Avg Reward = -19.9901, Cosine Similarity = 0.4350
# Epoch 200: Loss = -0.3872, Residual = 13.0294, Avg Reward = -20.3888, Cosine Similarity = 0.2802
# Epoch 300: Loss = -0.4152, Residual = 12.7130, Avg Reward = -16.1256, Cosine Similarity = 0.5094
# Epoch 400: Loss = -0.3867, Residual = 11.0610, Avg Reward = -15.1269, Cosine Similarity = 0.5790
# Epoch 500: Loss = -0.4917, Residual = 9.7941, Avg Reward = -11.1534, Cosine Similarity = 0.7021
# Epoch 600: Loss = -0.4475, Residual = 7.9362, Avg Reward = -6.8379, Cosine Similarity = 0.7678
# Epoch 700: Loss = -0.4134, Residual = 6.6259, Avg Reward = -5.2332, Cosine Similarity = 0.8936
# Epoch 800: Loss = -0.4021, Residual = 6.2727, Avg Reward = -3.9794, Cosine Similarity = 0.8802
# Epoch 900: Loss = -0.3817, Residual = 5.2989, Avg Reward = -3.1016, Cosine Similarity = 0.9076
# Epoch 1000: Loss = -0.3846, Residual = 4.1854, Avg Reward = -2.6288, Cosine Similarity = 0.9551
#
# Predicted eigenvector: [ 0.02306938  0.24808453  0.01786021  0.35511714  0.06037348 -0.09144384
#  -0.1193112   0.16134894  0.16449402 -0.00127123  0.24914034  0.06190502
#   0.18355986  0.08362179  0.08359393 -0.08210316  0.03319404 -0.10600162
#  -0.10387967  0.09252337  0.0876212   0.17109904  0.16622803  0.12390758
#  -0.38924196  0.17836529  0.14414805 -0.09880538 -0.19802874  0.07073145
#  -0.02533327  0.1595833  -0.0862564   0.08973453 -0.16149028 -0.20972489
#   0.11471713  0.03646786 -0.01117105  0.04411327  0.0597323   0.22688612
#   0.06151346  0.13816044  0.06457511  0.10281335 -0.09741097 -0.0942603
#  -0.00836667  0.05294573]
# True eigenvector: [ 7.0144556e-02  2.3694950e-01 -2.7057820e-04  3.7316194e-01
#   4.0039241e-02 -1.4821376e-01 -1.3440344e-01  1.5959658e-01
#   2.2806735e-01 -6.6017076e-02  2.6073429e-01  7.7691898e-02
#   1.7903703e-01  1.0755868e-02  9.6419506e-02 -8.5178077e-02
#   6.5761812e-02  1.9607400e-03 -1.1657257e-01  7.2010152e-02
#   8.4795028e-02  1.9913188e-01  1.7656724e-01  1.3650568e-01
#  -3.4119797e-01  1.7780972e-01  6.2269531e-02  4.1738609e-03
#  -1.9156259e-01  8.5678697e-03 -8.5545115e-02  2.0996389e-01
#  -3.9924104e-02  1.0473090e-01 -2.3401485e-01 -1.1599326e-01
#   9.2432670e-02  2.5935834e-02  8.7241773e-03  3.5824675e-02
#   7.5428537e-03  2.1342784e-01  5.7518564e-02  1.5087014e-01
#   9.8857172e-02  7.7462643e-02 -7.7500112e-02 -5.5015210e-02
#  -8.2355076e-03  7.5504884e-02]
# Cosine similarity: 0.9551
# Run 2
# True dominant eigenvalue: -18.457496973039696
# Epoch 0: Loss = -0.4102, Residual = 18.2389, Avg Reward = -18.5621, Cosine Similarity = -0.3346
# Epoch 100: Loss = -0.4712, Residual = 14.9188, Avg Reward = -19.2454, Cosine Similarity = 0.2097
# Epoch 200: Loss = -0.3180, Residual = 13.1519, Avg Reward = -18.8070, Cosine Similarity = -0.1091
# Epoch 300: Loss = -0.4840, Residual = 12.7332, Avg Reward = -16.7538, Cosine Similarity = -0.3152
# Epoch 400: Loss = -0.4548, Residual = 11.8306, Avg Reward = -14.6574, Cosine Similarity = -0.0164
# Epoch 500: Loss = -0.4233, Residual = 11.0022, Avg Reward = -12.1555, Cosine Similarity = -0.0228
# Epoch 600: Loss = -0.4506, Residual = 8.9767, Avg Reward = -9.6582, Cosine Similarity = -0.1153
# Epoch 700: Loss = -0.4101, Residual = 7.2549, Avg Reward = -7.0962, Cosine Similarity = -0.3521
# Epoch 800: Loss = -0.4113, Residual = 6.5556, Avg Reward = -5.6432, Cosine Similarity = -0.3295
# Epoch 900: Loss = -0.3901, Residual = 5.6276, Avg Reward = -4.4450, Cosine Similarity = -0.3151
# Epoch 1000: Loss = -0.3790, Residual = 4.1942, Avg Reward = -3.4279, Cosine Similarity = -0.3323
#
# Predicted eigenvector: [-0.01314058  0.07519714  0.06925988 -0.10270198  0.14788717  0.0417573
#   0.08403269  0.04338008 -0.17644216  0.13959008  0.17085794  0.0733472
#  -0.05807245 -0.21779574 -0.30042782  0.13621563 -0.2280475   0.0461541
#   0.04858032 -0.0584509   0.1693653  -0.00645929  0.12680094 -0.08891315
#   0.08976058 -0.07741533 -0.31584054  0.12637354 -0.19186324 -0.16492
#   0.17176099  0.13589413 -0.06518587  0.06164612 -0.14017892 -0.10722093
#  -0.27461332  0.00370616  0.01069669 -0.14238457 -0.1647022  -0.07654506
#  -0.22883184  0.18514109 -0.0569279  -0.07682981  0.25547105 -0.09592109
#  -0.00996755 -0.09347777]
# True eigenvector: [-0.02209365  0.09246968 -0.3031336   0.03563942  0.01790886 -0.1378741
# ...
#  -0.21620943 -0.1370657  -0.03955765  0.00462121 -0.00772816  0.01976945
#   0.00951244 -0.12814106 -0.12489126  0.02825101  0.09921195  0.09271285
#  -0.05765149 -0.07787588 -0.16784908  0.06163949  0.10529846 -0.10821082
#   0.02669699 -0.04818175 -0.11502692 -0.01944631  0.06833564 -0.12171993
#  -0.03677999  0.13091704 -0.13365385  0.00144244  0.07060096  0.01665374
#  -0.02499635 -0.04994281  0.08626905  0.08249834  0.0729704   0.12287255
#   0.07561977 -0.18976124 -0.08001912 -0.20198166  0.07006676  0.0810225
#   0.08670547 -0.11210231  0.05024348  0.10795457 -0.03113938  0.14475219
#  -0.18499634  0.05440943 -0.22280273 -0.2013996   0.00674638  0.04082112
#   0.0283226   0.06371519 -0.11258093  0.09870061  0.05487287 -0.04847103
#   0.19338053  0.03309231  0.05067832 -0.06316475  0.10727896 -0.08838239
#  -0.01586507  0.0253617  -0.01515255  0.02068951  0.1711969   0.02702398
#   0.17602527  0.1173592   0.06733833 -0.0885798   0.19484445  0.1271915
#  -0.01855937 -0.04496886  0.06901913  0.10026833 -0.07847429  0.1049014
#   0.01810539 -0.13907833 -0.12688339  0.00268976]
# Cosine similarity: 0.1533
# Run 7
# True dominant eigenvalue: -27.888568712255843
# Epoch 0: Loss = -1.1316, Residual = 27.0482, Avg Reward = -26.5826, Cosine Similarity = 0.0922
# Epoch 100: Loss = -1.1794, Residual = 25.1073, Avg Reward = -29.8115, Cosine Similarity = 0.2825
# Epoch 200: Loss = -1.1744, Residual = 24.7341, Avg Reward = -29.0703, Cosine Similarity = 0.0611
# Epoch 300: Loss = -1.1583, Residual = 23.7109, Avg Reward = -29.2643, Cosine Similarity = 0.2284
# Epoch 400: Loss = -1.2043, Residual = 22.8771, Avg Reward = -26.9453, Cosine Similarity = 0.1549
# Epoch 500: Loss = -1.2075, Residual = 22.2723, Avg Reward = -27.4127, Cosine Similarity = 0.2689
# Epoch 600: Loss = -1.1189, Residual = 19.7975, Avg Reward = -21.9909, Cosine Similarity = 0.3495
# Epoch 700: Loss = -1.1496, Residual = 17.5415, Avg Reward = -15.2849, Cosine Similarity = 0.4205
# Epoch 800: Loss = -1.1190, Residual = 12.7796, Avg Reward = -11.3825, Cosine Similarity = 0.6201
# Epoch 900: Loss = -1.1460, Residual = 11.5751, Avg Reward = -8.4082, Cosine Similarity = 0.6264
# Epoch 1000: Loss = -1.0809, Residual = 9.9676, Avg Reward = -5.7268, Cosine Similarity = 0.7224
#
# Predicted eigenvector: [-0.0854586   0.16851723 -0.14377485 -0.05791318 -0.0173798   0.09910319
#  -0.07877193  0.04650939  0.06756706  0.03435578  0.03184273  0.09817929
#   0.09170654  0.19718695  0.00492229  0.20114413 -0.20148748 -0.10364145
#  -0.01849127  0.04755294  0.09024145 -0.027291   -0.05796653  0.0904232
#  -0.12093987 -0.10404427  0.07971171  0.02957249 -0.03266805 -0.10726975
#   0.122981   -0.1618201   0.05979949 -0.04401379  0.04384116 -0.15342775
#  -0.1807873   0.06374074  0.10562891  0.20868279  0.02275918 -0.10745303
#  -0.00044581  0.05213871  0.08215044  0.00523737  0.00435665 -0.20989285
#   0.22489744  0.1415776  -0.02573047 -0.11428043 -0.05716759 -0.06587487
#   0.02925361 -0.01616397 -0.10470697 -0.01962844  0.00266275  0.05359772
#  -0.09524383  0.14257376 -0.11396047 -0.05086335  0.11351366  0.17837915
#  -0.04006857  0.05047981  0.00962038 -0.0027141   0.12617153  0.01185743
#  -0.12020067 -0.15828653 -0.01355468  0.06925048  0.01112024  0.1387608
#   0.06632859  0.02488604 -0.03028582 -0.0490856   0.07210207  0.07245333
#   0.1445763  -0.0692917  -0.02589905  0.1651929  -0.11074885 -0.06790505
#  -0.05863861 -0.13123924 -0.02225613 -0.06470671 -0.17817445  0.07362103
#  -0.01277901 -0.04243952  0.06713253 -0.17073531]
# True eigenvector: [-0.10297352  0.21384332 -0.12164862 -0.15160088  0.05766972  0.1304796
#  -0.11355092 -0.05746885  0.0245436  -0.07633527  0.1782082   0.04726693
#   0.06665184  0.20511045 -0.04238617  0.12893233 -0.12746693 -0.110525
#   0.03642069 -0.03596     0.1486832  -0.00920319  0.02915296  0.10706371
#  -0.17654856 -0.0280938  -0.07700177  0.11921042 -0.07248927 -0.1284347
#   0.02873676 -0.07621007 -0.14628978 -0.02412933  0.02179312  0.03887603
#  -0.11324252  0.0758217  -0.07535534  0.07681005  0.02538706 -0.02850518
#   0.00204346  0.11534319  0.0238103  -0.12975833  0.04319876 -0.14426959
#   0.13634983  0.08810813 -0.12549427 -0.13034192 -0.03272703  0.02438485
#   0.04227829  0.10675226 -0.18269011  0.04487019 -0.04290756  0.07508938
#  -0.15648186  0.15341558 -0.03525655  0.07117809  0.02391552  0.07317486
#  -0.05754343 -0.04467242 -0.10553387 -0.05471928  0.12909776  0.007334
#  -0.19587222 -0.25251943 -0.07685376  0.0434179   0.07346704  0.12920807
#   0.02870236 -0.01348145  0.10399667 -0.05619723  0.02072489  0.07613403
#   0.1351966  -0.05909744  0.02280474  0.20423064 -0.13862479 -0.09302112
#  -0.01245987  0.01414369  0.06902547 -0.0025211  -0.13553755  0.06770787
#  -0.00048479 -0.0532492   0.06050497 -0.12668443]
# Cosine similarity: 0.7224
# Run 8
# True dominant eigenvalue: -28.148088071015792
# Epoch 0: Loss = -1.1237, Residual = 26.1484, Avg Reward = -25.6522, Cosine Similarity = -0.0020
# Epoch 100: Loss = -1.1716, Residual = 23.9351, Avg Reward = -30.0571, Cosine Similarity = -0.1654
# Epoch 200: Loss = -1.1729, Residual = 23.5406, Avg Reward = -27.9596, Cosine Similarity = -0.0928
# Epoch 300: Loss = -1.1668, Residual = 23.4409, Avg Reward = -24.5519, Cosine Similarity = 0.0660
# Epoch 400: Loss = -1.1069, Residual = 21.9481, Avg Reward = -25.2326, Cosine Similarity = -0.2830
# Epoch 500: Loss = -1.1796, Residual = 19.6804, Avg Reward = -21.1575, Cosine Similarity = -0.1298
# Epoch 600: Loss = -1.1667, Residual = 15.7274, Avg Reward = -14.5326, Cosine Similarity = -0.3552
# Epoch 700: Loss = -1.1454, Residual = 12.9600, Avg Reward = -10.3414, Cosine Similarity = -0.3603
# Epoch 800: Loss = -1.0977, Residual = 10.9534, Avg Reward = -8.0368, Cosine Similarity = -0.4203
# Epoch 900: Loss = -1.0746, Residual = 9.6565, Avg Reward = -5.8335, Cosine Similarity = -0.5161
# Epoch 1000: Loss = -1.0711, Residual = 7.8963, Avg Reward = -4.9045, Cosine Similarity = -0.5342
#
# Predicted eigenvector: [-0.0982995   0.08363193 -0.001888   -0.00415899  0.11880326  0.09168279
#  -0.04000361 -0.01032298 -0.13693091 -0.01713375 -0.14440152  0.07473961
#  -0.15028931 -0.03188394  0.2658779  -0.05589719 -0.08384181 -0.00310857
#   0.05091601  0.05056301  0.00385126  0.0764764  -0.06990669  0.21622795
#   0.01634477 -0.11000396 -0.11346976  0.10440145  0.10130004 -0.08344612
#  -0.01746238 -0.07081769  0.02085112 -0.1287021  -0.11277328 -0.0303641
#  -0.0748641  -0.13123183  0.10824731 -0.14182825 -0.0459573  -0.22341813
#   0.14515835  0.02786461  0.02018094 -0.09917345  0.18223123  0.03641194
#  -0.16656423 -0.0839571   0.1572848   0.13094683 -0.03942753  0.12301151
#   0.00605001  0.03636201  0.15682852 -0.08918503  0.1593486   0.19268742
#  -0.16076855  0.01741795  0.00077259 -0.00033748  0.07240188  0.08265091
#  -0.11072251 -0.0255155  -0.0344197   0.06425922 -0.10616036  0.06987298
#  -0.11527875 -0.16993496 -0.0411567   0.09154545 -0.0976524   0.05141322
#   0.08677375 -0.1287866   0.12477116 -0.00301244 -0.10101628 -0.10980893
#  -0.06268137  0.04699781  0.04469537  0.02355266 -0.03828681  0.07132226
#   0.05244803  0.04676992  0.06413686 -0.01192334  0.1724685   0.09163447
#  -0.13496046 -0.10650013  0.04585422 -0.02926895]
# True eigenvector: [-0.04588503 -0.05442457  0.11456525 -0.00661934 -0.07847548 -0.01888189
#  -0.01458973  0.07694045 -0.0636024  -0.01328496  0.08343837 -0.19699013
#   0.11615042  0.01903912 -0.09876763  0.06903248  0.11761202 -0.0718095
#  -0.1009976  -0.17479856  0.02144399 -0.04877398  0.15074357 -0.06537319
#  -0.0524737   0.17003015  0.01482076  0.06051248 -0.23294921 -0.00478916
#   0.06835986  0.19459528 -0.04323796 -0.01744663 -0.03232837 -0.02236504
#   0.05412609 -0.03409647  0.0034614   0.09994238  0.05878397  0.07957879
#  -0.16714822  0.00603782 -0.01847825 -0.1120114  -0.07317323  0.02867395
#   0.00229262  0.14115763 -0.08577912 -0.18579271 -0.13372861 -0.07188611
#   0.09909726  0.02507727  0.08671687  0.10904397 -0.0693615  -0.19305015
#   0.14837961 -0.03220753  0.13187154 -0.01529293 -0.11907414  0.06509878
#   0.16429766  0.08050675  0.18250668 -0.01506034  0.18050183 -0.06426848
#   0.07351741  0.13482326  0.14435108  0.10190704  0.08948442 -0.02773053
#  -0.10843844  0.01691014 -0.19201228  0.06814314 -0.00082623  0.06283394
#  -0.08164448  0.00026276  0.11967625 -0.07120608 -0.01984144 -0.03214773
#   0.03686627  0.07395643  0.07948017  0.12122113 -0.06120374 -0.2531463
#   0.14220425  0.00777848 -0.10003908 -0.00366104]
# Cosine similarity: -0.5342
# Run 9
# True dominant eigenvalue: 28.45763595159161
# Epoch 0: Loss = -1.1392, Residual = 27.3775, Avg Reward = -28.2426, Cosine Similarity = 0.1667
# Epoch 100: Loss = -1.1601, Residual = 24.4930, Avg Reward = -30.2821, Cosine Similarity = -0.0713
# Epoch 200: Loss = -1.1744, Residual = 24.4930, Avg Reward = -26.6948, Cosine Similarity = -0.0713
# Epoch 300: Loss = -1.1557, Residual = 24.0723, Avg Reward = -28.2575, Cosine Similarity = -0.0313
# Epoch 400: Loss = -1.1871, Residual = 22.6534, Avg Reward = -26.7580, Cosine Similarity = -0.0583
# Epoch 500: Loss = -1.1105, Residual = 21.3866, Avg Reward = -20.8749, Cosine Similarity = -0.2628
# Epoch 600: Loss = -1.1359, Residual = 17.5968, Avg Reward = -17.7542, Cosine Similarity = -0.2436
# Epoch 700: Loss = -1.1769, Residual = 13.8332, Avg Reward = -12.3269, Cosine Similarity = -0.3850
# Epoch 800: Loss = -1.1013, Residual = 11.7717, Avg Reward = -9.1708, Cosine Similarity = -0.3640
# Epoch 900: Loss = -1.0616, Residual = 10.8747, Avg Reward = -7.1747, Cosine Similarity = -0.4646
# Epoch 1000: Loss = -1.0611, Residual = 8.9299, Avg Reward = -6.2258, Cosine Similarity = -0.5192
#
# Predicted eigenvector: [-1.28332555e-01 -5.30490987e-02 -8.58805142e-03 -1.07876994e-01
#   4.49660234e-02 -9.36877206e-02  8.63322988e-04 -2.76814755e-02
#  -1.87054724e-01 -1.66295797e-01 -1.53665841e-02 -9.80951637e-02
#   9.74241495e-02  5.50866090e-02 -2.57742435e-01 -9.14506242e-02
#  -6.61965534e-02 -1.87567040e-01 -4.19282205e-02 -7.57024288e-02
#  -1.04569793e-01  1.11744948e-01 -5.85069060e-02 -1.33624300e-01
#   4.94107828e-02  1.85436472e-01 -7.97130764e-02 -6.62391931e-02
#   1.11474648e-01  1.05062760e-01 -5.17594256e-02  1.93341449e-02
#  -7.22724721e-02 -1.21429168e-01 -2.09723674e-02  4.15840186e-02
#  -1.28091037e-01  3.14888135e-02 -6.68503344e-02 -4.77262773e-02
#   9.28827152e-02 -1.53282052e-02 -1.66962296e-01  1.57237388e-02
#   1.57075882e-01  1.18586078e-01 -1.52698204e-01  4.74819588e-03
#  -1.32704109e-01  5.89093640e-02  3.67584713e-02  8.94910097e-02
#   7.56008476e-02 -6.48189485e-02 -2.16192514e-01 -1.21065319e-01
#  -1.04969785e-01 -8.84678364e-02  3.39328945e-02 -1.16634749e-01
#  -5.94212711e-02  7.08509460e-02 -1.66249558e-01 -1.41659211e-02
#   3.81725319e-02 -4.21309359e-02  4.43619955e-03  1.56289577e-01
#   8.06462094e-02 -2.19956823e-02 -4.12878357e-02 -5.89501895e-02
#   1.59736380e-01 -1.76483467e-01 -1.16599314e-01  1.75113916e-01
#   9.22585726e-02 -3.88731360e-02  1.15066223e-01 -8.14880207e-02
#  -1.49212718e-01  7.55221918e-02  1.60304848e-02 -2.75690667e-03
#   5.57749644e-02 -2.05400097e-03  3.03831138e-02  4.36777398e-02
#   5.75406514e-02 -7.76072368e-02  5.81962653e-02 -2.22140715e-01
#   1.67052822e-05 -1.11122981e-01 -1.05862796e-01  5.28412983e-02
#  -2.92014237e-02 -8.91381279e-02  7.73952305e-02  8.14582258e-02]
# True eigenvector: [ 0.15622438  0.16154349 -0.12904403  0.16459629 -0.11605386  0.10362698
#   0.08769137  0.14726259  0.07922804  0.01070524 -0.05435741  0.00488784
#   0.04663589  0.02123193  0.07776692  0.02274516 -0.02252235  0.02620308
#   0.1407912  -0.02452103 -0.03642074  0.05119932 -0.05457496  0.18348442
#  -0.02751555 -0.12652557  0.03075714  0.05130789  0.03091689 -0.23864295
#  -0.07610238 -0.13153566 -0.04212212  0.01886889 -0.0931927  -0.06567621
#   0.01101737 -0.13760571  0.0623517   0.10043685 -0.15249017 -0.02301713
#   0.12896842  0.03349287 -0.14076898 -0.05806557  0.05325058  0.07734577
#  -0.03235197  0.16354674  0.02160364 -0.17754652 -0.00702099  0.11375955
#   0.16586186 -0.14939591  0.19452474  0.22412676  0.0697148  -0.02220503
#   0.04760667 -0.13195914  0.17933717 -0.04337512 -0.02227413  0.11687767
#  -0.14533578 -0.11503543 -0.12627074 -0.04215309  0.00647394  0.01217496
#  -0.13960896  0.07695284  0.13091323 -0.05872652 -0.14768128 -0.12238473
#  -0.05915499 -0.00156499  0.02692574 -0.02742099  0.06860669  0.12397625
#   0.04898153  0.104802    0.00125902 -0.10223328 -0.12367602  0.04209941
#   0.05483764  0.1332207   0.00174577 -0.02435149  0.01284933 -0.1067804
#  -0.14736271  0.04463787  0.04056277 -0.07181315]
# Cosine similarity: -0.5192
# Run 10
# True dominant eigenvalue: 29.94146846751412
# Epoch 0: Loss = -1.1508, Residual = 30.1271, Avg Reward = -29.4274, Cosine Similarity = -0.0091
# Epoch 100: Loss = -1.1738, Residual = 24.9487, Avg Reward = -30.9862, Cosine Similarity = 0.0294
# Epoch 200: Loss = -1.2858, Residual = 24.8152, Avg Reward = -29.9981, Cosine Similarity = 0.2758
# Epoch 300: Loss = -1.1643, Residual = 22.9962, Avg Reward = -24.3126, Cosine Similarity = 0.4065
# Epoch 400: Loss = -1.1532, Residual = 22.5619, Avg Reward = -22.6290, Cosine Similarity = 0.3840
# Epoch 500: Loss = -1.1668, Residual = 18.9040, Avg Reward = -19.5605, Cosine Similarity = 0.5375
# Epoch 600: Loss = -1.1462, Residual = 16.4427, Avg Reward = -14.6144, Cosine Similarity = 0.6733
# Epoch 700: Loss = -1.1025, Residual = 14.2286, Avg Reward = -11.4368, Cosine Similarity = 0.8003
# Epoch 800: Loss = -1.0835, Residual = 11.9032, Avg Reward = -8.4196, Cosine Similarity = 0.8284
# Epoch 900: Loss = -1.0671, Residual = 10.5399, Avg Reward = -5.7964, Cosine Similarity = 0.8621
# Epoch 1000: Loss = -1.0513, Residual = 10.1113, Avg Reward = -5.2593, Cosine Similarity = 0.9116
#
# Predicted eigenvector: [-0.01909512  0.1856702   0.03095287  0.09564185 -0.04860688  0.01603445
#  -0.02622072 -0.08724573  0.12032083  0.01276566 -0.06291008  0.1672049
#  -0.03868773 -0.01274837  0.04798141  0.03801269  0.01146528  0.00080625
#   0.12770991 -0.01133601 -0.05907682 -0.07760343  0.02351849  0.04338447
#  -0.06539477  0.02014687  0.10726353  0.16171773  0.06015744  0.16051061
#  -0.00593725  0.03938784 -0.00886748 -0.02809158  0.08450431  0.073209
#  -0.11441014  0.15351412 -0.08443521 -0.06437954 -0.07990561 -0.11396227
#   0.04266423 -0.00331991  0.26291743  0.17929502  0.05043145  0.1240153
#  -0.00354306  0.1284466  -0.10431661 -0.15072006  0.11021452 -0.04744752
#  -0.12343568  0.02824421  0.12093712  0.1002518   0.04323846 -0.05389325
#  -0.08552065 -0.01474426  0.00729513  0.02959743 -0.12114083 -0.0754512
#   0.03430321  0.08723911  0.1469795  -0.00134048 -0.03450804  0.00119139
#  -0.12632291 -0.0081514  -0.10691845 -0.0339906  -0.06749154 -0.27879688
#   0.00911305 -0.08527848  0.01253554  0.02115296  0.06764073  0.08098496
#   0.12988448  0.08756849  0.06983461  0.26607135 -0.08262596  0.10177325
#   0.21436124  0.01518029  0.01709744 -0.08630311  0.01398588  0.11033911
#   0.06047307 -0.06945166 -0.30998167 -0.00163849]
# True eigenvector: [ 0.0390409   0.19182254 -0.02830345  0.1654768  -0.05383032  0.04625193
#  -0.0326059  -0.06669927  0.17654292  0.00249925 -0.04802297  0.12825404
#   0.01346148 -0.03384877  0.03727706 -0.01554704  0.00970658 -0.02139139
#   0.1033448   0.04818635 -0.0481587  -0.10332871  0.05563497  0.06552397
#  -0.04448554  0.04967868  0.10104077  0.16847697  0.00554598  0.12052356
#  -0.02168949 -0.01078325 -0.03877988 -0.08694246  0.07911368  0.09078411
#  -0.11725839  0.08510966 -0.04183798 -0.01601505 -0.12309115 -0.11727974
#   0.00521715 -0.00601598  0.28599298  0.1486399   0.03983251  0.08750929
#   0.00499043  0.09528755  0.00828977 -0.13964857  0.06639034  0.01834812
#  -0.13556387  0.02566436  0.16936807  0.07408342  0.00405772 -0.02580162
#  -0.06440916 -0.0173668   0.09449124  0.06063419 -0.05131603 -0.07765717
#   0.07172795  0.06228236  0.16664074 -0.14072639  0.00606021 -0.07747741
#  -0.17200191  0.00329639 -0.07665823 -0.04547938 -0.04098588 -0.24946061
#   0.0013919  -0.12054057  0.05827833  0.03388148  0.05386849  0.05457163
#   0.11918063  0.15145513  0.06913587  0.23201436 -0.05304857  0.11573598
#   0.11625533  0.10828706  0.06035188 -0.05729293  0.03329489  0.08742157
#   0.03902319 -0.12761496 -0.33334953  0.07341705]
# Cosine similarity: 0.9116

# %% [markdown]
# ## Testing on $200 \times 200$ Matrix

# %%
result = np.zeros(200)
for i in range(200):
    result[i]=test_improved_policy(dim=200, epochs=1001)

# %%
print(results)
# Out:
# [[-0.99989378  0.99989712 -0.99969399 -0.99979639 -0.99949962 -0.99879837
#   -0.99980378 -0.99987417  0.99800885  0.99893636]
#  [ 0.98868424  0.98912501  0.39573392  0.90100849  0.99213219 -0.41455376
#    0.99516791 -0.99395812  0.96217597  0.9908163 ]
#  [ 0.93460745 -0.74831402  0.97032142  0.0392857   0.94186842  0.09373933
#    0.85724699 -0.39186513  0.12892543 -0.99045336]
#  [ 0.04372105 -0.37457335 -0.13406821 -0.53124219 -0.19299236  0.7946744
#    0.06214511 -0.639027    0.46845335 -0.87433743]
#  [-0.2202062   0.4366408  -0.00737423  0.30844855  0.78106272  0.28384042
#    0.57013911  0.56508613 -0.63855362  0.29097843]
#  [ 0.10769464  0.13857806 -0.30613685 -0.31653365 -0.20451172 -0.57231629
#    0.00109701 -0.25444061 -0.31986678  0.12743297]]

# %%
perf = [np.mean(np.abs(results[i])) for i in range(len(choices))]

# %%
for i in range(len(choices)):
  print(f"{choices[i]} :  {perf[i]}")
# Out:
# 5 :  0.999689120054245
# 10 :  0.8939916729927063
# 20 :  0.8687786281108856
# 50 :  0.6661560848355293
# 75 :  0.6077921230345964
# 100 :  0.49395446181297303
