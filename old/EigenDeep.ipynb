# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.distributions import MultivariateNormal
from collections import deque
import random
import matplotlib.pyplot as plt

# class Policy(nn.Module):
#     def __init__(self, dim):
#         super().__init__()
#         # Deep policy network
#         self.shared_net = nn.Sequential(
#             nn.Linear(dim, 256),
#             nn.ReLU(),
#             nn.Linear(256, 128),
#             nn.ReLU()
#         )
#         self.fc_mean = nn.Linear(128, dim)

#         # Simpler exploration - single learnable std
#         self.log_std = nn.Parameter(torch.zeros(1))

#         # Value function baseline
#         self.value_net = nn.Sequential(
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Linear(64, 1)
#         )

#     def forward(self, x):
#         features = self.shared_net(x)
#         mean = self.fc_mean(features)
#         # Scalar covariance for all dimensions
#         cov = torch.eye(x.size(-1)) * torch.exp(self.log_std)
#         return MultivariateNormal(mean, cov), self.value_net(features)

class Policy(nn.Module):
    def __init__(self, dim):
        super().__init__()
        # Deeper shared network for feature extraction
        self.shared_net = nn.Sequential(
            nn.Linear(dim, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU()
        )

        self.fc_mean = nn.Linear(128, dim)

        # Shared scalar std for simplicity
        self.log_std = nn.Parameter(torch.zeros(1))

        # Deeper value function network
        self.value_net = nn.Sequential(
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        features = self.shared_net(x)
        mean = self.fc_mean(features)
        cov = torch.eye(x.size(-1)) * torch.exp(self.log_std)
        return MultivariateNormal(mean, cov), self.value_net(features)


class ExperienceReplay:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        return random.sample(self.buffer, min(batch_size, len(self.buffer)))

    def __len__(self):
        return len(self.buffer)

def compute_reward(v_new, v_prev, A, lambda_):
    """Reward function using Rayleigh quotient"""
    # Compute Rayleigh quotient
    with torch.no_grad():
        R = (v_new @ A @ v_new) / (v_new @ v_new)

    # 1. Rayleigh quotient component (closer to true eigenvalue is better)
    rayleigh_component = -torch.abs(R - lambda_).item()

    # 2. Direction consistency component
    cosine_sim = torch.nn.functional.cosine_similarity(
        v_new.unsqueeze(0), v_prev.unsqueeze(0)
    ).item()
    direction_component = 0.3 * cosine_sim

    # 3. Improvement component (compared to previous Rayleigh quotient)
    with torch.no_grad():
        prev_R = (v_prev @ A @ v_prev) / (v_prev @ v_prev)
    improvement_component = 0.2 * (torch.abs(prev_R - lambda_).item() - torch.abs(R - lambda_).item())

    # Combined reward
    reward = rayleigh_component + direction_component + improvement_component

    # Also compute residual for tracking
    residual = torch.linalg.norm((A - lambda_ * torch.eye(A.shape[0])) @ v_new)

    return reward, residual.item(), cosine_sim

def train(A, lambda_, policy, epochs=500, batch_size=32, replay_size=1000, dominant_v=None):
    optimizer = optim.Adam(policy.parameters(), lr=1e-3)
    replay_buffer = ExperienceReplay(replay_size)
    v = torch.randn(A.shape[0])
    v = v / torch.norm(v)

    # Enhanced exploration parameters
    initial_log_std = 0.0  # Starting exploration level
    final_log_std = -2.0   # Minimum exploration level
    exploration_decay = 0.995  # Per-epoch decay

    # Dimension-aware hyperparameters
    dim = A.shape[0]
    entropy_coef = max(0.05, 0.01 * (dim / 20))  # Scales with dimension
    policy.log_std.data.fill_(initial_log_std)  # Initialize exploration

    # Tracking variables
    best_v = v.clone()
    best_residual = float('inf')
    stats = {
        'residuals': [],
        'rewards': [],
        'cosine_similarities': [],
        'exploration': [],
        'epochs': []
    }

    for epoch in range(epochs):
        # Anneal exploration
        current_log_std = max(
            final_log_std,
            initial_log_std * (exploration_decay ** epoch)
        )
        policy.log_std.data.fill_(current_log_std)

        # Batch collection
        states, actions, rewards, values = [], [], [], []
        for _ in range(batch_size):
            v_prev = v.clone()
            dist, value_est = policy(v_prev)
            delta_v = dist.sample()

            with torch.no_grad():
                v_new = (v_prev + delta_v).clone()
                v_new = v_new / torch.norm(v_new)
                reward, residual, cos_sim = compute_reward(v_new, v_prev, A, lambda_)

                if residual < best_residual:
                    best_residual = residual
                    best_v = v_new.clone()

            replay_buffer.push((v_prev, delta_v, reward, value_est))
            states.append(v_prev)
            actions.append(delta_v)
            rewards.append(reward)
            values.append(value_est)

        # Sample from replay buffer
        if len(replay_buffer) > batch_size//2:
            replay_batch = replay_buffer.sample(batch_size//2)
            states.extend([s for s,_,_,_ in replay_batch])
            actions.extend([a for _,a,_,_ in replay_batch])
            rewards.extend([r for _,_,r,_ in replay_batch])
            values.extend([v for _,_,_,v in replay_batch])

        # Convert to tensors
        states = torch.stack(states)
        actions = torch.stack(actions)
        rewards = torch.tensor(rewards, dtype=torch.float32)
        old_values = torch.cat(values).squeeze()

        # Normalize rewards
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-8)

        # PPO Update
        for _ in range(3):  # Multiple optimization steps
            dists, value_ests = policy(states)
            log_probs = dists.log_prob(actions)

            ratios = torch.exp(log_probs - dists.log_prob(actions).detach())
            advantages = rewards - old_values.detach()

            # Clipped objective
            clipped_ratios = torch.clamp(ratios, 0.8, 1.2)
            policy_loss = -torch.min(ratios*advantages, clipped_ratios*advantages).mean()

            # Enhanced losses
            value_loss = 0.5 * (value_ests.squeeze() - rewards).pow(2).mean()
            entropy = dists.entropy().mean()

            loss = policy_loss + 0.5*value_loss - entropy_coef*entropy

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(policy.parameters(), 0.5)
            optimizer.step()

        v = best_v.clone()

        # Logging
        if epoch % 50 == 0 or epoch == epochs-1:
            cos_sim = torch.nn.functional.cosine_similarity(
                best_v.unsqueeze(0), dominant_v.unsqueeze(0)
            ).item() if dominant_v is not None else 0.0

            stats['epochs'].append(epoch)
            stats['residuals'].append(best_residual)
            stats['cosine_similarities'].append(cos_sim)
            stats['exploration'].append(torch.exp(policy.log_std).item())

            print(
                f'Epoch {epoch}: '
                f'Residual={best_residual:.4f}, '
                f'CosSim={cos_sim:.4f}, '
                f'Exploration={torch.exp(policy.log_std).item():.4f}, '
                f'Entropy={entropy.item():.4f}'
            )

    return best_v, stats

def test_improved_policy(dim=5, epochs=1000):
    # Generate random symmetric matrix
    A_np = np.random.randn(dim, dim)
    A_np = A_np + A_np.T
    A = torch.tensor(A_np, dtype=torch.float32)

    # Get ground truth
    eigenvalues, eigenvectors = np.linalg.eig(A_np)
    dominant_idx = np.argmax(np.abs(eigenvalues))
    dominant_lambda = eigenvalues[dominant_idx]
    dominant_v = torch.tensor(eigenvectors[:, dominant_idx], dtype=torch.float32)

    print(f"True dominant eigenvalue: {dominant_lambda}")

    # Train
    policy = Policy(dim)
    predicted_v, stats = train(A, dominant_lambda, policy, epochs=epochs, dominant_v=dominant_v)

    # Compare
    cosine_sim = torch.nn.functional.cosine_similarity(
        predicted_v.unsqueeze(0), dominant_v.unsqueeze(0)
    ).item()

    print(f"\nPredicted eigenvector: {predicted_v.detach().numpy()}")
    print(f"True eigenvector: {dominant_v.numpy()}")
    print(f"Cosine similarity: {cosine_sim:.4f}")


    # # Plot cosine similarity
    # plt.figure(figsize=(10, 6))
    # plt.plot(stats['epochs'], np.abs(stats['cosine_similarities']), 'b-o', linewidth=2)
    # plt.title('Cosine Similarity vs Epoch', fontsize=14)
    # plt.xlabel('Epoch', fontsize=12)
    # plt.ylabel('Cosine Similarity', fontsize=12)
    # plt.grid(True, alpha=0.3)
    # plt.tight_layout()
    # plt.show()

    return cosine_sim, stats

# %%
from google.colab import drive
drive.mount('/content/drive/MyDrive/SMAI_Project')
# Out:
# Mounted at /content/drive

# %%
test_improved_policy(dim=5, epochs=1000)

# %%
test_improved_policy(dim=100, epochs=2000)
# Out:
# True dominant eigenvalue: 28.205543865572157
# Epoch 0: Residual=27.1610, CosSim=-0.2835, Exploration=1.0030, Entropy=141.9939
# Epoch 50: Residual=21.9557, CosSim=-0.3118, Exploration=0.9995, Entropy=141.8701
# Epoch 100: Residual=21.5926, CosSim=-0.2386, Exploration=0.9966, Entropy=141.7802
# Epoch 150: Residual=21.5926, CosSim=-0.2386, Exploration=0.9966, Entropy=141.7814
# Epoch 200: Residual=18.7773, CosSim=-0.2592, Exploration=1.0017, Entropy=141.9479
# Epoch 250: Residual=18.7773, CosSim=-0.2592, Exploration=0.9985, Entropy=141.8483
# Epoch 300: Residual=17.7337, CosSim=-0.3090, Exploration=0.9972, Entropy=141.8017
# Epoch 350: Residual=13.7667, CosSim=-0.5200, Exploration=1.0015, Entropy=141.9405
# Epoch 400: Residual=13.7667, CosSim=-0.5200, Exploration=0.9999, Entropy=141.8959
# Epoch 450: Residual=13.7667, CosSim=-0.5200, Exploration=0.9969, Entropy=141.7906
# Epoch 500: Residual=13.7667, CosSim=-0.5200, Exploration=1.0004, Entropy=141.9105
# Epoch 550: Residual=13.7667, CosSim=-0.5200, Exploration=0.9972, Entropy=141.8014
# Epoch 600: Residual=13.7667, CosSim=-0.5200, Exploration=0.9978, Entropy=141.8202
# Epoch 650: Residual=13.7667, CosSim=-0.5200, Exploration=1.0005, Entropy=141.9043
# Epoch 700: Residual=13.7667, CosSim=-0.5200, Exploration=0.9967, Entropy=141.7851
# Epoch 750: Residual=13.7667, CosSim=-0.5200, Exploration=0.9969, Entropy=141.7903
# Epoch 800: Residual=13.7667, CosSim=-0.5200, Exploration=0.9975, Entropy=141.8109
# Epoch 850: Residual=13.7667, CosSim=-0.5200, Exploration=0.9967, Entropy=141.7835
# Epoch 900: Residual=13.7667, CosSim=-0.5200, Exploration=0.9969, Entropy=141.7893
# Epoch 950: Residual=13.7667, CosSim=-0.5200, Exploration=0.9973, Entropy=141.8043
# Epoch 1000: Residual=13.7667, CosSim=-0.5200, Exploration=0.9998, Entropy=141.8926
# Epoch 1050: Residual=13.7667, CosSim=-0.5200, Exploration=0.9979, Entropy=141.8253
# Epoch 1100: Residual=13.7667, CosSim=-0.5200, Exploration=0.9969, Entropy=141.7895
# Epoch 1150: Residual=13.7667, CosSim=-0.5200, Exploration=0.9973, Entropy=141.8034
# Epoch 1200: Residual=13.7667, CosSim=-0.5200, Exploration=0.9975, Entropy=141.8098
# Epoch 1250: Residual=13.7667, CosSim=-0.5200, Exploration=0.9977, Entropy=141.8170
# Epoch 1300: Residual=13.7667, CosSim=-0.5200, Exploration=0.9980, Entropy=141.8280
# Epoch 1350: Residual=13.7667, CosSim=-0.5200, Exploration=1.0027, Entropy=141.9840
# Epoch 1400: Residual=13.7667, CosSim=-0.5200, Exploration=0.9969, Entropy=141.7908
# Epoch 1450: Residual=13.7667, CosSim=-0.5200, Exploration=1.0000, Entropy=141.8955
# Epoch 1500: Residual=13.7667, CosSim=-0.5200, Exploration=0.9980, Entropy=141.8253
# Epoch 1550: Residual=13.7667, CosSim=-0.5200, Exploration=0.9982, Entropy=141.8366
# Epoch 1600: Residual=13.7667, CosSim=-0.5200, Exploration=0.9965, Entropy=141.7771
# Epoch 1650: Residual=13.7667, CosSim=-0.5200, Exploration=0.9969, Entropy=141.7926
# Epoch 1700: Residual=13.7667, CosSim=-0.5200, Exploration=0.9980, Entropy=141.8277
# Epoch 1750: Residual=13.7667, CosSim=-0.5200, Exploration=0.9977, Entropy=141.8187
# Epoch 1800: Residual=13.7667, CosSim=-0.5200, Exploration=1.0000, Entropy=141.8981
# Epoch 1850: Residual=13.7667, CosSim=-0.5200, Exploration=0.9971, Entropy=141.7981
# Epoch 1900: Residual=13.7667, CosSim=-0.5200, Exploration=0.9984, Entropy=141.8448
# Epoch 1950: Residual=13.7667, CosSim=-0.5200, Exploration=0.9967, Entropy=141.7840
# Epoch 1999: Residual=13.7667, CosSim=-0.5200, Exploration=0.9983, Entropy=141.8408
#
# Predicted eigenvector: [-0.06969266 -0.02169806  0.07535896 -0.04870306 -0.11967811 -0.08318517
#  -0.09452096  0.01497611 -0.16498718 -0.07224525  0.11851105 -0.05937821
#   0.02490196  0.10354833  0.15762623  0.04248832 -0.0083996  -0.19754024
#  -0.05537764 -0.05106748 -0.10665584  0.09425651  0.12082915 -0.04510817
#   0.11804558 -0.05372384 -0.18688104 -0.09721389  0.04806142  0.05292125
#   0.11891101 -0.09691563 -0.04658471  0.14253356 -0.05493127 -0.14732364
#   0.12006187 -0.02550534 -0.04971008  0.00355837  0.14226744  0.11381554
#   0.05595376 -0.11375614  0.16368437 -0.14769068  0.13511151 -0.00650814
#  -0.04681876 -0.12464537  0.06258631  0.202743   -0.09175325 -0.1845256
#   0.18727602  0.06553363  0.1996903   0.18576087  0.04346619  0.13738734
#   0.09667639 -0.03646721  0.08610108 -0.12601298  0.09866456 -0.10510489
#   0.013732   -0.04319137 -0.00291196 -0.08968194  0.05905661 -0.1434051
#  -0.02779034 -0.09505951  0.02629787 -0.10141015  0.06069949  0.17372453
#   0.03416782  0.12887032 -0.07718825 -0.01290583  0.1237919   0.01529606
#  -0.04443589 -0.04757163  0.0427082  -0.02925877  0.10972912  0.00154193
#   0.06651304 -0.08472504 -0.13487929  0.0719915  -0.04948601  0.1137381
#   0.054378    0.10889435 -0.01820847  0.09258313]
# True eigenvector: [ 0.06086728  0.05136518 -0.01304686  0.15778553 -0.01331489  0.10604001
#   0.01677208 -0.00417608  0.0903816   0.06777935 -0.07556456 -0.04524822
#   0.11512607 -0.05757644  0.10711027 -0.19238201 -0.12944032  0.2750794
#   0.1090145  -0.12323242  0.03308581 -0.09523326  0.03257772  0.08276951
#   0.05001985  0.03374077  0.00950613  0.07200128  0.08649562 -0.1367224
#  -0.17752792 -0.04982767 -0.02267917 -0.21572097  0.06640001  0.01563776
#  -0.06773014 -0.0618756  -0.05238132  0.20952474 -0.04729584 -0.09731687
#  -0.02922057  0.10096157 -0.2650351   0.0244127  -0.09301788  0.05864556
#   0.02939658  0.08420067  0.00484772 -0.10099462 -0.02539639 -0.07360656
#   0.01896543  0.02638294 -0.09636857 -0.02376366  0.04645588 -0.04001297
#  -0.05795894 -0.14568324 -0.12644014  0.02956739 -0.01362343  0.14483158
#   0.00730872 -0.06828554  0.06055224  0.1146691  -0.02443543  0.08743259
#  -0.02689034 -0.02571905 -0.03137926  0.2763036  -0.05364396 -0.06122888
#  -0.18867905 -0.07347851  0.14810373  0.07865416 -0.11362972  0.04260504
#   0.05094372 -0.16906753 -0.05376785 -0.0433666  -0.15619858  0.03807566
#  -0.01793352  0.07541573  0.11691353 -0.00389515  0.06679907 -0.10217237
#  -0.03824661 -0.18206637  0.07688927 -0.12165731]
# Cosine similarity: -0.5200
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-e4c593449fb6> in <cell line: 0>()
# ----> 1 test_improved_policy(dim=100, epochs=2000)
#
# <ipython-input-1-128a1ed32e56> in test_improved_policy(dim, epochs)
#     229     # Plot cosine similarity
#     230     plt.figure(figsize=(10, 6))
# --> 231     plt.plot(stats['epochs'].numpy(), np.abs(stats['cosine_similarities'].numpy()), 'b-o', linewidth=2)
#     232     plt.title('Cosine Similarity vs Epoch', fontsize=14)
#     233     plt.xlabel('Epoch', fontsize=12)
#
# AttributeError: 'list' object has no attribute 'numpy'

# %% [markdown]
# # Evaluating on different sizes

# %%
choices = [10, 20, 50, 75, 100, 200, 1000]
results = []
for dim in choices:
    print(f"\nTesting with dimension: {dim}")
    for i in range(3):
        print(f"Run {i + 1}")
        x = test_improved_policy(dim=dim, epochs=2001)
        results.append(x)
    print(f"\n\n\n\n\n!!!______________________________________________________Testing for {dim}x{dim} matrices done ______________________________________________________!!!\n\n\n\n\n")
results = np.array(results)
results = results.reshape(len(choices), 10)
# Out:
# Testing with dimension: 10
# Run 1
# True dominant eigenvalue: -7.628652785210479
# Epoch 0: Residual=5.7799, CosSim=-0.7239, Exploration=1.0030, Entropy=14.1993
# Epoch 50: Residual=1.5430, CosSim=-0.9183, Exploration=0.9959, Entropy=14.1757
# Epoch 100: Residual=1.5430, CosSim=-0.9183, Exploration=0.9966, Entropy=14.1781
# Epoch 150: Residual=1.5430, CosSim=-0.9183, Exploration=0.9966, Entropy=14.1779
# Epoch 200: Residual=1.5430, CosSim=-0.9183, Exploration=0.9972, Entropy=14.1802
# Epoch 250: Residual=1.5430, CosSim=-0.9183, Exploration=0.9996, Entropy=14.1881
# Epoch 300: Residual=1.5430, CosSim=-0.9183, Exploration=0.9967, Entropy=14.1783
# Epoch 350: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1792
# Epoch 400: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1789
# Epoch 450: Residual=1.5430, CosSim=-0.9183, Exploration=0.9973, Entropy=14.1806
# Epoch 500: Residual=1.5430, CosSim=-0.9183, Exploration=0.9976, Entropy=14.1814
# Epoch 550: Residual=1.5430, CosSim=-0.9183, Exploration=0.9985, Entropy=14.1838
# Epoch 600: Residual=1.5430, CosSim=-0.9183, Exploration=0.9966, Entropy=14.1780
# Epoch 650: Residual=1.5430, CosSim=-0.9183, Exploration=0.9997, Entropy=14.1882
# Epoch 700: Residual=1.5430, CosSim=-0.9183, Exploration=0.9976, Entropy=14.1815
# Epoch 750: Residual=1.5430, CosSim=-0.9183, Exploration=0.9968, Entropy=14.1787
# Epoch 800: Residual=1.5430, CosSim=-0.9183, Exploration=0.9967, Entropy=14.1784
# Epoch 850: Residual=1.5430, CosSim=-0.9183, Exploration=0.9967, Entropy=14.1785
# Epoch 900: Residual=1.5430, CosSim=-0.9183, Exploration=0.9968, Entropy=14.1787
# Epoch 950: Residual=1.5430, CosSim=-0.9183, Exploration=0.9968, Entropy=14.1788
# Epoch 1000: Residual=1.5430, CosSim=-0.9183, Exploration=0.9968, Entropy=14.1788
# Epoch 1050: Residual=1.5430, CosSim=-0.9183, Exploration=0.9968, Entropy=14.1789
# Epoch 1100: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1790
# Epoch 1150: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1790
# Epoch 1200: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1791
# Epoch 1250: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1790
# Epoch 1300: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1791
# Epoch 1350: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1790
# Epoch 1400: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1792
# Epoch 1450: Residual=1.5430, CosSim=-0.9183, Exploration=0.9969, Entropy=14.1791
# Epoch 1500: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1792
# Epoch 1550: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1792
# Epoch 1600: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1792
# Epoch 1650: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1793
# Epoch 1700: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1792
# Epoch 1750: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1792
# Epoch 1800: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1793
# Epoch 1850: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1793
# Epoch 1900: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1793
# Epoch 1950: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1793
# Epoch 2000: Residual=1.5430, CosSim=-0.9183, Exploration=0.9970, Entropy=14.1793
#
# Predicted eigenvector: [ 0.20397432 -0.17357095  0.19920877 -0.50809234  0.21863519  0.2471223
#  -0.16908577  0.6004986   0.25754657  0.25697464]
# True eigenvector: [-0.24839765  0.29192552  0.11858196  0.4810403  -0.18243155 -0.17549421
#   0.13018903 -0.69663924 -0.16880594 -0.11307672]
# Cosine similarity: -0.9183
# Run 2
# True dominant eigenvalue: -6.7286161260626445
# Epoch 0: Residual=3.7195, CosSim=-0.7049, Exploration=1.0030, Entropy=14.1994
# Epoch 50: Residual=1.5485, CosSim=-0.7578, Exploration=0.9957, Entropy=14.1752
# Epoch 100: Residual=1.5485, CosSim=-0.7578, Exploration=1.0001, Entropy=14.1902
# Epoch 150: Residual=1.1279, CosSim=-0.7320, Exploration=0.9997, Entropy=14.1879
# Epoch 200: Residual=0.7471, CosSim=-0.7886, Exploration=0.9967, Entropy=14.1783
# Epoch 250: Residual=0.6627, CosSim=-0.8553, Exploration=0.9991, Entropy=14.1867
# Epoch 300: Residual=0.6327, CosSim=-0.8559, Exploration=0.9998, Entropy=14.1882
# Epoch 350: Residual=0.6327, CosSim=-0.8559, Exploration=0.9970, Entropy=14.1792
# Epoch 400: Residual=0.6327, CosSim=-0.8559, Exploration=0.9978, Entropy=14.1817
# Epoch 450: Residual=0.6327, CosSim=-0.8559, Exploration=0.9978, Entropy=14.1813
# Epoch 500: Residual=0.6327, CosSim=-0.8559, Exploration=0.9973, Entropy=14.1804
# Epoch 550: Residual=0.6327, CosSim=-0.8559, Exploration=0.9994, Entropy=14.1869
# Epoch 600: Residual=0.6327, CosSim=-0.8559, Exploration=0.9985, Entropy=14.1846
# Epoch 650: Residual=0.6327, CosSim=-0.8559, Exploration=1.0009, Entropy=14.1921
# Epoch 700: Residual=0.6327, CosSim=-0.8559, Exploration=0.9985, Entropy=14.1847
# Epoch 750: Residual=0.6327, CosSim=-0.8559, Exploration=0.9981, Entropy=14.1833
# Epoch 800: Residual=0.6327, CosSim=-0.8559, Exploration=0.9985, Entropy=14.1845
# Epoch 850: Residual=0.6327, CosSim=-0.8559, Exploration=0.9974, Entropy=14.1809
# Epoch 900: Residual=0.6327, CosSim=-0.8559, Exploration=0.9982, Entropy=14.1834
# Epoch 950: Residual=0.6327, CosSim=-0.8559, Exploration=0.9968, Entropy=14.1788
# Epoch 1000: Residual=0.6327, CosSim=-0.8559, Exploration=1.0008, Entropy=14.1915
# Epoch 1050: Residual=0.6327, CosSim=-0.8559, Exploration=0.9998, Entropy=14.1890
# Epoch 1100: Residual=0.6327, CosSim=-0.8559, Exploration=1.0006, Entropy=14.1912
# Epoch 1150: Residual=0.6327, CosSim=-0.8559, Exploration=0.9992, Entropy=14.1869
# Epoch 1200: Residual=0.6327, CosSim=-0.8559, Exploration=0.9977, Entropy=14.1817
# Epoch 1250: Residual=0.6327, CosSim=-0.8559, Exploration=0.9963, Entropy=14.1772
# Epoch 1300: Residual=0.6327, CosSim=-0.8559, Exploration=0.9984, Entropy=14.1845
# Epoch 1350: Residual=0.6327, CosSim=-0.8559, Exploration=0.9986, Entropy=14.1851
# Epoch 1400: Residual=0.6327, CosSim=-0.8559, Exploration=0.9972, Entropy=14.1802
# Epoch 1450: Residual=0.6327, CosSim=-0.8559, Exploration=1.0012, Entropy=14.1934
# Epoch 1500: Residual=0.6327, CosSim=-0.8559, Exploration=0.9990, Entropy=14.1859
# Epoch 1550: Residual=0.6327, CosSim=-0.8559, Exploration=1.0016, Entropy=14.1945
# Epoch 1600: Residual=0.6327, CosSim=-0.8559, Exploration=0.9994, Entropy=14.1880
# Epoch 1650: Residual=0.6327, CosSim=-0.8559, Exploration=0.9982, Entropy=14.1834
# Epoch 1700: Residual=0.6327, CosSim=-0.8559, Exploration=0.9974, Entropy=14.1795
# Epoch 1750: Residual=0.6327, CosSim=-0.8559, Exploration=0.9989, Entropy=14.1850
# Epoch 1800: Residual=0.6327, CosSim=-0.8559, Exploration=1.0007, Entropy=14.1914
# Epoch 1850: Residual=0.6327, CosSim=-0.8559, Exploration=1.0012, Entropy=14.1936
# Epoch 1900: Residual=0.6327, CosSim=-0.8559, Exploration=0.9991, Entropy=14.1863
# Epoch 1950: Residual=0.6327, CosSim=-0.8559, Exploration=0.9978, Entropy=14.1823
# Epoch 2000: Residual=0.6327, CosSim=-0.8559, Exploration=0.9988, Entropy=14.1859
#
# Predicted eigenvector: [ 0.64669544  0.02169594 -0.00656108  0.16539603 -0.42930675  0.00291404
#  -0.00824405  0.3280285  -0.32077596  0.39879152]
# True eigenvector: [-0.8190998   0.27649707  0.10440212 -0.00744393  0.24901591  0.08286067
#   0.10045438 -0.11190264  0.33241114 -0.19920951]
# Cosine similarity: -0.8559
# Run 3
# True dominant eigenvalue: 9.705328043360673
# Epoch 0: Residual=7.1707, CosSim=0.0887, Exploration=0.9971, Entropy=14.1797
# Epoch 50: Residual=3.8315, CosSim=0.7642, Exploration=0.9964, Entropy=14.1776
# Epoch 100: Residual=3.8315, CosSim=0.7642, Exploration=0.9991, Entropy=14.1855
# Epoch 150: Residual=3.8315, CosSim=0.7642, Exploration=0.9969, Entropy=14.1789
# Epoch 200: Residual=3.4630, CosSim=0.7886, Exploration=0.9974, Entropy=14.1807
# Epoch 250: Residual=3.4630, CosSim=0.7886, Exploration=0.9977, Entropy=14.1817
# Epoch 300: Residual=3.4630, CosSim=0.7886, Exploration=0.9974, Entropy=14.1805
# Epoch 350: Residual=3.4630, CosSim=0.7886, Exploration=0.9993, Entropy=14.1873
# Epoch 400: Residual=3.3736, CosSim=0.9448, Exploration=0.9998, Entropy=14.1884
# Epoch 450: Residual=3.3736, CosSim=0.9448, Exploration=0.9976, Entropy=14.1815
# Epoch 500: Residual=2.7810, CosSim=0.9284, Exploration=0.9981, Entropy=14.1834
# Epoch 550: Residual=2.7565, CosSim=0.9246, Exploration=0.9974, Entropy=14.1807
# Epoch 600: Residual=2.7319, CosSim=0.9232, Exploration=0.9992, Entropy=14.1872
# Epoch 650: Residual=2.6030, CosSim=0.9185, Exploration=0.9996, Entropy=14.1874
# Epoch 700: Residual=2.6030, CosSim=0.9185, Exploration=0.9973, Entropy=14.1804
# Epoch 750: Residual=2.6030, CosSim=0.9185, Exploration=0.9988, Entropy=14.1854
# Epoch 800: Residual=2.6030, CosSim=0.9185, Exploration=0.9980, Entropy=14.1827
# Epoch 850: Residual=2.6030, CosSim=0.9185, Exploration=0.9965, Entropy=14.1779
# Epoch 900: Residual=2.6030, CosSim=0.9185, Exploration=0.9992, Entropy=14.1861
# Epoch 950: Residual=2.6030, CosSim=0.9185, Exploration=0.9987, Entropy=14.1842
# Epoch 1000: Residual=2.6030, CosSim=0.9185, Exploration=1.0015, Entropy=14.1941
# Epoch 1050: Residual=2.6030, CosSim=0.9185, Exploration=0.9992, Entropy=14.1872
# Epoch 1100: Residual=2.6030, CosSim=0.9185, Exploration=0.9983, Entropy=14.1844
# Epoch 1150: Residual=2.6030, CosSim=0.9185, Exploration=1.0001, Entropy=14.1892
# Epoch 1200: Residual=2.5550, CosSim=0.9323, Exploration=0.9962, Entropy=14.1769
# Epoch 1250: Residual=2.5550, CosSim=0.9323, Exploration=0.9973, Entropy=14.1803
# Epoch 1300: Residual=2.5550, CosSim=0.9323, Exploration=0.9983, Entropy=14.1837
# Epoch 1350: Residual=2.5550, CosSim=0.9323, Exploration=0.9980, Entropy=14.1829
# Epoch 1400: Residual=2.5550, CosSim=0.9323, Exploration=0.9993, Entropy=14.1870
# Epoch 1450: Residual=2.5550, CosSim=0.9323, Exploration=1.0001, Entropy=14.1899
# Epoch 1500: Residual=2.5550, CosSim=0.9323, Exploration=0.9978, Entropy=14.1823
# Epoch 1550: Residual=2.5550, CosSim=0.9323, Exploration=0.9978, Entropy=14.1814
# Epoch 1600: Residual=2.5550, CosSim=0.9323, Exploration=0.9989, Entropy=14.1862
# Epoch 1650: Residual=2.5550, CosSim=0.9323, Exploration=0.9985, Entropy=14.1846
# Epoch 1700: Residual=2.5550, CosSim=0.9323, Exploration=0.9980, Entropy=14.1825
# Epoch 1750: Residual=2.5550, CosSim=0.9323, Exploration=0.9980, Entropy=14.1827
# Epoch 1800: Residual=2.5550, CosSim=0.9323, Exploration=0.9980, Entropy=14.1828
# Epoch 1850: Residual=2.5550, CosSim=0.9323, Exploration=0.9972, Entropy=14.1802
# Epoch 1900: Residual=2.5152, CosSim=0.9552, Exploration=0.9972, Entropy=14.1791
# Epoch 1950: Residual=2.4605, CosSim=0.9538, Exploration=0.9983, Entropy=14.1834
# Epoch 2000: Residual=2.4605, CosSim=0.9538, Exploration=0.9982, Entropy=14.1835
#
# Predicted eigenvector: [ 0.11001604 -0.15134045  0.2687253   0.63291794  0.48712298 -0.13876842
#   0.14939588  0.13616258 -0.03165999  0.4402125 ]
# True eigenvector: [ 0.19591768 -0.2503955   0.03788179  0.55963063  0.5806749  -0.06048166
#   0.15687864  0.10182501 -0.01984223  0.4561607 ]
# Cosine similarity: 0.9538
#
#
#
#
#
# !!!______________________________________________________Testing for 10x10 matrices done ______________________________________________________!!!
#
#
#
#
#
#
# Testing with dimension: 20
# Run 1
# True dominant eigenvalue: 12.119025968277217
# Epoch 0: Residual=8.7107, CosSim=-0.2244, Exploration=1.0030, Entropy=28.3988
# Epoch 50: Residual=5.9872, CosSim=-0.5496, Exploration=1.0021, Entropy=28.3939
# Epoch 100: Residual=5.9872, CosSim=-0.5496, Exploration=0.9990, Entropy=28.3727
# Epoch 150: Residual=5.9872, CosSim=-0.5496, Exploration=0.9969, Entropy=28.3585
# Epoch 200: Residual=5.9872, CosSim=-0.5496, Exploration=0.9971, Entropy=28.3596
# Epoch 250: Residual=5.9872, CosSim=-0.5496, Exploration=1.0023, Entropy=28.3935
# Epoch 300: Residual=5.9872, CosSim=-0.5496, Exploration=0.9986, Entropy=28.3697
# Epoch 350: Residual=5.9872, CosSim=-0.5496, Exploration=0.9973, Entropy=28.3612
# Epoch 400: Residual=5.9872, CosSim=-0.5496, Exploration=0.9969, Entropy=28.3586
# Epoch 450: Residual=5.9872, CosSim=-0.5496, Exploration=1.0017, Entropy=28.3900
# Epoch 500: Residual=5.9872, CosSim=-0.5496, Exploration=0.9978, Entropy=28.3641
# Epoch 550: Residual=5.9872, CosSim=-0.5496, Exploration=0.9976, Entropy=28.3617
# Epoch 600: Residual=5.9872, CosSim=-0.5496, Exploration=1.0009, Entropy=28.3849
# Epoch 650: Residual=5.9872, CosSim=-0.5496, Exploration=0.9970, Entropy=28.3588
# Epoch 700: Residual=5.9872, CosSim=-0.5496, Exploration=0.9973, Entropy=28.3610
# Epoch 750: Residual=5.9872, CosSim=-0.5496, Exploration=0.9974, Entropy=28.3619
# Epoch 800: Residual=5.9872, CosSim=-0.5496, Exploration=0.9985, Entropy=28.3694
# Epoch 850: Residual=5.9872, CosSim=-0.5496, Exploration=0.9986, Entropy=28.3705
# Epoch 900: Residual=5.9872, CosSim=-0.5496, Exploration=0.9994, Entropy=28.3754
# Epoch 950: Residual=5.9872, CosSim=-0.5496, Exploration=0.9978, Entropy=28.3647
# Epoch 1000: Residual=5.9872, CosSim=-0.5496, Exploration=0.9977, Entropy=28.3636
# Epoch 1050: Residual=5.9872, CosSim=-0.5496, Exploration=0.9974, Entropy=28.3615
# Epoch 1100: Residual=5.9872, CosSim=-0.5496, Exploration=0.9975, Entropy=28.3621
# Epoch 1150: Residual=5.9872, CosSim=-0.5496, Exploration=0.9977, Entropy=28.3638
# Epoch 1200: Residual=5.9872, CosSim=-0.5496, Exploration=0.9982, Entropy=28.3669
# Epoch 1250: Residual=5.9872, CosSim=-0.5496, Exploration=0.9987, Entropy=28.3702
# Epoch 1300: Residual=5.9872, CosSim=-0.5496, Exploration=1.0001, Entropy=28.3803
# Epoch 1350: Residual=5.9872, CosSim=-0.5496, Exploration=0.9997, Entropy=28.3758
# Epoch 1400: Residual=5.9872, CosSim=-0.5496, Exploration=0.9988, Entropy=28.3715
# Epoch 1450: Residual=5.9872, CosSim=-0.5496, Exploration=0.9971, Entropy=28.3587
# Epoch 1500: Residual=5.9872, CosSim=-0.5496, Exploration=0.9977, Entropy=28.3639
# Epoch 1550: Residual=5.9872, CosSim=-0.5496, Exploration=0.9988, Entropy=28.3714
# Epoch 1600: Residual=5.9872, CosSim=-0.5496, Exploration=0.9974, Entropy=28.3603
# Epoch 1650: Residual=5.9872, CosSim=-0.5496, Exploration=1.0004, Entropy=28.3825
# Epoch 1700: Residual=5.9872, CosSim=-0.5496, Exploration=0.9992, Entropy=28.3718
# Epoch 1750: Residual=5.9872, CosSim=-0.5496, Exploration=1.0010, Entropy=28.3848
# Epoch 1800: Residual=5.9872, CosSim=-0.5496, Exploration=0.9973, Entropy=28.3595
# Epoch 1850: Residual=5.9872, CosSim=-0.5496, Exploration=0.9967, Entropy=28.3567
# Epoch 1900: Residual=5.9872, CosSim=-0.5496, Exploration=0.9971, Entropy=28.3597
# Epoch 1950: Residual=5.9872, CosSim=-0.5496, Exploration=0.9972, Entropy=28.3603
# Epoch 2000: Residual=5.9872, CosSim=-0.5496, Exploration=0.9998, Entropy=28.3787
#
# Predicted eigenvector: [-0.21752593 -0.34054703  0.06444652  0.01012464  0.35744613 -0.16208935
#  -0.03462068  0.29784545 -0.26283845 -0.1650122  -0.1687105  -0.02946767
#  -0.38691914 -0.17033651 -0.30188403 -0.06438483  0.27472094  0.2328296
#   0.04476735 -0.23910812]
# True eigenvector: [-0.00707945  0.16405942  0.10266701  0.01036316 -0.3433554  -0.1235688
#   0.08729769 -0.41950145  0.01493393  0.31415698 -0.03504506 -0.417449
#   0.2563635  -0.04244448  0.27778694 -0.04476704 -0.16936813 -0.00946457
#  -0.4412705  -0.03200398]
# Cosine similarity: -0.5496
# Run 2
# True dominant eigenvalue: -12.586496390193682
# Epoch 0: Residual=9.8562, CosSim=-0.3560, Exploration=1.0030, Entropy=28.3987
# Epoch 50: Residual=5.9981, CosSim=-0.7376, Exploration=1.0014, Entropy=28.3869
# Epoch 100: Residual=5.9981, CosSim=-0.7376, Exploration=0.9974, Entropy=28.3621
# Epoch 150: Residual=5.9981, CosSim=-0.7376, Exploration=0.9969, Entropy=28.3582
# Epoch 200: Residual=4.8696, CosSim=-0.7190, Exploration=0.9983, Entropy=28.3682
# Epoch 250: Residual=4.3188, CosSim=-0.7299, Exploration=1.0008, Entropy=28.3851
# Epoch 300: Residual=4.3188, CosSim=-0.7299, Exploration=0.9986, Entropy=28.3694
# Epoch 350: Residual=4.3188, CosSim=-0.7299, Exploration=0.9990, Entropy=28.3709
# Epoch 400: Residual=3.1444, CosSim=-0.9112, Exploration=0.9970, Entropy=28.3592
# Epoch 450: Residual=3.1444, CosSim=-0.9112, Exploration=1.0014, Entropy=28.3874
# Epoch 500: Residual=3.1444, CosSim=-0.9112, Exploration=0.9980, Entropy=28.3655
# Epoch 550: Residual=3.1444, CosSim=-0.9112, Exploration=0.9967, Entropy=28.3569
# Epoch 600: Residual=3.0323, CosSim=-0.9197, Exploration=0.9999, Entropy=28.3770
# Epoch 650: Residual=1.9690, CosSim=-0.9536, Exploration=1.0005, Entropy=28.3816
# Epoch 700: Residual=1.9690, CosSim=-0.9536, Exploration=0.9982, Entropy=28.3670
# Epoch 750: Residual=1.6422, CosSim=-0.9651, Exploration=0.9976, Entropy=28.3628
# Epoch 800: Residual=1.6422, CosSim=-0.9651, Exploration=0.9990, Entropy=28.3725
# Epoch 850: Residual=1.6422, CosSim=-0.9651, Exploration=0.9981, Entropy=28.3665
# Epoch 900: Residual=1.6422, CosSim=-0.9651, Exploration=0.9963, Entropy=28.3539
# Epoch 950: Residual=1.6422, CosSim=-0.9651, Exploration=0.9968, Entropy=28.3575
# Epoch 1000: Residual=1.6422, CosSim=-0.9651, Exploration=0.9972, Entropy=28.3599
# Epoch 1050: Residual=1.6422, CosSim=-0.9651, Exploration=0.9984, Entropy=28.3682
# Epoch 1100: Residual=1.6422, CosSim=-0.9651, Exploration=1.0008, Entropy=28.3835
# Epoch 1150: Residual=1.6422, CosSim=-0.9651, Exploration=0.9984, Entropy=28.3684
# Epoch 1200: Residual=1.6422, CosSim=-0.9651, Exploration=0.9978, Entropy=28.3641
# Epoch 1250: Residual=1.6422, CosSim=-0.9651, Exploration=1.0018, Entropy=28.3904
# Epoch 1300: Residual=1.6422, CosSim=-0.9651, Exploration=1.0014, Entropy=28.3874
# Epoch 1350: Residual=1.6422, CosSim=-0.9651, Exploration=0.9966, Entropy=28.3561
# Epoch 1400: Residual=1.6422, CosSim=-0.9651, Exploration=0.9996, Entropy=28.3772
# Epoch 1450: Residual=1.6422, CosSim=-0.9651, Exploration=0.9980, Entropy=28.3643
# Epoch 1500: Residual=1.6422, CosSim=-0.9651, Exploration=1.0002, Entropy=28.3804
# Epoch 1550: Residual=1.6422, CosSim=-0.9651, Exploration=0.9994, Entropy=28.3738
# Epoch 1600: Residual=1.6422, CosSim=-0.9651, Exploration=0.9981, Entropy=28.3667
# Epoch 1650: Residual=1.6422, CosSim=-0.9651, Exploration=0.9961, Entropy=28.3525
# Epoch 1700: Residual=1.6422, CosSim=-0.9651, Exploration=0.9985, Entropy=28.3693
# Epoch 1750: Residual=1.6422, CosSim=-0.9651, Exploration=0.9984, Entropy=28.3686
# Epoch 1800: Residual=1.6422, CosSim=-0.9651, Exploration=0.9972, Entropy=28.3596
# Epoch 1850: Residual=1.6422, CosSim=-0.9651, Exploration=0.9974, Entropy=28.3618
# Epoch 1900: Residual=1.6422, CosSim=-0.9651, Exploration=0.9985, Entropy=28.3695
# Epoch 1950: Residual=1.6422, CosSim=-0.9651, Exploration=0.9994, Entropy=28.3735
# Epoch 2000: Residual=1.6422, CosSim=-0.9651, Exploration=1.0011, Entropy=28.3856
#
# Predicted eigenvector: [-0.14414789  0.24876224 -0.18594712 -0.03801082 -0.32940134 -0.11576732
#  -0.08218797  0.14540516 -0.25271958 -0.00854659  0.02315926 -0.18461107
#   0.3698291   0.12794071  0.21283425  0.28626776  0.37030992  0.25537702
#   0.2082902  -0.3268537 ]
# True eigenvector: [ 0.09019427 -0.25759384  0.2252059   0.06606211  0.38066545  0.17446087
#   0.0637275  -0.06600256  0.21950698  0.02232943 -0.00150428  0.16149715
#  -0.40260983 -0.09970472 -0.079329   -0.21004196 -0.38959265 -0.34669936
#  -0.08519541  0.33198664]
# Cosine similarity: -0.9651
# Run 3
# True dominant eigenvalue: 10.522387913628787
# Epoch 0: Residual=9.2573, CosSim=-0.4125, Exploration=1.0027, Entropy=28.3981
# Epoch 50: Residual=5.4419, CosSim=-0.7843, Exploration=0.9998, Entropy=28.3793
# Epoch 100: Residual=5.4419, CosSim=-0.7843, Exploration=0.9982, Entropy=28.3672
# Epoch 150: Residual=5.4419, CosSim=-0.7843, Exploration=0.9998, Entropy=28.3781
# Epoch 200: Residual=5.4419, CosSim=-0.7843, Exploration=1.0005, Entropy=28.3835
# Epoch 250: Residual=5.4419, CosSim=-0.7843, Exploration=0.9964, Entropy=28.3550
# Epoch 300: Residual=5.4419, CosSim=-0.7843, Exploration=0.9965, Entropy=28.3557
# Epoch 350: Residual=5.4419, CosSim=-0.7843, Exploration=1.0003, Entropy=28.3820
# Epoch 400: Residual=5.4419, CosSim=-0.7843, Exploration=0.9977, Entropy=28.3638
# Epoch 450: Residual=5.4419, CosSim=-0.7843, Exploration=0.9983, Entropy=28.3659
# Epoch 500: Residual=5.4419, CosSim=-0.7843, Exploration=0.9996, Entropy=28.3748
# Epoch 550: Residual=3.5923, CosSim=-0.8640, Exploration=1.0021, Entropy=28.3941
# Epoch 600: Residual=3.5923, CosSim=-0.8640, Exploration=0.9964, Entropy=28.3545
# Epoch 650: Residual=3.5806, CosSim=-0.8873, Exploration=1.0003, Entropy=28.3818
# Epoch 700: Residual=3.5806, CosSim=-0.8873, Exploration=0.9964, Entropy=28.3549
# Epoch 750: Residual=3.5806, CosSim=-0.8873, Exploration=0.9975, Entropy=28.3620
# Epoch 800: Residual=3.5011, CosSim=-0.9008, Exploration=0.9978, Entropy=28.3640
# Epoch 850: Residual=3.4179, CosSim=-0.9032, Exploration=0.9973, Entropy=28.3608
# Epoch 900: Residual=3.4179, CosSim=-0.9032, Exploration=0.9966, Entropy=28.3562
# Epoch 950: Residual=3.4179, CosSim=-0.9032, Exploration=0.9979, Entropy=28.3650
# Epoch 1000: Residual=3.3753, CosSim=-0.9048, Exploration=1.0001, Entropy=28.3790
# Epoch 1050: Residual=3.3264, CosSim=-0.9006, Exploration=1.0011, Entropy=28.3869
# Epoch 1100: Residual=3.3264, CosSim=-0.9006, Exploration=0.9965, Entropy=28.3556
# Epoch 1150: Residual=3.3264, CosSim=-0.9006, Exploration=0.9980, Entropy=28.3662
# Epoch 1200: Residual=3.3264, CosSim=-0.9006, Exploration=0.9986, Entropy=28.3696
# Epoch 1250: Residual=2.9414, CosSim=-0.8935, Exploration=0.9974, Entropy=28.3617
# Epoch 1300: Residual=2.9307, CosSim=-0.8930, Exploration=0.9995, Entropy=28.3746
# Epoch 1350: Residual=2.9307, CosSim=-0.8930, Exploration=0.9982, Entropy=28.3668
# Epoch 1400: Residual=2.9307, CosSim=-0.8930, Exploration=0.9979, Entropy=28.3646
# Epoch 1450: Residual=2.9307, CosSim=-0.8930, Exploration=1.0003, Entropy=28.3825
# Epoch 1500: Residual=2.9307, CosSim=-0.8930, Exploration=1.0013, Entropy=28.3873
# Epoch 1550: Residual=2.9307, CosSim=-0.8930, Exploration=1.0002, Entropy=28.3820
# Epoch 1600: Residual=2.9307, CosSim=-0.8930, Exploration=0.9995, Entropy=28.3769
# Epoch 1650: Residual=2.9307, CosSim=-0.8930, Exploration=0.9991, Entropy=28.3736
# Epoch 1700: Residual=2.9307, CosSim=-0.8930, Exploration=0.9995, Entropy=28.3759
# Epoch 1750: Residual=2.9307, CosSim=-0.8930, Exploration=1.0021, Entropy=28.3926
# Epoch 1800: Residual=2.9307, CosSim=-0.8930, Exploration=0.9974, Entropy=28.3614
# Epoch 1850: Residual=2.9307, CosSim=-0.8930, Exploration=0.9965, Entropy=28.3553
# Epoch 1900: Residual=2.9307, CosSim=-0.8930, Exploration=0.9992, Entropy=28.3740
# Epoch 1950: Residual=2.9307, CosSim=-0.8930, Exploration=0.9975, Entropy=28.3626
# Epoch 2000: Residual=2.9307, CosSim=-0.8930, Exploration=1.0000, Entropy=28.3778
#
# Predicted eigenvector: [ 0.38797313 -0.00641395  0.05324387  0.01222293  0.2939381  -0.40092257
#  -0.07803383  0.29631302  0.33606058 -0.34631044  0.00886782 -0.25027466
#   0.41303787 -0.08287188  0.06106044 -0.10665908  0.04585269 -0.00544505
#   0.05111796 -0.11189621]
# True eigenvector: [-0.48342842 -0.10115734 -0.05224544 -0.09423469 -0.07749384  0.35782233
#  -0.03650416 -0.08460043 -0.47701412  0.3806847   0.15114567  0.13123429
#  -0.41661382  0.0746543  -0.0333491   0.0863995   0.02896166  0.02418754
#  -0.01217898  0.01010977]
# Cosine similarity: -0.8930
#
#
#
#
#
# !!!______________________________________________________Testing for 20x20 matrices done ______________________________________________________!!!
#
#
#
#
#
#
# Testing with dimension: 50
# Run 1
# True dominant eigenvalue: 19.480551270815106
# Epoch 0: Residual=17.2368, CosSim=0.0331, Exploration=1.0030, Entropy=70.9969
# Epoch 50: Residual=14.1625, CosSim=-0.2244, Exploration=0.9981, Entropy=70.9170
# Epoch 100: Residual=14.1625, CosSim=-0.2244, Exploration=1.0015, Entropy=70.9758
# Epoch 150: Residual=14.1625, CosSim=-0.2244, Exploration=1.0013, Entropy=70.9660
# Epoch 200: Residual=14.1625, CosSim=-0.2244, Exploration=0.9967, Entropy=70.8922
# Epoch 250: Residual=13.4358, CosSim=-0.2917, Exploration=0.9985, Entropy=70.9212
# Epoch 300: Residual=13.4358, CosSim=-0.2917, Exploration=0.9968, Entropy=70.8929
# Epoch 350: Residual=13.4358, CosSim=-0.2917, Exploration=1.0019, Entropy=70.9777
# Epoch 400: Residual=13.4358, CosSim=-0.2917, Exploration=1.0016, Entropy=70.9715
# Epoch 450: Residual=13.4358, CosSim=-0.2917, Exploration=0.9975, Entropy=70.9057
# Epoch 500: Residual=13.4358, CosSim=-0.2917, Exploration=0.9993, Entropy=70.9373
# Epoch 550: Residual=13.4358, CosSim=-0.2917, Exploration=0.9986, Entropy=70.9201
# Epoch 600: Residual=13.4358, CosSim=-0.2917, Exploration=0.9996, Entropy=70.9413
# Epoch 650: Residual=13.4358, CosSim=-0.2917, Exploration=0.9972, Entropy=70.9002
# Epoch 700: Residual=13.4358, CosSim=-0.2917, Exploration=0.9985, Entropy=70.9193
# Epoch 750: Residual=13.4358, CosSim=-0.2917, Exploration=0.9981, Entropy=70.9160
# Epoch 800: Residual=13.4358, CosSim=-0.2917, Exploration=0.9976, Entropy=70.9073
# Epoch 850: Residual=13.4358, CosSim=-0.2917, Exploration=0.9985, Entropy=70.9176
# Epoch 900: Residual=13.4358, CosSim=-0.2917, Exploration=0.9970, Entropy=70.8970
# Epoch 950: Residual=13.4358, CosSim=-0.2917, Exploration=1.0018, Entropy=70.9765
# Epoch 1000: Residual=13.4358, CosSim=-0.2917, Exploration=0.9979, Entropy=70.9132
# Epoch 1050: Residual=13.4358, CosSim=-0.2917, Exploration=0.9986, Entropy=70.9252
# Epoch 1100: Residual=13.4358, CosSim=-0.2917, Exploration=0.9997, Entropy=70.9436
# Epoch 1150: Residual=13.4358, CosSim=-0.2917, Exploration=0.9972, Entropy=70.9002
# Epoch 1200: Residual=13.4358, CosSim=-0.2917, Exploration=0.9986, Entropy=70.9243
# Epoch 1250: Residual=13.4358, CosSim=-0.2917, Exploration=0.9970, Entropy=70.8974
# Epoch 1300: Residual=13.4358, CosSim=-0.2917, Exploration=1.0014, Entropy=70.9692
# Epoch 1350: Residual=13.4358, CosSim=-0.2917, Exploration=0.9980, Entropy=70.9099
# Epoch 1400: Residual=13.4358, CosSim=-0.2917, Exploration=0.9979, Entropy=70.9127
# Epoch 1450: Residual=13.4358, CosSim=-0.2917, Exploration=0.9967, Entropy=70.8921
# Epoch 1500: Residual=13.4358, CosSim=-0.2917, Exploration=0.9994, Entropy=70.9341
# Epoch 1550: Residual=13.4358, CosSim=-0.2917, Exploration=0.9971, Entropy=70.8977
# Epoch 1600: Residual=13.4358, CosSim=-0.2917, Exploration=0.9969, Entropy=70.8958
# Epoch 1650: Residual=13.4358, CosSim=-0.2917, Exploration=0.9982, Entropy=70.9182
# Epoch 1700: Residual=13.4358, CosSim=-0.2917, Exploration=0.9966, Entropy=70.8908
# Epoch 1750: Residual=13.4358, CosSim=-0.2917, Exploration=0.9974, Entropy=70.9039
# Epoch 1800: Residual=13.4358, CosSim=-0.2917, Exploration=0.9967, Entropy=70.8923
# Epoch 1850: Residual=13.4358, CosSim=-0.2917, Exploration=0.9974, Entropy=70.9046
# Epoch 1900: Residual=13.4358, CosSim=-0.2917, Exploration=0.9967, Entropy=70.8922
# Epoch 1950: Residual=13.4358, CosSim=-0.2917, Exploration=0.9996, Entropy=70.9377
# Epoch 2000: Residual=13.4358, CosSim=-0.2917, Exploration=0.9968, Entropy=70.8942
#
# Predicted eigenvector: [ 0.30864853 -0.14906241  0.1034294   0.08516257 -0.00769517 -0.11615926
#   0.1295267  -0.01413544 -0.04026897  0.02182341  0.11647126 -0.03507302
#   0.09665965  0.12067245  0.05479576 -0.13882443 -0.13797204 -0.00472887
#   0.29085395  0.14086665 -0.04511409  0.22762348 -0.15705253  0.16544527
#  -0.0852543  -0.08693333 -0.09875212 -0.07337938 -0.13864183  0.02954671
#   0.00692103  0.12773646  0.17423888 -0.15056545  0.16471079  0.09614994
#  -0.15794732 -0.16397603  0.14917025  0.28569078  0.18893154 -0.1000881
#  -0.08120756 -0.05182796  0.01786535  0.1888686  -0.15596117 -0.21535327
#   0.23441389  0.11581926]
# True eigenvector: [-1.11557767e-01  3.65309715e-01 -5.80420867e-02 -8.73762742e-03
#  -8.33976716e-02  2.19522566e-01 -1.39139235e-01 -1.89244777e-01
#   1.96874645e-02  5.10189421e-02  6.08085357e-02 -1.28410906e-02
#   1.77214611e-02 -5.84422871e-02 -1.00389794e-01  3.92606445e-02
#   1.20321795e-01  2.98648357e-01 -2.26651341e-01 -3.39903049e-02
#   3.02954078e-01 -9.12335818e-04 -1.57668535e-02 -8.13423768e-02
#   3.12645078e-01  1.94656089e-01  9.09924731e-02  3.56827155e-02
#  -1.30240142e-01  2.13838574e-02  2.43089478e-02 -6.34553134e-02
#  -2.73974165e-02 -9.65600386e-02 -1.11864083e-01  1.49560571e-01
#  -3.26598771e-02  1.76914446e-02  3.15970704e-02 -2.35878956e-02
#  -1.58255488e-01 -1.53167712e-04 -2.54356325e-01 -1.45727515e-01
#  -5.08443490e-02 -1.97298184e-01  1.02361187e-01  6.41634390e-02
#   2.64177889e-01  1.06312230e-01]
# Cosine similarity: -0.2917
# Run 2
# True dominant eigenvalue: -20.059997634325473
# Epoch 0: Residual=17.9237, CosSim=-0.1429, Exploration=1.0030, Entropy=70.9969
# Epoch 50: Residual=14.2267, CosSim=-0.0617, Exploration=1.0035, Entropy=71.0046
# Epoch 100: Residual=14.2267, CosSim=-0.0617, Exploration=0.9965, Entropy=70.8893
# Epoch 150: Residual=14.2267, CosSim=-0.0617, Exploration=0.9965, Entropy=70.8885
# Epoch 200: Residual=14.2267, CosSim=-0.0617, Exploration=1.0001, Entropy=70.9454
# Epoch 250: Residual=14.2267, CosSim=-0.0617, Exploration=0.9966, Entropy=70.8899
# Epoch 300: Residual=14.2267, CosSim=-0.0617, Exploration=1.0017, Entropy=70.9794
# Epoch 350: Residual=14.2016, CosSim=-0.2472, Exploration=0.9980, Entropy=70.9147
# Epoch 400: Residual=14.2016, CosSim=-0.2472, Exploration=0.9964, Entropy=70.8876
# Epoch 450: Residual=14.2016, CosSim=-0.2472, Exploration=0.9968, Entropy=70.8939
# Epoch 500: Residual=14.2016, CosSim=-0.2472, Exploration=0.9986, Entropy=70.9243
# Epoch 550: Residual=14.2016, CosSim=-0.2472, Exploration=0.9968, Entropy=70.8931
# Epoch 600: Residual=14.2016, CosSim=-0.2472, Exploration=0.9988, Entropy=70.9234
# Epoch 650: Residual=14.2016, CosSim=-0.2472, Exploration=0.9980, Entropy=70.9144
# Epoch 700: Residual=14.2016, CosSim=-0.2472, Exploration=0.9979, Entropy=70.9104
# Epoch 750: Residual=14.2016, CosSim=-0.2472, Exploration=0.9973, Entropy=70.9026
# Epoch 800: Residual=14.2016, CosSim=-0.2472, Exploration=0.9983, Entropy=70.9203
# Epoch 850: Residual=14.2016, CosSim=-0.2472, Exploration=0.9966, Entropy=70.8902
# Epoch 900: Residual=14.2016, CosSim=-0.2472, Exploration=0.9977, Entropy=70.9099
# Epoch 950: Residual=14.2016, CosSim=-0.2472, Exploration=0.9966, Entropy=70.8894
# Epoch 1000: Residual=14.2016, CosSim=-0.2472, Exploration=0.9967, Entropy=70.8927
# Epoch 1050: Residual=14.2016, CosSim=-0.2472, Exploration=0.9986, Entropy=70.9245
# Epoch 1100: Residual=14.2016, CosSim=-0.2472, Exploration=0.9971, Entropy=70.8989
# Epoch 1150: Residual=14.2016, CosSim=-0.2472, Exploration=1.0003, Entropy=70.9492
# Epoch 1200: Residual=14.2016, CosSim=-0.2472, Exploration=0.9986, Entropy=70.9243
# Epoch 1250: Residual=14.2016, CosSim=-0.2472, Exploration=0.9983, Entropy=70.9156
# Epoch 1300: Residual=14.2016, CosSim=-0.2472, Exploration=1.0018, Entropy=70.9767
# Epoch 1350: Residual=14.2016, CosSim=-0.2472, Exploration=0.9966, Entropy=70.8908
# Epoch 1400: Residual=14.2016, CosSim=-0.2472, Exploration=0.9967, Entropy=70.8920
# Epoch 1450: Residual=14.2016, CosSim=-0.2472, Exploration=0.9969, Entropy=70.8962
# Epoch 1500: Residual=14.2016, CosSim=-0.2472, Exploration=1.0004, Entropy=70.9514
# Epoch 1550: Residual=14.2016, CosSim=-0.2472, Exploration=0.9965, Entropy=70.8888
# Epoch 1600: Residual=14.2016, CosSim=-0.2472, Exploration=0.9977, Entropy=70.9048
# Epoch 1650: Residual=14.2016, CosSim=-0.2472, Exploration=0.9973, Entropy=70.9027
# Epoch 1700: Residual=14.2016, CosSim=-0.2472, Exploration=1.0001, Entropy=70.9510
# Epoch 1750: Residual=14.2016, CosSim=-0.2472, Exploration=0.9997, Entropy=70.9417
# Epoch 1800: Residual=14.2016, CosSim=-0.2472, Exploration=1.0004, Entropy=70.9517
# Epoch 1850: Residual=14.2016, CosSim=-0.2472, Exploration=0.9981, Entropy=70.9108
# Epoch 1900: Residual=14.2016, CosSim=-0.2472, Exploration=0.9981, Entropy=70.9168
# Epoch 1950: Residual=14.2016, CosSim=-0.2472, Exploration=0.9995, Entropy=70.9417
# Epoch 2000: Residual=14.2016, CosSim=-0.2472, Exploration=1.0005, Entropy=70.9536
#
# Predicted eigenvector: [ 0.10802326  0.22279161 -0.10544651  0.01753936  0.10017618  0.143536
#   0.2557382  -0.17015338  0.00794584 -0.02439591  0.09330638 -0.20123345
#   0.17660125 -0.0238318   0.00374878 -0.13600545  0.01674807  0.10669007
#   0.14087267  0.1991958  -0.0346069  -0.07073845 -0.08229307  0.24999207
#  -0.17586446 -0.04628997 -0.08366999 -0.05247283  0.2543696   0.02939345
#   0.21558407 -0.01650781 -0.11923072  0.1584542   0.2418867   0.03373578
#  -0.15628181 -0.20236054  0.06897962  0.28166613  0.02909722 -0.00744754
#  -0.13572839  0.07042853 -0.13714671  0.16600996 -0.15336834 -0.21508487
#  -0.10453911 -0.02338617]
# True eigenvector: [-0.05281721  0.02773218 -0.1729038   0.20115808 -0.00054166  0.16485588
#  -0.08192908 -0.03922765 -0.02685205 -0.28675368 -0.12849037 -0.17513245
#   0.16248094  0.25086498  0.0281285   0.12351749  0.04630166 -0.08968333
#   0.10506818 -0.292039   -0.046632    0.15309347  0.1756186  -0.23110911
#  -0.07890019  0.06354281 -0.14451315  0.04136185 -0.05486241 -0.08775457
#  -0.07637416  0.00743595  0.14497533  0.07838617 -0.06232799  0.23125973
#   0.0768578   0.08117495  0.11780674 -0.0169517  -0.09998452 -0.11096223
#   0.22693746 -0.3292722   0.07503638 -0.19578452  0.09198812  0.05684791
#   0.10093137 -0.17332737]
# Cosine similarity: -0.2472
# Run 3
# True dominant eigenvalue: 20.184508505063523
# Epoch 0: Residual=19.7670, CosSim=-0.1521, Exploration=0.9970, Entropy=70.8973
# Epoch 50: Residual=13.4542, CosSim=-0.2189, Exploration=0.9973, Entropy=70.9030
# Epoch 100: Residual=13.4542, CosSim=-0.2189, Exploration=0.9986, Entropy=70.9189
# Epoch 150: Residual=13.4542, CosSim=-0.2189, Exploration=0.9994, Entropy=70.9332
# Epoch 200: Residual=13.4542, CosSim=-0.2189, Exploration=0.9972, Entropy=70.9009
# Epoch 250: Residual=13.4542, CosSim=-0.2189, Exploration=0.9992, Entropy=70.9332
# Epoch 300: Residual=9.3542, CosSim=-0.2372, Exploration=0.9981, Entropy=70.9170
# Epoch 350: Residual=9.3542, CosSim=-0.2372, Exploration=0.9989, Entropy=70.9315
# Epoch 400: Residual=9.3542, CosSim=-0.2372, Exploration=0.9980, Entropy=70.9153
# Epoch 450: Residual=9.3542, CosSim=-0.2372, Exploration=0.9975, Entropy=70.9057
# Epoch 500: Residual=9.3542, CosSim=-0.2372, Exploration=1.0005, Entropy=70.9574
# Epoch 550: Residual=9.3542, CosSim=-0.2372, Exploration=0.9968, Entropy=70.8930
# Epoch 600: Residual=9.3542, CosSim=-0.2372, Exploration=0.9970, Entropy=70.8963
# Epoch 650: Residual=9.3542, CosSim=-0.2372, Exploration=1.0019, Entropy=70.9807
# Epoch 700: Residual=9.3542, CosSim=-0.2372, Exploration=0.9970, Entropy=70.8972
# Epoch 750: Residual=9.3542, CosSim=-0.2372, Exploration=0.9972, Entropy=70.9003
# Epoch 800: Residual=9.3542, CosSim=-0.2372, Exploration=1.0002, Entropy=70.9538
# Epoch 850: Residual=9.3542, CosSim=-0.2372, Exploration=0.9987, Entropy=70.9238
# Epoch 900: Residual=9.3542, CosSim=-0.2372, Exploration=0.9996, Entropy=70.9374
# Epoch 950: Residual=9.3542, CosSim=-0.2372, Exploration=1.0005, Entropy=70.9583
# Epoch 1000: Residual=9.3542, CosSim=-0.2372, Exploration=0.9966, Entropy=70.8911
# Epoch 1050: Residual=9.3542, CosSim=-0.2372, Exploration=0.9970, Entropy=70.8973
# Epoch 1100: Residual=9.3542, CosSim=-0.2372, Exploration=0.9970, Entropy=70.8971
# Epoch 1150: Residual=9.3542, CosSim=-0.2372, Exploration=0.9982, Entropy=70.9184
# Epoch 1200: Residual=9.3542, CosSim=-0.2372, Exploration=0.9976, Entropy=70.9078
# Epoch 1250: Residual=9.3542, CosSim=-0.2372, Exploration=0.9976, Entropy=70.9078
# Epoch 1300: Residual=9.3542, CosSim=-0.2372, Exploration=0.9993, Entropy=70.9368
# Epoch 1350: Residual=9.3542, CosSim=-0.2372, Exploration=1.0021, Entropy=70.9821
# Epoch 1400: Residual=9.3542, CosSim=-0.2372, Exploration=0.9967, Entropy=70.8913
# Epoch 1450: Residual=9.3542, CosSim=-0.2372, Exploration=0.9973, Entropy=70.9018
# Epoch 1500: Residual=9.3542, CosSim=-0.2372, Exploration=0.9969, Entropy=70.8948
# Epoch 1550: Residual=9.3542, CosSim=-0.2372, Exploration=0.9984, Entropy=70.9214
# Epoch 1600: Residual=9.3542, CosSim=-0.2372, Exploration=0.9982, Entropy=70.9188
# Epoch 1650: Residual=9.3542, CosSim=-0.2372, Exploration=0.9975, Entropy=70.9053
# Epoch 1700: Residual=9.3542, CosSim=-0.2372, Exploration=0.9972, Entropy=70.9007
# Epoch 1750: Residual=9.3542, CosSim=-0.2372, Exploration=0.9997, Entropy=70.9393
# Epoch 1800: Residual=9.3542, CosSim=-0.2372, Exploration=0.9997, Entropy=70.9393
# Epoch 1850: Residual=9.3542, CosSim=-0.2372, Exploration=0.9973, Entropy=70.9020
# Epoch 1900: Residual=9.3542, CosSim=-0.2372, Exploration=0.9971, Entropy=70.8984
# Epoch 1950: Residual=9.3542, CosSim=-0.2372, Exploration=1.0007, Entropy=70.9568
# Epoch 2000: Residual=9.3542, CosSim=-0.2372, Exploration=1.0001, Entropy=70.9463
#
# Predicted eigenvector: [-0.04263754 -0.01984996  0.14487156  0.15768129 -0.02030052  0.04407724
#  -0.0972762  -0.21294717  0.26518783  0.02468641  0.04356726 -0.04027488
#  -0.06302468  0.04177429  0.22766052  0.27512017  0.13463587  0.09194076
#  -0.19616307  0.01637052 -0.25757575  0.02511739 -0.09727756 -0.03612842
#  -0.19089398 -0.02553694 -0.09455463  0.10607243  0.12873447  0.00858644
#   0.06571147 -0.01577924 -0.05838528 -0.10939626  0.21044384 -0.21559556
#   0.00508365 -0.24869184 -0.20786458 -0.2122041   0.06224434  0.16896194
#  -0.00597624 -0.06951921  0.12679145 -0.18645637  0.08787181 -0.19037847
#   0.26213926  0.09186488]
# True eigenvector: [ 0.19522785  0.01575886  0.03358264 -0.07094934 -0.12545787 -0.15904261
#   0.05035184 -0.12070252  0.08298766  0.1538506   0.12730147  0.01995078
#   0.06160358 -0.0971154  -0.04488731 -0.09019595 -0.05240188 -0.14686511
#  -0.1316779   0.24357282 -0.17625073 -0.25020266  0.22491299  0.07884858
#   0.15085246 -0.05458335  0.12968108 -0.17981228  0.18102089 -0.14773263
#  -0.03603632 -0.09196939  0.3799202  -0.022987   -0.19202824 -0.05596335
#   0.03745164  0.11685011  0.31005174  0.02240046 -0.21189393 -0.1091459
#   0.09042142 -0.06973432  0.10523615 -0.06064393 -0.04220149  0.03650924
#  -0.13784152 -0.1811943 ]
# Cosine similarity: -0.2372
#
#
#
#
#
# !!!______________________________________________________Testing for 50x50 matrices done ______________________________________________________!!!
#
#
#
#
#
#
# Testing with dimension: 75
# Run 1
# True dominant eigenvalue: 23.45904597514182
# Epoch 0: Residual=22.9328, CosSim=-0.1174, Exploration=1.0030, Entropy=106.4954
# Epoch 50: Residual=18.1848, CosSim=-0.1482, Exploration=1.0018, Entropy=106.4665
# Epoch 100: Residual=18.1848, CosSim=-0.1482, Exploration=1.0003, Entropy=106.4300
# Epoch 150: Residual=18.1848, CosSim=-0.1482, Exploration=0.9968, Entropy=106.3387
# Epoch 200: Residual=18.1848, CosSim=-0.1482, Exploration=0.9966, Entropy=106.3341
# Epoch 250: Residual=13.6898, CosSim=-0.1699, Exploration=0.9991, Entropy=106.3955
# Epoch 300: Residual=13.6898, CosSim=-0.1699, Exploration=0.9964, Entropy=106.3304
# Epoch 350: Residual=13.6898, CosSim=-0.1699, Exploration=0.9982, Entropy=106.3760
# Epoch 400: Residual=13.6898, CosSim=-0.1699, Exploration=0.9965, Entropy=106.3337
# Epoch 450: Residual=13.6898, CosSim=-0.1699, Exploration=0.9981, Entropy=106.3673
# Epoch 500: Residual=13.6898, CosSim=-0.1699, Exploration=0.9976, Entropy=106.3617
# Epoch 550: Residual=13.6898, CosSim=-0.1699, Exploration=0.9986, Entropy=106.3859
# Epoch 600: Residual=13.6898, CosSim=-0.1699, Exploration=0.9967, Entropy=106.3384
# Epoch 650: Residual=13.6898, CosSim=-0.1699, Exploration=0.9987, Entropy=106.3912
# Epoch 700: Residual=13.6898, CosSim=-0.1699, Exploration=0.9978, Entropy=106.3583
# Epoch 750: Residual=13.6898, CosSim=-0.1699, Exploration=0.9968, Entropy=106.3412
# Epoch 800: Residual=13.6898, CosSim=-0.1699, Exploration=0.9967, Entropy=106.3379
# Epoch 850: Residual=13.6898, CosSim=-0.1699, Exploration=0.9979, Entropy=106.3674
# Epoch 900: Residual=13.6898, CosSim=-0.1699, Exploration=0.9976, Entropy=106.3605
# Epoch 950: Residual=13.6898, CosSim=-0.1699, Exploration=0.9994, Entropy=106.3997
# Epoch 1000: Residual=13.6898, CosSim=-0.1699, Exploration=0.9976, Entropy=106.3598
# Epoch 1050: Residual=13.6898, CosSim=-0.1699, Exploration=0.9975, Entropy=106.3584
# Epoch 1100: Residual=13.3937, CosSim=-0.3179, Exploration=0.9977, Entropy=106.3556
# Epoch 1150: Residual=11.5427, CosSim=-0.3523, Exploration=0.9969, Entropy=106.3435
# Epoch 1200: Residual=11.3297, CosSim=-0.3566, Exploration=1.0013, Entropy=106.4492
# Epoch 1250: Residual=11.3297, CosSim=-0.3566, Exploration=0.9970, Entropy=106.3450
# Epoch 1300: Residual=11.3297, CosSim=-0.3566, Exploration=0.9988, Entropy=106.3921
# Epoch 1350: Residual=11.3297, CosSim=-0.3566, Exploration=0.9995, Entropy=106.4117
# Epoch 1400: Residual=11.3297, CosSim=-0.3566, Exploration=0.9984, Entropy=106.3823
# Epoch 1450: Residual=11.3297, CosSim=-0.3566, Exploration=0.9979, Entropy=106.3684
# Epoch 1500: Residual=11.3297, CosSim=-0.3566, Exploration=0.9982, Entropy=106.3766
# Epoch 1550: Residual=11.3297, CosSim=-0.3566, Exploration=0.9967, Entropy=106.3377
# Epoch 1600: Residual=11.3297, CosSim=-0.3566, Exploration=1.0014, Entropy=106.4519
# Epoch 1650: Residual=11.3297, CosSim=-0.3566, Exploration=0.9972, Entropy=106.3519
# Epoch 1700: Residual=11.3297, CosSim=-0.3566, Exploration=0.9968, Entropy=106.3405
# Epoch 1750: Residual=11.3297, CosSim=-0.3566, Exploration=0.9969, Entropy=106.3430
# Epoch 1800: Residual=11.3297, CosSim=-0.3566, Exploration=0.9967, Entropy=106.3375
# Epoch 1850: Residual=11.3297, CosSim=-0.3566, Exploration=0.9975, Entropy=106.3580
# Epoch 1900: Residual=11.3297, CosSim=-0.3566, Exploration=0.9974, Entropy=106.3550
# Epoch 1950: Residual=11.3297, CosSim=-0.3566, Exploration=1.0001, Entropy=106.4221
# Epoch 2000: Residual=11.3297, CosSim=-0.3566, Exploration=0.9998, Entropy=106.4123
#
# Predicted eigenvector: [-0.00244688 -0.00740158  0.04991212  0.02918855  0.04146598 -0.10627086
#  -0.01553934  0.11962014  0.22236311  0.00233824 -0.00791982 -0.01542446
#   0.19252855 -0.10343601  0.13530551 -0.05447656 -0.04584736  0.04142904
#   0.01517567 -0.01188451 -0.11711146 -0.02087474 -0.08092735  0.1252063
#   0.09670185 -0.01248667  0.06616662 -0.00579762 -0.14717877 -0.04568139
#  -0.0587546   0.12108856 -0.1922825   0.00455687 -0.10556728  0.12723203
#  -0.07524268 -0.02807513 -0.19593702 -0.04658706  0.01298948 -0.00774847
#  -0.02255334  0.26868322  0.03858429 -0.13937339  0.13297942 -0.09285834
#  -0.1374286   0.07014202 -0.12129717  0.13193683 -0.20813908  0.2448765
#   0.02725567 -0.11576151  0.06698009 -0.02440792  0.23481902  0.02310585
#  -0.22260837  0.03365124  0.24285777 -0.16742977  0.27150416  0.01333399
#   0.01016179  0.00585604  0.18724664  0.08095292  0.11710978 -0.11172581
#   0.03229872 -0.08715867  0.01059123]
# True eigenvector: [-0.18207353  0.05986984 -0.07504444 -0.13378271  0.15758821 -0.02608672
#  -0.2087899   0.00040154 -0.22645134  0.02956155 -0.01346379  0.06056057
#  -0.04572097 -0.13038857  0.01936323 -0.02433428  0.0134501   0.09867604
#  -0.13102423  0.01255442  0.03473478  0.08708075 -0.03779851 -0.11987617
#   0.12953404 -0.0031009  -0.22138721 -0.09721477  0.0274259  -0.09294952
#   0.16514528 -0.07756189 -0.08716923 -0.01146814  0.24272364 -0.00949664
#  -0.18588215 -0.02529069  0.1339015   0.10620838 -0.09454412 -0.05577309
#   0.00270124 -0.13687876 -0.05475438  0.15174367 -0.04307847  0.05682039
#   0.16960366 -0.11177334  0.03115921  0.00213299  0.17252162 -0.06517968
#  -0.04923579  0.05176539  0.13028659 -0.06086147 -0.10941643  0.13110125
#  -0.01769619 -0.12215565 -0.24918634  0.14400361  0.05592717 -0.06108126
#   0.12421317  0.06462999 -0.14272292 -0.00377672  0.03204664  0.11152756
#  -0.12128633 -0.35704848 -0.00148887]
# Cosine similarity: -0.3566
# Run 2
# True dominant eigenvalue: -24.979502135139303
# Epoch 0: Residual=24.3658, CosSim=0.0602, Exploration=1.0030, Entropy=106.4953
# Epoch 50: Residual=19.1627, CosSim=0.2181, Exploration=1.0003, Entropy=106.4241
# Epoch 100: Residual=19.1627, CosSim=0.2181, Exploration=0.9979, Entropy=106.3617
# Epoch 150: Residual=19.1627, CosSim=0.2181, Exploration=0.9978, Entropy=106.3675
# Epoch 200: Residual=19.1627, CosSim=0.2181, Exploration=0.9964, Entropy=106.3305
# Epoch 250: Residual=19.0340, CosSim=0.2292, Exploration=0.9996, Entropy=106.4099
# Epoch 300: Residual=17.7022, CosSim=0.1494, Exploration=1.0011, Entropy=106.4466
# Epoch 350: Residual=17.7022, CosSim=0.1494, Exploration=0.9980, Entropy=106.3716
# Epoch 400: Residual=17.7022, CosSim=0.1494, Exploration=0.9979, Entropy=106.3602
# Epoch 450: Residual=17.7022, CosSim=0.1494, Exploration=0.9971, Entropy=106.3469
# Epoch 500: Residual=17.7022, CosSim=0.1494, Exploration=0.9994, Entropy=106.4022
# Epoch 550: Residual=17.6485, CosSim=0.2278, Exploration=1.0022, Entropy=106.4764
# Epoch 600: Residual=17.6485, CosSim=0.2278, Exploration=0.9967, Entropy=106.3388
# Epoch 650: Residual=17.6485, CosSim=0.2278, Exploration=0.9983, Entropy=106.3801
# Epoch 700: Residual=17.6485, CosSim=0.2278, Exploration=0.9983, Entropy=106.3792
# Epoch 750: Residual=17.6485, CosSim=0.2278, Exploration=0.9978, Entropy=106.3670
# Epoch 800: Residual=17.6485, CosSim=0.2278, Exploration=0.9995, Entropy=106.4040
# Epoch 850: Residual=17.6485, CosSim=0.2278, Exploration=0.9998, Entropy=106.4186
# Epoch 900: Residual=17.6485, CosSim=0.2278, Exploration=0.9976, Entropy=106.3615
# Epoch 950: Residual=17.6485, CosSim=0.2278, Exploration=1.0014, Entropy=106.4566
# Epoch 1000: Residual=17.6485, CosSim=0.2278, Exploration=0.9986, Entropy=106.3875
# Epoch 1050: Residual=17.6485, CosSim=0.2278, Exploration=0.9988, Entropy=106.3881
# Epoch 1100: Residual=17.6485, CosSim=0.2278, Exploration=0.9990, Entropy=106.3882
# Epoch 1150: Residual=17.6485, CosSim=0.2278, Exploration=0.9997, Entropy=106.4101
# Epoch 1200: Residual=17.6485, CosSim=0.2278, Exploration=1.0018, Entropy=106.4629
# Epoch 1250: Residual=17.5801, CosSim=0.2068, Exploration=0.9994, Entropy=106.4088
# Epoch 1300: Residual=17.5778, CosSim=0.2084, Exploration=0.9963, Entropy=106.3282
# Epoch 1350: Residual=17.5778, CosSim=0.2084, Exploration=0.9974, Entropy=106.3541
# Epoch 1400: Residual=17.5233, CosSim=0.2250, Exploration=0.9997, Entropy=106.4083
# Epoch 1450: Residual=17.5156, CosSim=0.2239, Exploration=0.9986, Entropy=106.3795
# Epoch 1500: Residual=17.5143, CosSim=0.2245, Exploration=0.9981, Entropy=106.3746
# Epoch 1550: Residual=17.4811, CosSim=0.2245, Exploration=0.9968, Entropy=106.3412
# Epoch 1600: Residual=17.4699, CosSim=0.2255, Exploration=0.9982, Entropy=106.3776
# Epoch 1650: Residual=17.4595, CosSim=0.2230, Exploration=1.0003, Entropy=106.4325
# Epoch 1700: Residual=17.4078, CosSim=0.2292, Exploration=0.9964, Entropy=106.3317
# Epoch 1750: Residual=17.4078, CosSim=0.2292, Exploration=0.9971, Entropy=106.3493
# Epoch 1800: Residual=17.4062, CosSim=0.2243, Exploration=0.9988, Entropy=106.3942
# Epoch 1850: Residual=17.3089, CosSim=0.2133, Exploration=0.9965, Entropy=106.3328
# Epoch 1900: Residual=17.3089, CosSim=0.2133, Exploration=0.9986, Entropy=106.3864
# Epoch 1950: Residual=17.3021, CosSim=0.2145, Exploration=0.9970, Entropy=106.3460
# Epoch 2000: Residual=17.2842, CosSim=0.2100, Exploration=0.9990, Entropy=106.3912
#
# Predicted eigenvector: [ 0.02440391  0.155052   -0.01893561  0.19036198  0.01262781  0.1680879
#  -0.20558426  0.23194818 -0.00870754 -0.12120908 -0.02776857  0.02283045
#  -0.12503268  0.12170769  0.01543094  0.00724611 -0.00242276 -0.1912003
#   0.11487091 -0.07340428  0.01760951  0.09350629  0.12139121  0.14874305
#  -0.07905034  0.00241121  0.03154444  0.16978993  0.03206443 -0.026635
#   0.1853352  -0.02645771 -0.15901105 -0.14210086  0.19864723  0.18751384
#  -0.02689813  0.036838    0.1770407   0.01921168  0.0284791   0.10164435
#   0.01625961  0.16494064  0.18923733 -0.01897322 -0.12047689  0.11495402
#  -0.19834955 -0.15064783 -0.18123944  0.00494272  0.19908899  0.03246605
#   0.01140364  0.01687147 -0.18358576 -0.01425309 -0.18564664 -0.1506698
#  -0.00803432  0.05404143 -0.1580627  -0.03092221 -0.20902015 -0.00037192
#   0.07004776  0.03658033 -0.0293945  -0.02748077  0.15862429 -0.02731594
#   0.03176685  0.0425107   0.02952862]
# True eigenvector: [ 9.49802529e-03  7.08708242e-02 -3.49383689e-02  1.22497663e-01
#   1.36592370e-02 -1.31101593e-01  4.44211364e-02  8.16187337e-02
#  -3.87938768e-02 -9.01815146e-02  1.81407034e-01 -1.15416676e-01
#  -5.19779623e-02  9.53198597e-02  2.98974309e-02  8.47183168e-02
#   8.02789405e-02 -1.66811496e-01  2.22087368e-01 -1.89201143e-02
#   7.85498321e-02 -2.03588545e-01 -2.81181596e-02  1.77177683e-01
#   1.32311294e-02 -1.70254618e-01  2.39898250e-01  4.51317988e-02
#  -1.97020575e-01 -7.58463964e-02  3.92428376e-02  6.58156201e-02
#  -3.34747359e-02  3.57938521e-02 -2.54792161e-04  1.59503259e-02
#  -9.49723274e-02 -3.97709794e-02 -2.73413688e-01  3.32832262e-02
#   2.47517064e-01  2.48823073e-02 -1.84107330e-02 -1.86965745e-02
#  -1.04228780e-01 -8.61768574e-02 -1.01573840e-01  9.76720229e-02
#  -1.55645773e-01  1.99259967e-02 -2.39212468e-01 -4.30179760e-02
# ...
# Epoch 1050: Residual=28.6561, CosSim=-0.1110, Exploration=0.9968, Entropy=283.5754
# Epoch 1100: Residual=28.6561, CosSim=-0.1110, Exploration=0.9968, Entropy=283.5760
# Epoch 1150: Residual=28.6561, CosSim=-0.1110, Exploration=0.9968, Entropy=283.5764
# Epoch 1200: Residual=28.6561, CosSim=-0.1110, Exploration=0.9971, Entropy=283.5974
# Epoch 1250: Residual=28.6561, CosSim=-0.1110, Exploration=0.9969, Entropy=283.5790
# Epoch 1300: Residual=28.6561, CosSim=-0.1110, Exploration=0.9969, Entropy=283.5796
# Epoch 1350: Residual=28.6561, CosSim=-0.1110, Exploration=0.9969, Entropy=283.5791
# Epoch 1400: Residual=28.6561, CosSim=-0.1110, Exploration=0.9969, Entropy=283.5796
# Epoch 1450: Residual=28.6561, CosSim=-0.1110, Exploration=0.9969, Entropy=283.5804
# Epoch 1500: Residual=28.6561, CosSim=-0.1110, Exploration=0.9983, Entropy=283.6745
# Epoch 1550: Residual=28.6561, CosSim=-0.1110, Exploration=0.9977, Entropy=283.6344
# Epoch 1600: Residual=28.6561, CosSim=-0.1110, Exploration=0.9969, Entropy=283.5789
# Epoch 1650: Residual=28.6561, CosSim=-0.1110, Exploration=0.9985, Entropy=283.6751
# Epoch 1700: Residual=28.6561, CosSim=-0.1110, Exploration=0.9995, Entropy=283.7472
# Epoch 1750: Residual=28.6561, CosSim=-0.1110, Exploration=0.9995, Entropy=283.7432
# Epoch 1800: Residual=28.6561, CosSim=-0.1110, Exploration=0.9990, Entropy=283.7259
# Epoch 1850: Residual=28.6561, CosSim=-0.1110, Exploration=0.9975, Entropy=283.6215
# Epoch 1900: Residual=28.6561, CosSim=-0.1110, Exploration=0.9967, Entropy=283.5704
# Epoch 1950: Residual=28.6561, CosSim=-0.1110, Exploration=0.9984, Entropy=283.6826
# Epoch 2000: Residual=28.6561, CosSim=-0.1110, Exploration=0.9992, Entropy=283.7253
#
# Predicted eigenvector: [-2.40387693e-02  7.49641890e-03 -1.54942960e-01  5.05021140e-02
#   1.99737195e-02 -6.92990273e-02 -1.14089422e-01 -1.18218385e-01
#  -6.83910586e-03 -1.46934271e-01 -3.35131846e-02  1.12550423e-01
#   1.41598657e-01  2.27488428e-02  1.98905729e-02  1.75380692e-01
#   6.60550781e-04 -4.31546122e-02 -4.06301655e-02 -8.56468678e-02
#  -3.45492959e-02  1.17204905e-01  5.48248887e-02 -1.05709776e-01
#  -3.29583660e-02 -6.29969612e-02  1.33160487e-01  7.48713017e-02
#  -4.80392650e-02 -6.34844527e-02  1.25754133e-01 -3.12280785e-02
#   3.75810564e-02 -1.43274218e-01 -1.08792432e-01 -3.36398631e-02
#   9.20847580e-02  6.83943704e-02 -1.44402115e-02 -4.05915827e-02
#  -2.04031877e-02  3.04314718e-02  3.30246873e-02 -6.21112585e-02
#  -1.48498891e-02  4.92698662e-02  8.22418183e-03  2.57925615e-02
#  -7.11316988e-02  6.42371699e-02  2.12099813e-02 -3.26818861e-02
#   4.11592089e-02 -7.37311915e-02 -7.79342279e-02 -5.73767871e-02
#  -2.94619557e-02 -2.74643060e-02 -8.53231847e-02  1.60892925e-03
#   2.84731332e-02 -2.69818343e-02  2.05732509e-02  1.25331983e-01
#  -1.06359430e-01  7.04453960e-02  5.83938733e-02 -9.97000933e-02
#   1.04999905e-02 -8.38336423e-02 -8.98728892e-02  4.10779566e-02
#  -6.93734065e-02  1.16335250e-01  6.82440167e-03 -1.43259719e-01
#   6.32365420e-02  1.07994452e-01  4.39151451e-02  5.04181236e-02
#   4.67798226e-02 -8.11131075e-02  7.21226074e-03 -3.05409171e-02
#   2.68091988e-02  1.30155712e-01 -3.02826799e-02  1.48614170e-02
#  -1.21866897e-01  3.37904133e-02 -2.46068183e-02  2.22346913e-02
#   6.50694966e-02  1.82991233e-02 -1.12336770e-01 -1.72972213e-02
#   1.15946364e-02 -7.19119087e-02  7.08996281e-02 -7.27246478e-02
#  -5.83403669e-02  1.49885386e-01  6.52891919e-02  5.31568341e-02
#  -5.79051115e-02 -1.18940569e-01  1.03117779e-01 -6.78095371e-02
#   4.10900116e-02  6.31430894e-02  1.72954686e-02 -4.34554107e-02
#  -2.63620988e-02 -7.00161308e-02  1.27501816e-01 -7.76232705e-02
#  -7.03300163e-02 -4.93880436e-02 -4.53202799e-02  8.04701298e-02
#   4.56356294e-02  5.35722077e-02  5.32786921e-02  7.84808025e-02
#  -3.64934020e-02 -1.06568895e-02 -6.43205866e-02  3.76542789e-06
#   5.65286689e-02  4.37545963e-02 -1.10184262e-02  3.99123691e-02
#  -1.54963639e-02 -6.54668733e-02  8.66018981e-02  3.76834236e-02
#   3.31308169e-04  5.83453290e-02 -6.76155016e-02 -4.15329263e-02
#  -2.09653780e-01  2.45322660e-02 -2.36779489e-02  7.42321387e-02
#   7.76654929e-02 -9.32904854e-02 -5.73415905e-02  1.16272219e-01
#  -2.97794566e-02 -3.50533389e-02  7.00407997e-02  8.35324917e-03
#  -1.15039721e-02 -1.99015867e-02  7.33192936e-02  1.52651663e-03
#  -1.27048731e-01  1.01169303e-01  3.09092551e-02 -1.05599247e-01
#  -7.55461901e-02  1.12007484e-01 -7.36593381e-02 -4.92905788e-02
#  -1.21927746e-02  2.52219313e-03 -5.13375923e-02 -1.15306405e-02
#   4.37713973e-02 -6.73448071e-02  3.39096226e-02 -7.19815940e-02
#  -1.67418972e-01  4.74501736e-02  1.19318843e-01 -4.26636338e-02
#   1.00143485e-01  1.64049827e-02 -3.84124485e-03 -6.64817691e-02
#   4.97599617e-02  9.17921811e-02  1.94061939e-02  2.82749627e-02
#   8.70147943e-02  8.52545723e-02  9.04453844e-02 -6.64661601e-02
#  -6.91301972e-02 -7.23821074e-02  6.05380768e-03  5.32705858e-02
#  -3.80504057e-02 -2.03591865e-02  4.99564223e-02 -1.45818284e-02
#  -3.01186368e-02  5.38919754e-02  5.01678977e-03 -9.44587681e-03]
# True eigenvector: [-0.07036756  0.08214708 -0.00176094  0.08681381 -0.00650196 -0.01313609
#   0.01199369  0.00884525  0.09915454  0.08720171  0.04630855  0.00624202
#  -0.06673905 -0.02704012  0.0415677   0.06822859 -0.06429302 -0.06669185
#   0.05368415  0.14342874 -0.07386936 -0.04880736 -0.10510065 -0.0337401
#  -0.07685707  0.12611586 -0.0922767   0.05644533 -0.02036358  0.10385688
#  -0.02426342 -0.02269544 -0.09572691  0.055495    0.04148364  0.03836703
#  -0.0961278   0.04147487  0.07031536 -0.11942373 -0.01267618 -0.05197334
#  -0.14944436  0.03999954  0.02094958  0.00099586  0.00260911  0.01438809
#  -0.01726554 -0.04239757  0.08004418  0.06907     0.04054674  0.01040622
#   0.03950061  0.02479197 -0.00806207  0.01890746 -0.05336345 -0.0089136
#   0.09848961 -0.08504677  0.00258893  0.1594398  -0.08120756  0.00578286
#   0.02290284  0.06067093  0.091578   -0.08456773 -0.06055078  0.04425668
#  -0.02361959  0.09964075  0.00339954 -0.0182785   0.05574425 -0.03115843
#  -0.09755334  0.11850212  0.04568599  0.03756425  0.0720762  -0.01482047
#  -0.01337043 -0.01521763  0.0579099  -0.01274792 -0.16732965 -0.06749438
#  -0.01476493 -0.00774242  0.0004054   0.01467015  0.03992541 -0.05144962
#   0.08684127  0.0589329  -0.06819256  0.05690264  0.03045797 -0.08012867
#   0.02520307  0.05515797  0.03327678 -0.07840635  0.01373802  0.05047018
#  -0.01010882  0.03901137 -0.08555238  0.16225857  0.07316604 -0.00740511
#   0.01546825  0.12105433  0.00923523 -0.05635996  0.0445096   0.07731842
#   0.11566474 -0.04866066 -0.04586494 -0.08673158  0.02103927 -0.05370672
#  -0.02122056  0.01861278 -0.01505209  0.07658847 -0.12761581  0.07778177
#   0.09547289  0.07610036  0.01481875  0.02694168 -0.05728563  0.02248029
#  -0.03797457  0.03497868  0.04342775  0.0393492  -0.00266867  0.02422076
#   0.15803875  0.00329728  0.0620099  -0.03200337 -0.15467186 -0.10535394
#  -0.1067507  -0.00066339 -0.03547188  0.0721194  -0.0739832  -0.04184586
#   0.05151325 -0.02907698 -0.14057554  0.05907944 -0.07271153 -0.09146092
#  -0.11438484  0.07793278 -0.04910944 -0.02172429  0.04633778  0.02085651
#  -0.10830804 -0.02035487 -0.01021335  0.03830885  0.08543636  0.05168382
#   0.00670754  0.1712747   0.0317572  -0.11613666 -0.07637282  0.05280446
#  -0.03140483 -0.08906861 -0.07725297  0.00133154  0.0181713   0.00944074
#  -0.0116388  -0.01652501 -0.06047561 -0.01704957  0.00685323 -0.26295915
#   0.07089481 -0.116647    0.04214811 -0.02491857  0.18662348 -0.14394927
#  -0.07448933 -0.03965871]
# Cosine similarity: -0.1110
# Run 2
# True dominant eigenvalue: -38.86333587591147
# Epoch 0: Residual=40.3189, CosSim=-0.0578, Exploration=1.0030, Entropy=283.9878
# Epoch 50: Residual=35.6890, CosSim=0.1636, Exploration=1.0001, Entropy=283.7832
# Epoch 100: Residual=34.8313, CosSim=0.1471, Exploration=1.0027, Entropy=283.9653
# Epoch 150: Residual=34.8313, CosSim=0.1471, Exploration=0.9968, Entropy=283.5783
# Epoch 200: Residual=34.8313, CosSim=0.1471, Exploration=0.9973, Entropy=283.6093
# Epoch 250: Residual=34.8313, CosSim=0.1471, Exploration=1.0002, Entropy=283.8076
# Epoch 300: Residual=34.8313, CosSim=0.1471, Exploration=0.9997, Entropy=283.7771
# Epoch 350: Residual=34.8313, CosSim=0.1471, Exploration=0.9993, Entropy=283.7270
# Epoch 400: Residual=34.8313, CosSim=0.1471, Exploration=0.9970, Entropy=283.5862
# Epoch 450: Residual=34.8313, CosSim=0.1471, Exploration=0.9977, Entropy=283.6377
# Epoch 500: Residual=34.8313, CosSim=0.1471, Exploration=0.9984, Entropy=283.6783
# Epoch 550: Residual=34.8313, CosSim=0.1471, Exploration=0.9967, Entropy=283.5689
# Epoch 600: Residual=34.8313, CosSim=0.1471, Exploration=0.9972, Entropy=283.5999
# Epoch 650: Residual=34.8313, CosSim=0.1471, Exploration=0.9973, Entropy=283.6010
# Epoch 700: Residual=34.8313, CosSim=0.1471, Exploration=0.9969, Entropy=283.5791
# Epoch 750: Residual=34.8313, CosSim=0.1471, Exploration=0.9985, Entropy=283.6950
# Epoch 800: Residual=34.8313, CosSim=0.1471, Exploration=0.9973, Entropy=283.6087
# Epoch 850: Residual=34.8313, CosSim=0.1471, Exploration=0.9989, Entropy=283.7092
# Epoch 900: Residual=34.8313, CosSim=0.1471, Exploration=0.9991, Entropy=283.7347
# Epoch 950: Residual=34.8313, CosSim=0.1471, Exploration=0.9970, Entropy=283.5883
# Epoch 1000: Residual=34.8313, CosSim=0.1471, Exploration=0.9976, Entropy=283.6194
# Epoch 1050: Residual=34.8313, CosSim=0.1471, Exploration=0.9967, Entropy=283.5715
# Epoch 1100: Residual=34.8313, CosSim=0.1471, Exploration=0.9966, Entropy=283.5591
# Epoch 1150: Residual=34.8313, CosSim=0.1471, Exploration=0.9975, Entropy=283.6060
# Epoch 1200: Residual=34.8313, CosSim=0.1471, Exploration=0.9974, Entropy=283.6128
# Epoch 1250: Residual=34.8313, CosSim=0.1471, Exploration=0.9990, Entropy=283.7258
# Epoch 1300: Residual=34.8313, CosSim=0.1471, Exploration=0.9988, Entropy=283.6918
# Epoch 1350: Residual=34.8313, CosSim=0.1471, Exploration=0.9971, Entropy=283.5925
# Epoch 1400: Residual=34.8313, CosSim=0.1471, Exploration=0.9980, Entropy=283.6590
# Epoch 1450: Residual=34.8313, CosSim=0.1471, Exploration=0.9967, Entropy=283.5673
# Epoch 1500: Residual=34.8313, CosSim=0.1471, Exploration=1.0005, Entropy=283.8313
# Epoch 1550: Residual=34.8313, CosSim=0.1471, Exploration=0.9972, Entropy=283.6040
# Epoch 1600: Residual=34.8313, CosSim=0.1471, Exploration=0.9976, Entropy=283.6294
# Epoch 1650: Residual=34.8313, CosSim=0.1471, Exploration=0.9966, Entropy=283.5580
# Epoch 1700: Residual=34.8313, CosSim=0.1471, Exploration=0.9974, Entropy=283.6149
# Epoch 1750: Residual=34.8313, CosSim=0.1471, Exploration=1.0000, Entropy=283.7769
# Epoch 1800: Residual=34.8313, CosSim=0.1471, Exploration=0.9971, Entropy=283.5982
# Epoch 1850: Residual=34.8313, CosSim=0.1471, Exploration=0.9965, Entropy=283.5565
# Epoch 1900: Residual=34.8313, CosSim=0.1471, Exploration=1.0005, Entropy=283.8299
# Epoch 1950: Residual=34.8313, CosSim=0.1471, Exploration=0.9971, Entropy=283.5972
# Epoch 2000: Residual=34.8313, CosSim=0.1471, Exploration=0.9972, Entropy=283.6018
#
# Predicted eigenvector: [-0.08905589  0.04792398 -0.05947605 -0.0750825  -0.08849203  0.06406575
#  -0.01838193 -0.09792408 -0.07868351  0.07354648 -0.07143274 -0.03028574
#  -0.0613981   0.06122221 -0.03991115  0.07943024  0.06018713 -0.05799412
#  -0.09360636  0.09096507 -0.10671946 -0.04263839  0.0137058   0.06422879
#  -0.03090161  0.0664001  -0.05667829 -0.0791432  -0.0675649   0.06762963
#  -0.0038218   0.06647443  0.08555007  0.06074489 -0.06535343  0.0718485
#  -0.03462225  0.08425742 -0.07212924  0.00670457 -0.09290195 -0.08190515
#   0.0459218  -0.05316533  0.08703304  0.05217948 -0.02741737  0.05972773
#   0.0898912   0.10797011  0.06457037  0.05749342 -0.13634692  0.05124796
#  -0.0701978   0.1049944   0.05477283  0.0654723  -0.095756    0.04127247
#  -0.0923363   0.07364275 -0.09211367 -0.04517871  0.08167416  0.04707429
#   0.05283684  0.06336118 -0.06364362  0.06439088  0.0918813   0.04784961
#   0.0834193  -0.07568489  0.11076923 -0.0816692  -0.0735919  -0.01674874
#  -0.01068566 -0.04327103  0.0498382  -0.05178315 -0.06491313  0.08255735
#   0.0644244  -0.0769721   0.07130889 -0.03615946  0.03285909  0.07382789
#   0.03283779  0.07383216  0.02615242  0.05360181 -0.08897945 -0.07714505
#  -0.07437356 -0.0834385  -0.07120415  0.04548455 -0.10164538 -0.08364012
#   0.10442284  0.06490202 -0.06995036  0.03673398 -0.08108229  0.09040871
#   0.10713721  0.03506051 -0.07820614  0.01252945 -0.06064595  0.08222215
#   0.07251512 -0.06452936 -0.06166427 -0.08075801 -0.06268562  0.03757028
#   0.11672929  0.05910437  0.06324974  0.05576354  0.07567802 -0.03387184
#  -0.05103189  0.04527856 -0.08976015 -0.02725406  0.05326102 -0.07229341
#   0.07339107  0.06520859  0.07288697 -0.07177557 -0.10044079 -0.02134264
#  -0.07120131 -0.01457826 -0.02683641 -0.01914127 -0.05886835  0.06256929
#  -0.01182518  0.10052522 -0.09084414 -0.04383032 -0.07664239 -0.03687368
#  -0.11982918  0.01250908 -0.09617047 -0.07722423  0.01625155 -0.02635674
#   0.06251613 -0.07407875 -0.05631225 -0.10144361  0.10039958  0.09399667
#   0.0921344   0.10631079  0.06750541  0.10423873  0.02705764  0.08387021
#   0.08072591  0.08918636 -0.09781844  0.06568242 -0.03396424 -0.06076118
#  -0.05877382  0.06819653  0.05869522  0.07739275  0.06081126 -0.03800547
#  -0.08758176 -0.01313324 -0.06290791 -0.06333011  0.08685654 -0.07125121
#  -0.09133778  0.02710148  0.1045383   0.06403424  0.11590374  0.01790961
#  -0.08491571 -0.11687505  0.09467448  0.05437762 -0.07081826  0.08893159
#   0.08429462  0.00951692]
# True eigenvector: [-0.02306075 -0.03777866 -0.15264504 -0.01311616 -0.07275355 -0.13972034
#  -0.05355113 -0.01551061 -0.00933597 -0.04973645 -0.04115148 -0.02025067
#   0.03271188 -0.0025041  -0.03494302  0.05326043  0.0748396   0.06828377
#   0.01302894 -0.01328482 -0.0481053  -0.04335345  0.12399916  0.03698812
#   0.10533196 -0.07623351 -0.03317304  0.0006597  -0.02713498 -0.02872671
#  -0.04982623 -0.01842716  0.04078072  0.00393939  0.03265614  0.11790407
#  -0.00742155  0.03902584 -0.02859023  0.04466815  0.1260979  -0.06862567
#   0.07342073  0.13925366 -0.06494177 -0.1239489  -0.04783536 -0.10157299
#  -0.02710589 -0.05133575 -0.0891052   0.05793861 -0.09085793  0.03195104
#  -0.00020525  0.06394432  0.1370776   0.08357449 -0.02144463 -0.00390564
#  -0.00825925  0.02104195 -0.02379581 -0.00021652  0.06165808  0.02950751
#   0.051615   -0.07337777 -0.00744323  0.02282266 -0.04742017 -0.16006169
#   0.15662692 -0.0741609   0.11982137 -0.01920056  0.13189231  0.06369302
#   0.05587901 -0.00826517  0.04502273  0.09610639  0.11732183  0.07538719
#   0.05035053  0.002683   -0.05261271  0.07234095  0.03164307 -0.00522169
#  -0.03261914 -0.03823821 -0.0590282  -0.20125052 -0.01906118 -0.06178959
#  -0.09286857 -0.02394725 -0.01685323 -0.11362579  0.03307991 -0.12309742
#  -0.02080454 -0.06471788  0.04001401  0.05979903 -0.11478536  0.06806748
#   0.09960797 -0.01801639 -0.04193405 -0.06564023 -0.03601778  0.03499145
#  -0.13627759  0.03483674 -0.0570371   0.04376302  0.01224036  0.01357219
#   0.01320199  0.05003291  0.10704157  0.04524255  0.02083781  0.03126407
#  -0.06271767  0.11050268  0.10540193 -0.00829325  0.00988272 -0.01233497
#  -0.09103291 -0.04087069  0.07678404 -0.01303445 -0.06454682  0.00338282
#  -0.0028732  -0.0495207  -0.00708021  0.00485354  0.09704411 -0.01878253
#  -0.07547567 -0.01625509 -0.03850627  0.02002118  0.01235248 -0.07151087
#   0.05242463  0.11181913  0.10279728  0.02423688  0.02967728  0.07405072
#  -0.01132887 -0.04562864 -0.13088986 -0.01079217  0.02454708  0.12987621
#   0.11683394  0.11712898  0.0195171   0.03440606  0.00026731 -0.12091959
#  -0.01098728  0.11052395  0.04656738  0.10130998 -0.01123325 -0.10205524
#  -0.05069085 -0.02930878  0.02273594  0.04774071 -0.03988568 -0.11869287
#   0.01471619  0.05386983  0.05377585 -0.07619216  0.09883406  0.0725232
#  -0.00693623  0.20055103 -0.05399948  0.13929215  0.01193602  0.0586677
#   0.07808036  0.04859703  0.15433493  0.02160574 -0.12705246 -0.10589804
#   0.01947742 -0.01653207]
# Cosine similarity: 0.1471
# Run 3
# True dominant eigenvalue: -40.171796861472366
# Epoch 0: Residual=39.7767, CosSim=0.0019, Exploration=1.0030, Entropy=283.9878
# Epoch 50: Residual=36.4740, CosSim=0.0588, Exploration=1.0032, Entropy=284.0000

# %%
perf = [np.mean(np.abs(results[i])) for i in range(len(choices))]

# %%
for i in range(len(choices)):
  print(f"{choices[i]} :  {perf[i]}")
